# %%
# import pandas as pd
# from imblearn.over_sampling import SMOTE
# from collections import Counter

# # Load your dataset here (replace 'your_dataset.csv' with your actual dataset file)
# data = pd.read_csv('AllTogetherEverything.csv')

# # Assuming 'material_type' is the column that indicates the material type
# X = data.drop(columns=['Material_Type'])
# y = data['Material_Type']

# # Initialize SMOTE with the desired number of samples for each class (e.g., 100)
# desired_samples = 5000
# smote = SMOTE(sampling_strategy={material_type: desired_samples for material_type in y.unique()})

# # Apply SMOTE to the dataset
# X_resampled, y_resampled = smote.fit_resample(X, y)

# # Check the new class distribution
# print("Class distribution after SMOTE:", Counter(y_resampled))

# # Now you can use X_resampled and y_resampled as your balanced dataset

# # Create a new DataFrame with the resampled data
# resampled_data = pd.DataFrame(X_resampled, columns=X.columns)
# resampled_data['Material_Type'] = y_resampled

# # Save the resampled data to a CSV file
# resampled_data.to_csv('resampled_datasetEverything.csv', index=False)
# Out:
# Class distribution after SMOTE: Counter({'HDPE': 5000, 'LDPE': 5000, 'Other': 5000, 'PP': 5000, 'PET': 5000})

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import EarlyStopping

# Load the dataset
data = pd.read_csv("resampled_datasetEverything.csv")


# Separate features and labels
X = data.drop(columns=["Material_Type"])
y = data["Material_Type"]

# %%
# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into train and test sets (Normal)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.3, random_state=42)

# # Normalize features
# X_train_normalized = (X_train - X_train.min()) / (X_train.max() - X_train.min())
# X_test_normalized = (X_test - X_train.min()) / (X_train.max() - X_train.min())
X_train_normalized = ((X_train - 0) / (8410000 - 0))
X_test_normalized = ((X_test - 0) / (8410000 - 0))

# Define the model architecture
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dense(len(label_encoder.classes_), activation="softmax")
])

# %%
# Compile the model
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(X_train_normalized, y_train, epochs=500, batch_size=64, validation_split=0.3, callbacks=[early_stopping])
# history = model.fit(X_train_normalized, y_train, epochs=500, batch_size=256, validation_split=0.2)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_normalized, y_test)

# Save the model
model.save("15_point_plastic_classifier_modelEverything.keras")
# model.save("3_point_plastic_classifier_model.keras")

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss')
plt.legend()
plt.show()

# Plot training and validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/500
# 192/192 [==============================] - 1s 2ms/step - loss: 1.0348 - accuracy: 0.5955 - val_loss: 0.6240 - val_accuracy: 0.7396
# Epoch 2/500
# 192/192 [==============================] - 0s 1ms/step - loss: 0.5398 - accuracy: 0.7516 - val_loss: 0.4955 - val_accuracy: 0.8128
# Epoch 3/500
# 192/192 [==============================] - 0s 1ms/step - loss: 0.4597 - accuracy: 0.7820 - val_loss: 0.4493 - val_accuracy: 0.7518
# Epoch 4/500
# 192/192 [==============================] - 0s 1ms/step - loss: 0.4179 - accuracy: 0.8011 - val_loss: 0.4126 - val_accuracy: 0.7794
# Epoch 5/500
# 192/192 [==============================] - 0s 1ms/step - loss: 0.3876 - accuracy: 0.8178 - val_loss: 0.3992 - val_accuracy: 0.8516
# Epoch 6/500
# 192/192 [==============================] - 0s 2ms/step - loss: 0.3662 - accuracy: 0.8385 - val_loss: 0.3681 - val_accuracy: 0.8171
# Epoch 7/500
# 192/192 [==============================] - 0s 1ms/step - loss: 0
500
# 192/192 [==============================] - 0s 1ms/step - loss: 0.0198 - accuracy: 0.9931 - val_loss: 0.0222 - val_accuracy: 0.9914
# Epoch 398/500
# 192/192 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.9935 - val_loss: 0.0190 - val_accuracy: 0.9941
# Epoch 399/500
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0211 - accuracy: 0.9916 - val_loss: 0.0332 - val_accuracy: 0.9899
# Epoch 400/500
# 192/192 [==============================] - 0s 1ms/step - loss: 0.0205 - accuracy: 0.9927 - val_loss: 0.0399 - val_accuracy: 0.9876
# Epoch 401/500
# 192/192 [==============================] - 0s 1ms/step - loss: 0.0205 - accuracy: 0.9940 - val_loss: 0.0233 - val_accuracy: 0.9910
# Epoch 402/500
# 192/192 [==============================] - 0s 1ms/step - loss: 0.0165 - accuracy: 0.9948 - val_loss: 0.0188 - val_accuracy: 0.9931
# Epoch 403/500
# 192/192 [==============================] - 0s 1ms/step - loss: 0.0213 - accuracy: 0.9924 - val_loss: 0.0377 - val_accuracy: 0.9874
# 235/235 [==============================] - 0s 789us/step - loss: 0.0169 - accuracy: 0.9937

# %%
# Make predictions
predictions = model.predict(X_test_normalized)
predicted_labels = np.argmax(predictions, axis=1)
predicted_plastic_types = label_encoder.inverse_transform(predicted_labels)



# Convert predictions to percentage likelihood
percentage_likelihood = predictions.max(axis=1) * 100

# Display test accuracy and example predictions
print(f"Test Accuracy: {test_accuracy}")
for i in range(15):
    if y_test[i] == predicted_labels[i]:
        CorF = "Correct"
    else:
        CorF = "False"
    print(f"Sample {i+1}: {CorF} Predicted {predicted_plastic_types[i]} with {percentage_likelihood[i]:.2f}% likelihood")




total_params = model.count_params()
total_size_bytes = total_params * 4  # Each parameter is usually a 32-bit float
total_size_mb = total_size_bytes / (1024)  # Convert bytes to megabytes

print(f"Total size of the model: {total_size_mb:.2f} KB")
# Out:
# 235/235 [==============================] - 0s 669us/step
# Test Accuracy: 0.9937333464622498
# Sample 1: Correct Predicted Other with 100.00% likelihood
# Sample 2: Correct Predicted PP with 94.68% likelihood
# Sample 3: Correct Predicted Other with 100.00% likelihood
# Sample 4: Correct Predicted PE with 100.00% likelihood
# Sample 5: Correct Predicted PE with 100.00% likelihood
# Sample 6: Correct Predicted Other with 100.00% likelihood
# Sample 7: Correct Predicted Alu with 100.00% likelihood
# Sample 8: Correct Predicted PE with 100.00% likelihood
# Sample 9: Correct Predicted Alu with 100.00% likelihood
# Sample 10: Correct Predicted Other with 100.00% likelihood
# Sample 11: Correct Predicted PP with 99.71% likelihood
# Sample 12: Correct Predicted Alu with 100.00% likelihood
# Sample 13: Correct Predicted Other with 100.00% likelihood
# Sample 14: Correct Predicted PET with 100.00% likelihood
# Sample 15: Correct Predicted Alu with 100.00% likelihood
# Total size of the model: 21.52 KB

# %%
# Make predictions
predictions = model.predict(X_test_normalized)

# Get the top 4 predictions for each sample
top_predictions = np.argsort(predictions, axis=1)[:, -5:]
top_labels = top_predictions[:, ::-1]

# print(predictions)

# Reshape the top_labels array to be 1D
top_labels_1d = top_labels.reshape(-1)

# Inverse transform the labels
top_plastic_types = label_encoder.inverse_transform(top_labels_1d)

# Reshape the top_plastic_types array back to 2D
top_plastic_types = top_plastic_types.reshape(top_labels.shape)

# Get the percentage likelihoods for the top 4 predictions
percentage_likelihoods = np.take_along_axis(predictions, top_predictions, axis=1) * 100

# Display test accuracy and example predictions
print(f"Test Accuracy: {test_accuracy}")
for i in range(len(predicted_labels)):
    num_predictions = min(5, len(np.unique(top_labels[i])))
    if y_test[i] == predicted_labels[i]:
        CorF = "Correct,"
    else:
        CorF = "False,"
    print(f"Sample {i+1}: {CorF} it was {label_encoder.classes_[y_test[i]]}")
    for j in range(num_predictions):
        print(f"  Prediction {j+1}: {top_plastic_types[i][j]} with {percentage_likelihoods[i][1-j]:.2f}% likelihood") #put in '1' for HvL and '3' for the others
# Out:
# 235/235 [==============================] - 0s 675us/step
# Test Accuracy: 0.9937333464622498
# Sample 1: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 2: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 94.68% likelihood
#   Prediction 4: PET with 5.32% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 3: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 4: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 5: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: Alu with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 6: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 9: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 10: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 11: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 99.71% likelihood
#   Prediction 4: Alu with 0.29% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 12: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 13: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 14: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: Alu with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 15: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 16: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 99.91% likelihood
#   Prediction 4: PET with 0.09% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 17: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 99.99% likelihood
#   Prediction 4: PET with 0.01% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 18: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 99.81% likelihood
#   Prediction 4: PET with 0.19% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 19: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: Alu with 100.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 20: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 21: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 22: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 23: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 24: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 25: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 26: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 27: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 28: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 99.33% likelihood
#   Prediction 4: Alu with 0.67% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 29: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 30: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 31: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 78.52% likelihood
#   Prediction 4: PET with 21.48% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 32: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 99.67% likelihood
#   Prediction 4: Alu with 0.27% likelihood
#   Prediction 5: PET with 0.06% likelihood
# Sample 33: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 34: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 35: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 99.97% likelihood
#   Prediction 4: PE with 0.03% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 36: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 99.80% likelihood
#   Prediction 4: PET with 0.20% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 37: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 38: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 39: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: Other with 99.13% likelihood
#   Prediction 4: PE with 0.87% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 40: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 41: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 42: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 43: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 44: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 45: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: Alu with 99.95% likelihood
#   Prediction 4: PE with 0.05% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 46: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 47: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 99.29% likelihood
#   Prediction 4: Alu with 0.71% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 48: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 98.66% likelihood
#   Prediction 4: PET with 1.34% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 49: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 50: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 51: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 52: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 99.62% likelihood
#   Prediction 4: Alu with 0.38% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 53: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 54: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 55: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 99.70% likelihood
#   Prediction 4: PET with 0.30% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 56: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 57: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 82.68% likelihood
#   Prediction 4: PET with 17.32% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 58: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 59: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 60: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: Alu with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 61: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 94.58% likelihood
#   Prediction 4: PET with 5.42% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 62: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: Alu with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 63: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 64: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 97.95% likelihood
#   Prediction 4: PET with 2.05% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 65: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 81.90% likelihood
#   Prediction 4: PET with 18.10% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 66: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 99.87% likelihood
#   Prediction 4: Alu with 0.13% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 67: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 68: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 69: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: Alu with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 70: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 71: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 72: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 73: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: Alu with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 74: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 75: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 76: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 77: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 78: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 79: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 80: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 81: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 82: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: Other with 99.99% likelihood
#   Prediction 4: PP with 0.01% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 83: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: Alu with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 84: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 85: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 97.23% likelihood
#   Prediction 4: PET with 2.77% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 86: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 87: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 88: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 99.86% likelihood
#   Prediction 4: PE with 0.14% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 89: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 97.52% likelihood
#   Prediction 4: PET with 2.48% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 90: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 91: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 98.83% likelihood
#   Prediction 4: PET with 1.17% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 92: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 93: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 94: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 95: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 96: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 98.30% likelihood
#   Prediction 4: PET with 1.70% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 97: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 97.58% likelihood
#   Prediction 4: PET with 2.42% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 98: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: Alu with 99.98% likelihood
#   Prediction 4: PE with 0.02% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 99: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 98.02% likelihood
#   Prediction 4: PET with 1.98% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 100: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 92.47% likelihood
#   Prediction 4: PET with 7.53% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 101: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 102: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 99.99% likelihood
#   Prediction 4: PET with 0.01% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 103: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 104: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PE with 99.58% likelihood
#   Prediction 4: PP with 0.42% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 105: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 97.95% likelihood
#   Prediction 4: PET with 2.05% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 106: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 107: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 108: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 109: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 110: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 50.72% likelihood
#   Prediction 4: PET with 49.28% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 111: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 112: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 113: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: Alu with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 114: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 115: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 116: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PP with 99.98% likelihood
#   Prediction 4: PET with 0.02% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 117: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 118: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 119: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 120: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 121: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Alu with 99.96% likelihood
#   Prediction 4: PE with 0.04% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 122: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 123: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 124: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 125: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 97.91% likelihood
#   Prediction 4: Alu with 2.09% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 126: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 127: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 91.31% likelihood
#   Prediction 4: PET with 8.69% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 128: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 129: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 130: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 131: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 132: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 133: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: Alu with 99.99% likelihood
#   Prediction 4: PE with 0.01% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 134: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 96.45% likelihood
#   Prediction 4: PET with 3.55% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 135: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 136: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 137: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 138: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 99.96% likelihood
#   Prediction 4: PET with 0.04% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 139: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 140: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: Alu with 100.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 141: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Alu with 97.36% likelihood
#   Prediction 4: PE with 2.64% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 142: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 143: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 144: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 145: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 146: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 87.90% likelihood
#   Prediction 4: Alu with 12.10% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 147: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: Alu with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 148: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 149: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 150: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 151: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 152: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 153: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 154: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 155: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 156: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 157: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 98.89% likelihood
#   Prediction 4: PET with 1.11% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 158: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: Alu with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 159: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 99.94% likelihood
#   Prediction 4: PE with 0.06% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 160: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 161: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: Alu with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 162: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 163: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 96.32% likelihood
#   Prediction 4: PET with 3.68% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 164: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 61.89% likelihood
#   Prediction 4: PET with 38.11% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 165: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 166: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: Alu with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 167: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 99.99% likelihood
#   Prediction 4: PET with 0.01% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 168: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 99.96% likelihood
#   Prediction 4: PET with 0.04% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 169: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: Alu with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 170: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 171: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 99.89% likelihood
#   Prediction 4: PET with 0.11% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 172: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 173: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 99.98% likelihood
#   Prediction 4: Alu with 0.02% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 174: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 94.65% likelihood
#   Prediction 4: PET with 5.35% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 175: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 176: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 99.90% likelihood
#   Prediction 4: PE with 0.10% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 177: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 178: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 97.23% likelihood
#   Prediction 4: PET with 2.77% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 179: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 97.08% likelihood
#   Prediction 4: Alu with 2.92% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 180: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 80.30% likelihood
#   Prediction 4: PET with 19.70% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 181: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 98.71% likelihood
#   Prediction 4: Alu with 1.29% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 182: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 183: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 184: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 99.44% likelihood
#   Prediction 4: Alu with 0.56% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 185: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 186: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 187: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: Alu with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 188: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Alu with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 189: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 190: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 99.99% likelihood
#   Prediction 4: PET with 0.01% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 191: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 192: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 87.36% likelihood
#   Prediction 4: PET with 12.64% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 193: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 194: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 195: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 196: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 197: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
# ...
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7436: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 7437: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7438: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 99.99% likelihood
#   Prediction 4: PET with 0.01% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7439: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: Other with 99.95% likelihood
#   Prediction 4: PE with 0.05% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7440: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 99.99% likelihood
#   Prediction 4: PET with 0.01% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7441: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 7442: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: Alu with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 7443: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 99.99% likelihood
#   Prediction 4: PP with 0.01% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7444: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 99.96% likelihood
#   Prediction 4: PET with 0.04% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7445: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7446: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7447: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7448: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7449: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7450: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7451: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7452: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7453: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 99.85% likelihood
#   Prediction 4: PET with 0.15% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7454: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 7455: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7456: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7457: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 97.57% likelihood
#   Prediction 4: PET with 2.43% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7458: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7459: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 99.52% likelihood
#   Prediction 4: PET with 0.48% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7460: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 98.95% likelihood
#   Prediction 4: Alu with 1.05% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 7461: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7462: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7463: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7464: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 97.26% likelihood
#   Prediction 4: Alu with 2.74% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 7465: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 99.89% likelihood
#   Prediction 4: Alu with 0.11% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 7466: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 99.99% likelihood
#   Prediction 4: PET with 0.01% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7467: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7468: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7469: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 7470: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 98.36% likelihood
#   Prediction 4: Alu with 1.64% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 7471: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 7472: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7473: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7474: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7475: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7476: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 98.43% likelihood
#   Prediction 4: PET with 1.57% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7477: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 98.72% likelihood
#   Prediction 4: PET with 1.28% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7478: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 98.58% likelihood
#   Prediction 4: PET with 1.42% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7479: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 7480: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 75.89% likelihood
#   Prediction 4: PET with 24.11% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7481: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7482: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 7483: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 99.99% likelihood
#   Prediction 4: Alu with 0.01% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 7484: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 98.16% likelihood
#   Prediction 4: Alu with 1.84% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 7485: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: Alu with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 7486: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7487: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 7488: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7489: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 7490: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7491: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 99.99% likelihood
#   Prediction 4: PET with 0.01% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7492: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7493: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 7494: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 98.23% likelihood
#   Prediction 4: Alu with 1.77% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 7495: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 7496: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 99.26% likelihood
#   Prediction 4: Alu with 0.74% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 7497: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 95.33% likelihood
#   Prediction 4: Alu with 4.67% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 7498: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7499: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: Alu with 0.00% likelihood
# Sample 7500: Correct, it was Alu
#   Prediction 1: Alu with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood

# %%
# Get manual input from the user
manual_input = np.array([[1365889,2383139,3943193,6364119,6459881,3520279,1572135,859381,1734251,3039005,5108675,6392189,4980199,2559117,1249619]])  # Replace with your input values

# Normalize the manual input if needed
normalized_manual_input = ((manual_input - 0) / (8388608 - 0))

# Make predictions on manual input
predictions = model.predict(normalized_manual_input)
print(predictions)

# Get the top prediction
top_prediction = np.argmax(predictions)
print(top_prediction)

top_plastic_type = label_encoder.inverse_transform([top_prediction])[0]
print(top_plastic_type)
likelihood = predictions[0][top_prediction] * 100

# Display the prediction for manual input
print(f"Manual Input Prediction:")
print(f"  Prediction: {top_plastic_type} with {likelihood:.2f}% likelihood")
# Out:
# 1/1 [==============================] - 0s 59ms/step
# [[3.3573198e-24 4.6895738e-15 3.2550696e-02 8.9477867e-23 9.6744931e-01]]
# 4
# PP
# Manual Input Prediction:
#   Prediction: PP with 96.74% likelihood

# %%
# Make predictions from manual
manual_input = np.array([[1365889,2383139,3943193,6364119,6459881,3520279,1572135,859381,1734251,3039005,5108675,6392189,4980199,2559117,1249619
]])

# Calculate the column-wise min and max values from your original dataset
min_values = [74296, 1151721, 2379300, 2748695, 3681840, 1997402, 1742243, 942818, 392145, 795677, 1406647, 2482140, 2630495, 1748806, 1249297]
max_values = [1773075, 3755206, 7787954, 8401566, 8405071, 8401566, 7232265, 8185313, 2080604, 4455589, 8402979, 8405071, 8405071, 8403086, 6084492]

# Convert the lists to numpy arrays
min_values = np.array(min_values)
max_values = np.array(max_values)

# Normalize the manual input using the calculated min and max values
normalized_manual_input = (manual_input - min_values) / (max_values - min_values)
# normalized_manual_input = np.array([[0.85611,0.63202,0.53239,0.41068,0.59174,0.39869,0.44654,0.42188,0.8826042,0.67470967,0.34701898,0.42024683,0.34977269,0.16862726,0.1471771]])

print(normalized_manual_input)

predictions = model.predict(normalized_manual_input)
predicted_labels = np.argmax(predictions, axis=1)
predicted_plastic_types = label_encoder.inverse_transform(predicted_labels)

    
## Calculate the percentage likelihoods
percentage_likelihoods = predictions * 100

# Get the indices of the top 4 predicted classes based on percentage likelihoods
top_indices = np.argsort(percentage_likelihoods[0])[::-1][:4]

# Get the labels for the top predicted classes
top_labels = label_encoder.inverse_transform(top_indices)

# Get the predicted label
predicted_label = top_labels[0]

# Get the true label from the original data (replace with your true label)
true_label = 'ALU'  # Replace with the true label

# Calculate the accuracy
if predicted_label == true_label:
    accuracy = "Correct"
else:
    accuracy = "False"

# Print the prediction, label, and accuracy
print(f"Predicted label: {predicted_label}")
print(f"True label: {true_label}")
print(f"Accuracy: {accuracy}")

# Print the percentages for each type
for label, likelihood in zip(top_labels, percentage_likelihoods[0][top_indices]):
    print(f"{label}: {likelihood:.2f}% likelihood")
# Out:
# [[ 7.60306667e-01  4.72988321e-01  2.89146431e-01  6.39573059e-01
#    5.88165389e-01  2.37794816e-01 -3.09849396e-02 -1.15204774e-02
#    7.94870352e-01  6.12945885e-01  5.29138411e-01  6.60154407e-01
#    4.06905026e-01  1.21772904e-01  6.65950391e-05]]
# 1/1 [==============================] - 0s 39ms/step
# Predicted label: PE
# True label: ALU
# Accuracy: False
# PE: 99.99% likelihood
# PP: 0.01% likelihood
# PET: 0.00% likelihood
# Other: 0.00% likelihood
