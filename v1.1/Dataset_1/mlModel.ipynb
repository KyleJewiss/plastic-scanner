# %%
# import pandas as pd
# from imblearn.over_sampling import SMOTE
# from collections import Counter

# # Load your dataset here (replace 'your_dataset.csv' with your actual dataset file)
# # data = pd.read_csv('AllTogether.csv')
# data = pd.read_csv("AllTogether8Ptest.csv")
# # data = pd.read_csv("HDPEvsLDPE.csv")

# # Assuming 'material_type' is the column that indicates the material type
# X = data.drop(columns=['Material_Type'])
# y = data['Material_Type']

# # Initialize SMOTE with the desired number of samples for each class (e.g., 100)
# desired_samples = 2000
# smote = SMOTE(sampling_strategy={material_type: desired_samples for material_type in y.unique()})

# # Apply SMOTE to the dataset
# X_resampled, y_resampled = smote.fit_resample(X, y)

# # Check the new class distribution
# print("Class distribution after SMOTE:", Counter(y_resampled))

# # Now you can use X_resampled and y_resampled as your balanced dataset

# # Create a new DataFrame with the resampled data
# resampled_data = pd.DataFrame(X_resampled, columns=X.columns)
# resampled_data['Material_Type'] = y_resampled

# # Save the resampled data to a CSV file
# resampled_data.to_csv('resampled_dataset8Ptest.csv', index=False)

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import EarlyStopping

# Load the dataset
data = pd.read_csv("AllTogether8Ptest.csv")
# data = pd.read_csv("resampled_datasetNewPPFAT.csv")
# data = pd.read_csv("resampled_datasetHvL.csv")


# Separate features and labels
X = data.drop(columns=["Material_Type"])
y = data["Material_Type"]

# %%
# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into train and test sets (Normal)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.3, random_state=42)

# # Normalize features
# X_train_normalized = (X_train - X_train.min()) / (X_train.max() - X_train.min())
# X_test_normalized = (X_test - X_train.min()) / (X_train.max() - X_train.min())
X_train_normalized = ((X_train - 0) / (8410000 - 0))
X_test_normalized = ((X_test - 0) / (8410000 - 0))

# Define the model architecture
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(256, activation="relu"),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(len(label_encoder.classes_), activation="softmax")
])

# %%
# Compile the model
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# # Define early stopping callback
# early_stopping = EarlyStopping(
#     monitor='val_loss',  # Monitor validation loss
#     patience=10,          # Wait for 10 epochs without improvement
#     min_delta=0.001,      # Minimum change required to consider an improvement
#     verbose=1,            # Print messages about early stopping
#     restore_best_weights=True
# )

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(X_train_normalized, y_train, epochs=200, batch_size=128, validation_split=0.3, callbacks=[early_stopping])
# history = model.fit(X_train_normalized, y_train, epochs=500, batch_size=256, validation_split=0.2)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_normalized, y_test)

# Save the model
model.save("15_point_plastic_classifier_modelHvL.keras")
# model.save("15_point_plastic_classifier_model_99Perc")

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss')
plt.legend()
plt.show()

# Plot training and validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and
200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4700 - accuracy: 0.7580 - val_loss: 0.5356 - val_accuracy: 0.6765
# Epoch 190/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4721 - accuracy: 0.7580 - val_loss: 0.5330 - val_accuracy: 0.6765
# Epoch 191/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4685 - accuracy: 0.7580 - val_loss: 0.5254 - val_accuracy: 0.6765
# Epoch 192/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4639 - accuracy: 0.7580 - val_loss: 0.5268 - val_accuracy: 0.6765
# Epoch 193/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4655 - accuracy: 0.7580 - val_loss: 0.5244 - val_accuracy: 0.6765
# Epoch 194/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.4637 - accuracy: 0.7516 - val_loss: 0.5224 - val_accuracy: 0.6765
# Epoch 195/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.4605 - accuracy: 0.7516 - val_loss: 0.5212 - val_accuracy: 0.6765
# Epoch 196/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4607 - accuracy: 0.7516 - val_loss: 0.5212 - val_accuracy: 0.6765
# Epoch 197/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4583 - accuracy: 0.7707 - val_loss: 0.5231 - val_accuracy: 0.6765
# Epoch 198/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4595 - accuracy: 0.7707 - val_loss: 0.5240 - val_accuracy: 0.6765
# Epoch 199/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.4563 - accuracy: 0.7707 - val_loss: 0.5216 - val_accuracy: 0.6765
# Epoch 200/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4515 - accuracy: 0.7580 - val_loss: 0.5176 - val_accuracy: 0.6765
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4638 - accuracy: 0.7629

# %%
# Make predictions
predictions = model.predict(X_test_normalized)
predicted_labels = np.argmax(predictions, axis=1)
predicted_plastic_types = label_encoder.inverse_transform(predicted_labels)



# Convert predictions to percentage likelihood
percentage_likelihood = predictions.max(axis=1) * 100

# Display test accuracy and example predictions
print(f"Test Accuracy: {test_accuracy}")
for i in range(15):
    if y_test[i] == predicted_labels[i]:
        CorF = "Correct"
    else:
        CorF = "False"
    print(f"Sample {i+1}: {CorF} Predicted {predicted_plastic_types[i]} with {percentage_likelihood[i]:.2f}% likelihood")




total_params = model.count_params()
total_size_bytes = total_params * 4  # Each parameter is usually a 32-bit float
total_size_mb = total_size_bytes / (1024)  # Convert bytes to megabytes

print(f"Total size of the model: {total_size_mb:.2f} KB")
# Out:
# 4/4 [==============================] - 0s 6ms/step
# Test Accuracy: 0.7628865838050842
# Sample 1: False Predicted PE with 58.01% likelihood
# Sample 2: Correct Predicted ALU with 98.77% likelihood
# Sample 3: Correct Predicted Other with 90.37% likelihood
# Sample 4: Correct Predicted PE with 88.52% likelihood
# Sample 5: Correct Predicted PE with 59.67% likelihood
# Sample 6: Correct Predicted PE with 58.34% likelihood
# Sample 7: Correct Predicted Other with 99.26% likelihood
# Sample 8: Correct Predicted ALU with 98.89% likelihood
# Sample 9: Correct Predicted Other with 99.96% likelihood
# Sample 10: False Predicted PE with 55.03% likelihood
# Sample 11: Correct Predicted Other with 56.06% likelihood
# Sample 12: Correct Predicted PE with 59.86% likelihood
# Sample 13: False Predicted PE with 60.13% likelihood
# Sample 14: Correct Predicted PE with 51.99% likelihood
# Sample 15: False Predicted PE with 56.40% likelihood
# Total size of the model: 140.02 KB

# %%
# Make predictions
predictions = model.predict(X_test_normalized)

# Get the top 4 predictions for each sample
top_predictions = np.argsort(predictions, axis=1)[:, -4:]
top_labels = top_predictions[:, ::-1]

# print(predictions)

# Reshape the top_labels array to be 1D
top_labels_1d = top_labels.reshape(-1)

# Inverse transform the labels
top_plastic_types = label_encoder.inverse_transform(top_labels_1d)

# Reshape the top_plastic_types array back to 2D
top_plastic_types = top_plastic_types.reshape(top_labels.shape)

# Get the percentage likelihoods for the top 4 predictions
percentage_likelihoods = np.take_along_axis(predictions, top_predictions, axis=1) * 100

# Display test accuracy and example predictions
print(f"Test Accuracy: {test_accuracy}")
for i in range(len(predicted_labels)):
    num_predictions = min(4, len(np.unique(top_labels[i])))
    if y_test[i] == predicted_labels[i]:
        CorF = "Correct,"
    else:
        CorF = "False,"
    print(f"Sample {i+1}: {CorF} it was {label_encoder.classes_[y_test[i]]}")
    for j in range(num_predictions):
        print(f"  Prediction {j+1}: {top_plastic_types[i][j]} with {percentage_likelihoods[i][1-j]:.2f}% likelihood") #put in '1' for HvL and '3' for the others
# Out:
# 4/4 [==============================] - 0s 1ms/step
# Test Accuracy: 0.7628865838050842
# Sample 1: False, it was PLA
#   Prediction 1: PE with 16.21% likelihood
#   Prediction 2: PP with 1.95% likelihood
#   Prediction 3: PLA with 58.01% likelihood
#   Prediction 4: Other with 23.82% likelihood
# Sample 2: Correct, it was ALU
#   Prediction 1: ALU with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PLA with 98.77% likelihood
#   Prediction 4: PE with 1.23% likelihood
# Sample 3: Correct, it was Other
#   Prediction 1: Other with 0.22% likelihood
#   Prediction 2: ALU with 0.14% likelihood
#   Prediction 3: PLA with 90.37% likelihood
#   Prediction 4: PE with 9.27% likelihood
# Sample 4: Correct, it was PE
#   Prediction 1: PE with 1.02% likelihood
#   Prediction 2: PP with 0.68% likelihood
#   Prediction 3: Other with 88.52% likelihood
#   Prediction 4: PLA with 9.79% likelihood
# Sample 5: Correct, it was PE
#   Prediction 1: PE with 3.19% likelihood
#   Prediction 2: PP with 0.77% likelihood
#   Prediction 3: PLA with 59.67% likelihood
#   Prediction 4: Other with 36.36% likelihood
# Sample 6: Correct, it was PE
#   Prediction 1: PE with 3.44% likelihood
#   Prediction 2: PP with 0.68% likelihood
#   Prediction 3: PLA with 58.34% likelihood
#   Prediction 4: Other with 37.54% likelihood
# Sample 7: Correct, it was Other
#   Prediction 1: Other with 0.01% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PLA with 99.26% likelihood
#   Prediction 4: ALU with 0.72% likelihood
# Sample 8: Correct, it was ALU
#   Prediction 1: ALU with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PLA with 98.89% likelihood
#   Prediction 4: PE with 1.11% likelihood
# Sample 9: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PLA with 99.96% likelihood
#   Prediction 4: ALU with 0.04% likelihood
# Sample 10: False, it was PP
#   Prediction 1: PE with 3.46% likelihood
#   Prediction 2: PP with 0.57% likelihood
#   Prediction 3: PLA with 55.03% likelihood
#   Prediction 4: Other with 40.94% likelihood
# Sample 11: Correct, it was Other
#   Prediction 1: Other with 19.90% likelihood
#   Prediction 2: PE with 1.33% likelihood
#   Prediction 3: PLA with 56.06% likelihood
#   Prediction 4: ALU with 22.26% likelihood
# Sample 12: Correct, it was PE
#   Prediction 1: PE with 4.65% likelihood
#   Prediction 2: PP with 0.88% likelihood
#   Prediction 3: PLA with 59.86% likelihood
#   Prediction 4: Other with 34.60% likelihood
# Sample 13: False, it was PP
#   Prediction 1: PE with 2.26% likelihood
#   Prediction 2: PP with 0.55% likelihood
#   Prediction 3: PLA with 60.13% likelihood
#   Prediction 4: Other with 37.05% likelihood
# Sample 14: Correct, it was PE
#   Prediction 1: PE with 16.29% likelihood
#   Prediction 2: PLA with 5.05% likelihood
#   Prediction 3: Other with 51.99% likelihood
#   Prediction 4: PP with 26.49% likelihood
# Sample 15: False, it was PLA
#   Prediction 1: PE with 16.69% likelihood
#   Prediction 2: PLA with 2.76% likelihood
#   Prediction 3: PP with 56.40% likelihood
#   Prediction 4: Other with 24.13% likelihood
# Sample 16: False, it was PP
#   Prediction 1: PE with 4.39% likelihood
#   Prediction 2: PP with 0.67% likelihood
#   Prediction 3: PLA with 55.82% likelihood
#   Prediction 4: Other with 39.11% likelihood
# Sample 17: Correct, it was PE
#   Prediction 1: PE with 5.32% likelihood
#   Prediction 2: PP with 0.91% likelihood
#   Prediction 3: PLA with 59.19% likelihood
#   Prediction 4: Other with 34.57% likelihood
# Sample 18: Correct, it was PE
#   Prediction 1: PE with 2.84% likelihood
#   Prediction 2: PP with 0.67% likelihood
#   Prediction 3: PLA with 61.58% likelihood
#   Prediction 4: Other with 34.91% likelihood
# Sample 19: Correct, it was PE
#   Prediction 1: PE with 2.41% likelihood
#   Prediction 2: PP with 2.00% likelihood
#   Prediction 3: PLA with 83.34% likelihood
#   Prediction 4: Other with 12.25% likelihood
# Sample 20: Correct, it was PE
#   Prediction 1: PE with 1.68% likelihood
#   Prediction 2: PP with 1.39% likelihood
#   Prediction 3: Other with 86.59% likelihood
#   Prediction 4: PLA with 10.34% likelihood
# Sample 21: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PLA with 99.88% likelihood
#   Prediction 4: ALU with 0.12% likelihood
# Sample 22: Correct, it was PE
#   Prediction 1: PE with 2.17% likelihood
#   Prediction 2: PP with 1.65% likelihood
#   Prediction 3: PLA with 81.29% likelihood
#   Prediction 4: Other with 14.88% likelihood
# Sample 23: Correct, it was PE
#   Prediction 1: PE with 1.20% likelihood
#   Prediction 2: PP with 0.77% likelihood
#   Prediction 3: Other with 84.43% likelihood
#   Prediction 4: PLA with 13.59% likelihood
# Sample 24: False, it was PP
#   Prediction 1: PE with 3.90% likelihood
#   Prediction 2: PP with 0.61% likelihood
#   Prediction 3: PLA with 55.62% likelihood
#   Prediction 4: Other with 39.86% likelihood
# Sample 25: False, it was PP
#   Prediction 1: PE with 3.20% likelihood
#   Prediction 2: PP with 0.53% likelihood
#   Prediction 3: PLA with 54.89% likelihood
#   Prediction 4: Other with 41.38% likelihood
# Sample 26: Correct, it was PE
#   Prediction 1: PE with 3.52% likelihood
#   Prediction 2: PP with 0.85% likelihood
#   Prediction 3: PLA with 60.71% likelihood
#   Prediction 4: Other with 34.92% likelihood
# Sample 27: Correct, it was PE
#   Prediction 1: PE with 1.81% likelihood
#   Prediction 2: PP with 1.28% likelihood
#   Prediction 3: PLA with 78.46% likelihood
#   Prediction 4: Other with 18.45% likelihood
# Sample 28: Correct, it was PE
#   Prediction 1: PE with 3.50% likelihood
#   Prediction 2: PP with 1.61% likelihood
#   Prediction 3: PLA with 76.33% likelihood
#   Prediction 4: Other with 18.56% likelihood
# Sample 29: Correct, it was Other
#   Prediction 1: Other with 6.35% likelihood
#   Prediction 2: PE with 0.05% likelihood
#   Prediction 3: PLA with 86.50% likelihood
#   Prediction 4: PP with 7.10% likelihood
# Sample 30: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PLA with 99.88% likelihood
#   Prediction 4: ALU with 0.12% likelihood
# Sample 31: Correct, it was PE
#   Prediction 1: PE with 5.04% likelihood
#   Prediction 2: PP with 0.96% likelihood
#   Prediction 3: PLA with 60.66% likelihood
#   Prediction 4: Other with 33.34% likelihood
# Sample 32: False, it was Other
#   Prediction 1: PE with 0.39% likelihood
#   Prediction 2: Other with 0.23% likelihood
#   Prediction 3: PP with 79.28% likelihood
#   Prediction 4: PLA with 20.07% likelihood
# Sample 33: Correct, it was PE
#   Prediction 1: PE with 1.73% likelihood
#   Prediction 2: PP with 1.06% likelihood
#   Prediction 3: PLA with 79.51% likelihood
#   Prediction 4: Other with 17.69% likelihood
# Sample 34: False, it was Other
#   Prediction 1: PE with 6.59% likelihood
#   Prediction 2: PLA with 6.41% likelihood
#   Prediction 3: PP with 74.62% likelihood
#   Prediction 4: Other with 12.37% likelihood
# Sample 35: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PLA with 99.86% likelihood
#   Prediction 4: ALU with 0.13% likelihood
# Sample 36: Correct, it was ALU
#   Prediction 1: ALU with 0.01% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PLA with 94.80% likelihood
#   Prediction 4: PE with 5.19% likelihood
# Sample 37: False, it was PP
#   Prediction 1: PE with 2.62% likelihood
#   Prediction 2: PP with 0.48% likelihood
#   Prediction 3: PLA with 55.43% likelihood
#   Prediction 4: Other with 41.46% likelihood
# Sample 38: Correct, it was PE
#   Prediction 1: PE with 5.72% likelihood
#   Prediction 2: PP with 3.05% likelihood
#   Prediction 3: PLA with 80.95% likelihood
#   Prediction 4: Other with 10.28% likelihood
# Sample 39: Correct, it was ALU
#   Prediction 1: ALU with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PLA with 99.79% likelihood
#   Prediction 4: PE with 0.21% likelihood
# Sample 40: Correct, it was ALU
#   Prediction 1: ALU with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PLA with 98.71% likelihood
#   Prediction 4: PE with 1.28% likelihood
# Sample 41: False, it was PP
#   Prediction 1: PE with 3.04% likelihood
#   Prediction 2: PP with 0.52% likelihood
#   Prediction 3: PLA with 55.48% likelihood
#   Prediction 4: Other with 40.96% likelihood
# Sample 42: Correct, it was PE
#   Prediction 1: PE with 9.95% likelihood
#   Prediction 2: PP with 2.68% likelihood
#   Prediction 3: PLA with 66.07% likelihood
#   Prediction 4: Other with 21.29% likelihood
# Sample 43: False, it was PP
#   Prediction 1: PE with 3.58% likelihood
#   Prediction 2: PP with 0.76% likelihood
#   Prediction 3: PLA with 58.74% likelihood
#   Prediction 4: Other with 36.92% likelihood
# Sample 44: False, it was PP
#   Prediction 1: PE with 3.82% likelihood
#   Prediction 2: PP with 0.67% likelihood
#   Prediction 3: PLA with 57.07% likelihood
#   Prediction 4: Other with 38.44% likelihood
# Sample 45: Correct, it was PE
#   Prediction 1: PE with 6.86% likelihood
#   Prediction 2: PP with 2.28% likelihood
#   Prediction 3: PLA with 77.30% likelihood
#   Prediction 4: Other with 13.56% likelihood
# Sample 46: False, it was PP
#   Prediction 1: PE with 2.83% likelihood
#   Prediction 2: PP with 0.48% likelihood
#   Prediction 3: PLA with 54.30% likelihood
#   Prediction 4: Other with 42.39% likelihood
# Sample 47: Correct, it was PE
#   Prediction 1: PE with 3.47% likelihood
#   Prediction 2: PP with 0.82% likelihood
#   Prediction 3: PLA with 61.10% likelihood
#   Prediction 4: Other with 34.61% likelihood
# Sample 48: Correct, it was PE
#   Prediction 1: PE with 5.93% likelihood
#   Prediction 2: PP with 1.08% likelihood
#   Prediction 3: PLA with 61.08% likelihood
#   Prediction 4: Other with 31.91% likelihood
# Sample 49: Correct, it was PE
#   Prediction 1: PE with 5.63% likelihood
#   Prediction 2: Other with 5.02% likelihood
#   Prediction 3: PLA with 77.32% likelihood
#   Prediction 4: PP with 12.03% likelihood
# Sample 50: Correct, it was PE
#   Prediction 1: PE with 1.42% likelihood
#   Prediction 2: PP with 1.09% likelihood
#   Prediction 3: PLA with 77.15% likelihood
#   Prediction 4: Other with 20.34% likelihood
# Sample 51: Correct, it was PE
#   Prediction 1: PE with 3.80% likelihood
#   Prediction 2: PP with 0.85% likelihood
#   Prediction 3: PLA with 60.76% likelihood
#   Prediction 4: Other with 34.58% likelihood
# Sample 52: Correct, it was PE
#   Prediction 1: PE with 3.68% likelihood
#   Prediction 2: PP with 0.77% likelihood
#   Prediction 3: PLA with 62.23% likelihood
#   Prediction 4: Other with 33.32% likelihood
# Sample 53: False, it was PLA
#   Prediction 1: PE with 27.35% likelihood
#   Prediction 2: PLA with 2.54% likelihood
#   Prediction 3: Other with 35.90% likelihood
#   Prediction 4: PP with 33.89% likelihood
# Sample 54: Correct, it was PE
#   Prediction 1: PE with 1.71% likelihood
#   Prediction 2: PP with 0.81% likelihood
#   Prediction 3: PLA with 72.70% likelihood
#   Prediction 4: Other with 24.78% likelihood
# Sample 55: False, it was PP
#   Prediction 1: PE with 2.49% likelihood
#   Prediction 2: PP with 0.58% likelihood
#   Prediction 3: PLA with 57.38% likelihood
#   Prediction 4: Other with 39.55% likelihood
# Sample 56: False, it was PP
#   Prediction 1: PE with 2.29% likelihood
#   Prediction 2: PP with 0.56% likelihood
#   Prediction 3: PLA with 58.00% likelihood
#   Prediction 4: Other with 39.14% likelihood
# Sample 57: False, it was PP
#   Prediction 1: PE with 2.46% likelihood
#   Prediction 2: PP with 0.62% likelihood
#   Prediction 3: PLA with 59.36% likelihood
#   Prediction 4: Other with 37.55% likelihood
# Sample 58: Correct, it was PE
#   Prediction 1: PE with 2.37% likelihood
#   Prediction 2: PP with 2.17% likelihood
#   Prediction 3: PLA with 87.78% likelihood
#   Prediction 4: Other with 7.66% likelihood
# Sample 59: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PLA with 99.88% likelihood
#   Prediction 4: ALU with 0.12% likelihood
# Sample 60: Correct, it was PE
#   Prediction 1: PE with 4.34% likelihood
#   Prediction 2: PP with 0.69% likelihood
#   Prediction 3: PLA with 56.48% likelihood
#   Prediction 4: Other with 38.49% likelihood
# Sample 61: Correct, it was Other
#   Prediction 1: Other with 0.90% likelihood
#   Prediction 2: PE with 0.04% likelihood
#   Prediction 3: PLA with 82.42% likelihood
#   Prediction 4: PP with 16.63% likelihood
# Sample 62: Correct, it was PE
#   Prediction 1: PE with 7.35% likelihood
#   Prediction 2: PP with 1.11% likelihood
#   Prediction 3: PLA with 59.70% likelihood
#   Prediction 4: Other with 31.84% likelihood
# Sample 63: Correct, it was Other
#   Prediction 1: Other with 0.01% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PLA with 99.37% likelihood
#   Prediction 4: ALU with 0.62% likelihood
# Sample 64: Correct, it was Other
#   Prediction 1: Other with 0.05% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PLA with 97.93% likelihood
#   Prediction 4: PP with 2.02% likelihood
# Sample 65: Correct, it was PE
#   Prediction 1: PE with 3.49% likelihood
#   Prediction 2: PP with 0.67% likelihood
#   Prediction 3: PLA with 58.55% likelihood
#   Prediction 4: Other with 37.29% likelihood
# Sample 66: Correct, it was PLA
#   Prediction 1: PLA with 26.31% likelihood
#   Prediction 2: PE with 2.51% likelihood
#   Prediction 3: Other with 35.84% likelihood
#   Prediction 4: PP with 35.02% likelihood
# Sample 67: Correct, it was PE
#   Prediction 1: PE with 4.25% likelihood
#   Prediction 2: PP with 4.04% likelihood
#   Prediction 3: Other with 81.07% likelihood
#   Prediction 4: PLA with 10.64% likelihood
# Sample 68: Correct, it was PE
#   Prediction 1: PE with 5.09% likelihood
#   Prediction 2: PP with 1.34% likelihood
#   Prediction 3: PLA with 64.70% likelihood
#   Prediction 4: Other with 28.86% likelihood
# Sample 69: False, it was PLA
#   Prediction 1: PE with 15.91% likelihood
#   Prediction 2: PP with 1.77% likelihood
#   Prediction 3: PLA with 56.54% likelihood
#   Prediction 4: Other with 25.77% likelihood
# Sample 70: Correct, it was PE
#   Prediction 1: PE with 3.75% likelihood
#   Prediction 2: PP with 0.73% likelihood
#   Prediction 3: PLA with 58.50% likelihood
#   Prediction 4: Other with 37.01% likelihood
# Sample 71: Correct, it was PE
#   Prediction 1: PE with 11.72% likelihood
#   Prediction 2: PLA with 5.90% likelihood
#   Prediction 3: Other with 46.11% likelihood
#   Prediction 4: PP with 36.20% likelihood
# Sample 72: Correct, it was PE
#   Prediction 1: PE with 4.77% likelihood
#   Prediction 2: PP with 0.91% likelihood
#   Prediction 3: PLA with 59.65% likelihood
#   Prediction 4: Other with 34.67% likelihood
# Sample 73: Correct, it was ALU
#   Prediction 1: ALU with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 99.95% likelihood
#   Prediction 4: PLA with 0.05% likelihood
# Sample 74: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PLA with 99.86% likelihood
#   Prediction 4: ALU with 0.13% likelihood
# Sample 75: False, it was PP
#   Prediction 1: PE with 2.61% likelihood
#   Prediction 2: PP with 0.52% likelihood
#   Prediction 3: PLA with 55.96% likelihood
#   Prediction 4: Other with 40.90% likelihood
# Sample 76: Correct, it was PE
#   Prediction 1: PE with 3.51% likelihood
#   Prediction 2: PP with 0.90% likelihood
#   Prediction 3: PLA with 61.93% likelihood
#   Prediction 4: Other with 33.66% likelihood
# Sample 77: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PLA with 99.83% likelihood
#   Prediction 4: ALU with 0.17% likelihood
# Sample 78: False, it was PP
#   Prediction 1: PE with 3.78% likelihood
#   Prediction 2: PP with 0.67% likelihood
#   Prediction 3: PLA with 57.10% likelihood
#   Prediction 4: Other with 38.44% likelihood
# Sample 79: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PLA with 99.93% likelihood
#   Prediction 4: ALU with 0.07% likelihood
# Sample 80: Correct, it was PE
#   Prediction 1: PE with 3.39% likelihood
#   Prediction 2: PP with 0.87% likelihood
#   Prediction 3: PLA with 63.92% likelihood
#   Prediction 4: Other with 31.82% likelihood
# Sample 81: False, it was PP
#   Prediction 1: PE with 3.50% likelihood
#   Prediction 2: PP with 0.63% likelihood
#   Prediction 3: PLA with 56.69% likelihood
#   Prediction 4: Other with 39.19% likelihood
# Sample 82: Correct, it was ALU
#   Prediction 1: ALU with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PLA with 98.64% likelihood
#   Prediction 4: PE with 1.36% likelihood
# Sample 83: Correct, it was ALU
#   Prediction 1: ALU with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PLA with 98.68% likelihood
#   Prediction 4: PE with 1.31% likelihood
# Sample 84: Correct, it was Other
#   Prediction 1: Other with 0.29% likelihood
#   Prediction 2: PE with 0.01% likelihood
#   Prediction 3: PLA with 91.70% likelihood
#   Prediction 4: PP with 8.00% likelihood
# Sample 85: Correct, it was Other
#   Prediction 1: Other with 0.31% likelihood
#   Prediction 2: PE with 0.01% likelihood
#   Prediction 3: PLA with 89.53% likelihood
#   Prediction 4: PP with 10.14% likelihood
# Sample 86: Correct, it was ALU
#   Prediction 1: ALU with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PLA with 99.85% likelihood
#   Prediction 4: PE with 0.15% likelihood
# Sample 87: Correct, it was PE
#   Prediction 1: PE with 2.71% likelihood
#   Prediction 2: PP with 1.32% likelihood
#   Prediction 3: PLA with 78.42% likelihood
#   Prediction 4: Other with 17.55% likelihood
# Sample 88: Correct, it was ALU
#   Prediction 1: ALU with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PLA with 98.73% likelihood
#   Prediction 4: PE with 1.27% likelihood
# Sample 89: Correct, it was PE
#   Prediction 1: PE with 2.27% likelihood
#   Prediction 2: PP with 1.86% likelihood
#   Prediction 3: Other with 86.69% likelihood
#   Prediction 4: PLA with 9.18% likelihood
# Sample 90: Correct, it was Other
#   Prediction 1: Other with 0.24% likelihood
#   Prediction 2: ALU with 0.15% likelihood
#   Prediction 3: PLA with 89.77% likelihood
#   Prediction 4: PE with 9.85% likelihood
# Sample 91: Correct, it was PE
#   Prediction 1: PE with 3.42% likelihood
#   Prediction 2: PP with 0.61% likelihood
#   Prediction 3: PLA with 56.92% likelihood
#   Prediction 4: Other with 39.05% likelihood
# Sample 92: Correct, it was PE
#   Prediction 1: PE with 1.58% likelihood
#   Prediction 2: PP with 1.34% likelihood
#   Prediction 3: PLA with 82.87% likelihood
#   Prediction 4: Other with 14.21% likelihood
# Sample 93: False, it was PP
#   Prediction 1: PE with 3.25% likelihood
#   Prediction 2: PP with 0.62% likelihood
#   Prediction 3: PLA with 56.70% likelihood
#   Prediction 4: Other with 39.43% likelihood
# Sample 94: Correct, it was Other
#   Prediction 1: Other with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PLA with 99.88% likelihood
#   Prediction 4: ALU with 0.12% likelihood
# Sample 95: Correct, it was PE
#   Prediction 1: PE with 1.95% likelihood
#   Prediction 2: PP with 0.70% likelihood
#   Prediction 3: PLA with 67.48% likelihood
#   Prediction 4: Other with 29.87% likelihood
# Sample 96: Correct, it was ALU
#   Prediction 1: ALU with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PLA with 98.64% likelihood
#   Prediction 4: PE with 1.36% likelihood
# Sample 97: Correct, it was ALU
#   Prediction 1: ALU with 0.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PLA with 99.80% likelihood
#   Prediction 4: PE with 0.20% likelihood

# %%
# Get manual input from the user
manual_input = np.array([[1365889,2383139,3943193,6364119,6459881,3520279,1572135,859381,1734251,3039005,5108675,6392189,4980199,2559117,1249619]])  # Replace with your input values

# Normalize the manual input if needed
normalized_manual_input = ((manual_input - 0) / (8388608 - 0))

# Make predictions on manual input
predictions = model.predict(normalized_manual_input)
print(predictions)

# Get the top prediction
top_prediction = np.argmax(predictions)
print(top_prediction)

top_plastic_type = label_encoder.inverse_transform([top_prediction])[0]
print(top_plastic_type)
likelihood = predictions[0][top_prediction] * 100

# Display the prediction for manual input
print(f"Manual Input Prediction:")
print(f"  Prediction: {top_plastic_type} with {likelihood:.2f}% likelihood")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\kylej\dev\plastic-scanner\v1.1\Dataset 1\mlModel.ipynb Cell 7 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/mlModel.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> normalized_manual_input = ((manual_input - 0) / (8388608 - 0))
#       <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/mlModel.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a> # Make predictions on manual input
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/mlModel.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a> predictions = model.predict(normalized_manual_input)
#       <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/mlModel.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a> print(predictions)
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/mlModel.ipynb#W6sZmlsZQ%3D%3D?line=10'>11</a> # Get the top prediction
#
# File c:\Users\kylej\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_filezly6j0k4.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "c:\Users\kylej\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py", line 2341, in predict_function  *
#         return step_function(self, iterator)
#     File "c:\Users\kylej\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py", line 2327, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\kylej\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py", line 2315, in run_step  **
#         outputs = model.predict_step(data)
#     File "c:\Users\kylej\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py", line 2283, in predict_step
#         return self(x, training=False)
#     File "c:\Users\kylej\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "c:\Users\kylej\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_13" is incompatible with the layer: expected shape=(None, 8), found shape=(None, 15)

# %%
# Make predictions from manual
manual_input = np.array([[1365889,2383139,3943193,6364119,6459881,3520279,1572135,859381,1734251,3039005,5108675,6392189,4980199,2559117,1249619
]])

# Calculate the column-wise min and max values from your original dataset
min_values = [74296, 1151721, 2379300, 2748695, 3681840, 1997402, 1742243, 942818, 392145, 795677, 1406647, 2482140, 2630495, 1748806, 1249297]
max_values = [1773075, 3755206, 7787954, 8401566, 8405071, 8401566, 7232265, 8185313, 2080604, 4455589, 8402979, 8405071, 8405071, 8403086, 6084492]

# Convert the lists to numpy arrays
min_values = np.array(min_values)
max_values = np.array(max_values)

# Normalize the manual input using the calculated min and max values
normalized_manual_input = (manual_input - min_values) / (max_values - min_values)
# normalized_manual_input = np.array([[0.85611,0.63202,0.53239,0.41068,0.59174,0.39869,0.44654,0.42188,0.8826042,0.67470967,0.34701898,0.42024683,0.34977269,0.16862726,0.1471771]])

print(normalized_manual_input)

predictions = model.predict(normalized_manual_input)
predicted_labels = np.argmax(predictions, axis=1)
predicted_plastic_types = label_encoder.inverse_transform(predicted_labels)

    
## Calculate the percentage likelihoods
percentage_likelihoods = predictions * 100

# Get the indices of the top 4 predicted classes based on percentage likelihoods
top_indices = np.argsort(percentage_likelihoods[0])[::-1][:4]

# Get the labels for the top predicted classes
top_labels = label_encoder.inverse_transform(top_indices)

# Get the predicted label
predicted_label = top_labels[0]

# Get the true label from the original data (replace with your true label)
true_label = 'ALU'  # Replace with the true label

# Calculate the accuracy
if predicted_label == true_label:
    accuracy = "Correct"
else:
    accuracy = "False"

# Print the prediction, label, and accuracy
print(f"Predicted label: {predicted_label}")
print(f"True label: {true_label}")
print(f"Accuracy: {accuracy}")

# Print the percentages for each type
for label, likelihood in zip(top_labels, percentage_likelihoods[0][top_indices]):
    print(f"{label}: {likelihood:.2f}% likelihood")
# Out:
# [[ 7.60306667e-01  4.72988321e-01  2.89146431e-01  6.39573059e-01
#    5.88165389e-01  2.37794816e-01 -3.09849396e-02 -1.15204774e-02
#    7.94870352e-01  6.12945885e-01  5.29138411e-01  6.60154407e-01
#    4.06905026e-01  1.21772904e-01  6.65950391e-05]]
# 1/1 [==============================] - 0s 26ms/step
# Predicted label: PP
# True label: ALU
# Accuracy: False
# PP: 99.97% likelihood
# PE: 0.03% likelihood
# PLA: 0.00% likelihood
# Other: 0.00% likelihood
