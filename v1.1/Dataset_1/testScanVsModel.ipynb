# %%
from tensorflow.keras.models import load_model
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import EarlyStopping

# Load the model
# model = load_model("15_point_plastic_classifier_model.keras")
# model = load_model("15_point_plastic_classifier_model_NewPPFAT.keras") # NewPPFAT is the best model so far
model = load_model("15_point_plastic_classifier_model_HvL.keras")

# %%
# data = pd.read_csv("AllTogether.csv")
# data = pd.read_csv("resampled_dataset.csv")
# data = pd.read_csv("resampled_datasetNewPP.csv")
data = pd.read_csv("HDPEvsLDPE.csv")

# Separate features and labels
X = data.drop(columns=["Material_Type"])
y = data["Material_Type"]

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into train and test sets (Normal)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=54)


# Normalize the manual input if needed
X_test_normalized = ((X_test - 0) / (8410000 - 0))
# X_test_normalized = (X_test - X_train.min()) / (X_train.max() - X_train.min())

# Make predictions
predictions = model.predict(X_test_normalized)
predicted_labels = np.argmax(predictions, axis=1)
predicted_plastic_types = label_encoder.inverse_transform(predicted_labels)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_normalized, y_test)

# Make predictions
predictions = model.predict(X_test_normalized)

# Get the top 4 predictions for each sample
top_predictions = np.argsort(predictions, axis=1)[:, -4:]
top_labels = top_predictions[:, ::-1]

# print(predictions)

# Reshape the top_labels array to be 1D
top_labels_1d = top_labels.reshape(-1)

# Inverse transform the labels
top_plastic_types = label_encoder.inverse_transform(top_labels_1d)

# Reshape the top_plastic_types array back to 2D
top_plastic_types = top_plastic_types.reshape(top_labels.shape)

# Get the percentage likelihoods for the top 4 predictions
percentage_likelihoods = np.take_along_axis(predictions, top_predictions, axis=1) * 100

# Display test accuracy and example predictions
print(f"Test Accuracy: {test_accuracy}")
for i in range(len(predicted_labels)):
    num_predictions = min(4, len(np.unique(top_labels[i])))
    if y_test[i] == predicted_labels[i]:
        CorF = "Correct,"
    else:
        CorF = "False,"
    print(f"Sample {i+1}: {CorF} it was {label_encoder.classes_[y_test[i]]}")
    for j in range(num_predictions):
        print(f"  Prediction {j+1}: {top_plastic_types[i][j]} with {percentage_likelihoods[i][1-j]:.2f}% likelihood")
# Out:
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 184ms/step - loss: 0.3680 - accuracy: 0.9231
# 1/1 [==============================] - 0s 27ms/step
# Test Accuracy: 0.9230769276618958
# Sample 1: Correct, it was HDPE
#   Prediction 1: HDPE with 96.19% likelihood
#   Prediction 2: LDPE with 3.81% likelihood
# Sample 2: Correct, it was LDPE
#   Prediction 1: LDPE with 98.84% likelihood
#   Prediction 2: HDPE with 1.16% likelihood
# Sample 3: Correct, it was LDPE
#   Prediction 1: LDPE with 95.52% likelihood
#   Prediction 2: HDPE with 4.48% likelihood
# Sample 4: Correct, it was LDPE
#   Prediction 1: LDPE with 97.61% likelihood
#   Prediction 2: HDPE with 2.39% likelihood
# Sample 5: Correct, it was HDPE
#   Prediction 1: HDPE with 75.19% likelihood
#   Prediction 2: LDPE with 24.81% likelihood
# Sample 6: False, it was HDPE
#   Prediction 1: LDPE with 98.71% likelihood
#   Prediction 2: HDPE with 1.29% likelihood
# Sample 7: Correct, it was HDPE
#   Prediction 1: HDPE with 99.97% likelihood
#   Prediction 2: LDPE with 0.03% likelihood
# Sample 8: Correct, it was LDPE
#   Prediction 1: LDPE with 99.56% likelihood
#   Prediction 2: HDPE with 0.44% likelihood
# Sample 9: False, it was LDPE
#   Prediction 1: HDPE with 94.26% likelihood
#   Prediction 2: LDPE with 5.74% likelihood
# Sample 10: Correct, it was LDPE
#   Prediction 1: LDPE with 88.11% likelihood
#   Prediction 2: HDPE with 11.89% likelihood
# Sample 11: Correct, it was HDPE
#   Prediction 1: HDPE with 88.30% likelihood
#   Prediction 2: LDPE with 11.70% likelihood
# Sample 12: Correct, it was LDPE
#   Prediction 1: LDPE with 99.62% likelihood
#   Prediction 2: HDPE with 0.38% likelihood
# Sample 13: Correct, it was LDPE
#   Prediction 1: LDPE with 55.91% likelihood
#   Prediction 2: HDPE with 44.09% likelihood
# Sample 14: Correct, it was HDPE
#   Prediction 1: HDPE with 99.70% likelihood
#   Prediction 2: LDPE with 0.30% likelihood
# Sample 15: Correct, it was HDPE
#   Prediction 1: HDPE with 80.45% likelihood
#   Prediction 2: LDPE with 19.55% likelihood
# Sample 16: Correct, it was HDPE
#   Prediction 1: HDPE with 99.96% likelihood
#   Prediction 2: LDPE with 0.04% likelihood
# Sample 17: Correct, it was HDPE
#   Prediction 1: HDPE with 99.19% likelihood
#   Prediction 2: LDPE with 0.81% likelihood
# Sample 18: Correct, it was LDPE
#   Prediction 1: LDPE with 97.70% likelihood
#   Prediction 2: HDPE with 2.30% likelihood
# Sample 19: Correct, it was HDPE
#   Prediction 1: HDPE with 98.92% likelihood
#   Prediction 2: LDPE with 1.08% likelihood
# Sample 20: Correct, it was HDPE
#   Prediction 1: HDPE with 100.00% likelihood
#   Prediction 2: LDPE with 0.00% likelihood
# Sample 21: Correct, it was LDPE
#   Prediction 1: LDPE with 85.12% likelihood
#   Prediction 2: HDPE with 14.88% likelihood
# Sample 22: Correct, it was HDPE
#   Prediction 1: HDPE with 72.30% likelihood
#   Prediction 2: LDPE with 27.70% likelihood
# Sample 23: Correct, it was LDPE
#   Prediction 1: LDPE with 90.86% likelihood
#   Prediction 2: HDPE with 9.14% likelihood
# Sample 24: Correct, it was HDPE
#   Prediction 1: HDPE with 99.69% likelihood
#   Prediction 2: LDPE with 0.31% likelihood
# Sample 25: Correct, it was HDPE
#   Prediction 1: HDPE with 76.55% likelihood
#   Prediction 2: LDPE with 23.45% likelihood
# Sample 26: Correct, it was HDPE
#   Prediction 1: HDPE with 100.00% likelihood
#   Prediction 2: LDPE with 0.00% likelihood

# %%
exclude_alu_indices = y != 'ALU'
X_filtered = X[exclude_alu_indices]
y_filtered = y_encoded[exclude_alu_indices]
# Split the filtered data into train and test sets (Filtered ALU)
X_train, X_test, y_train, y_test = train_test_split(X_filtered, y_filtered, test_size=0.2, random_state=50)
#features
X_test_normalized = ((X_test - 0) / (8410000 - 0))

# Make predictions
predictions = model.predict(X_test_normalized)
predicted_labels = np.argmax(predictions, axis=1)
predicted_plastic_types = label_encoder.inverse_transform(predicted_labels)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_normalized, y_test)

# Make predictions
predictions = model.predict(X_test_normalized)

# Get the top 4 predictions for each sample
top_predictions = np.argsort(predictions, axis=1)[:, -4:]
top_labels = top_predictions[:, ::-1]

# print(predictions)

# Reshape the top_labels array to be 1D
top_labels_1d = top_labels.reshape(-1)

# Inverse transform the labels
top_plastic_types = label_encoder.inverse_transform(top_labels_1d)

# Reshape the top_plastic_types array back to 2D
top_plastic_types = top_plastic_types.reshape(top_labels.shape)

# Get the percentage likelihoods for the top 4 predictions
percentage_likelihoods = np.take_along_axis(predictions, top_predictions, axis=1) * 100

# Display test accuracy and example predictions
print(f"Test Accuracy: {test_accuracy}")
for i in range(len(predicted_labels)):
    num_predictions = min(4, len(np.unique(top_labels[i])))
    if y_test[i] == predicted_labels[i]:
        CorF = "Correct,"
    else:
        CorF = "False,"
    print(f"Sample {i+1}: {CorF} it was {label_encoder.classes_[y_test[i]]}")
    for j in range(num_predictions):
        print(f"  Prediction {j+1}: {top_plastic_types[i][j]} with {percentage_likelihoods[i][3-j]:.2f}% likelihood")
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1530 - accuracy: 0.9231
# 1/1 [==============================] - 0s 21ms/step
# Test Accuracy: 0.9230769276618958
# Sample 1: Correct, it was HDPE
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\kylej\dev\plastic-scanner\v1.1\Dataset 1\testScanVsModel.ipynb Cell 3 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W2sZmlsZQ%3D%3D?line=45'>46</a> print(f"Sample {i+1}: {CorF} it was {label_encoder.classes_[y_test[i]]}")
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W2sZmlsZQ%3D%3D?line=46'>47</a> for j in range(num_predictions):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W2sZmlsZQ%3D%3D?line=47'>48</a>     print(f"  Prediction {j+1}: {top_plastic_types[i][j]} with {percentage_likelihoods[i][3-j]:.2f}% likelihood")
#
# IndexError: index 3 is out of bounds for axis 0 with size 2

# %%
# Get manual input from the user
manual_input = np.array([[1271389,2107581,3534859,5988057,6233631,3880377,1498541,985865,1561809,2707983,4719147,6111335,5063453,2701889,1262325]])  # Replace with your input values

# Normalize the manual input if needed
normalized_manual_input = ((manual_input - 0) / (8410000 - 0))

# Make predictions on manual input
predictions = model.predict(normalized_manual_input)
print(predictions)

# Get the top prediction
top_prediction = np.argmax(predictions)
print(top_prediction)

top_plastic_type = label_encoder.inverse_transform([top_prediction])[0]
print(top_plastic_type)
likelihood = predictions[0][top_prediction] * 100

# Display the prediction for manual input
print(f"Manual Input Prediction:")
print(f"  Prediction: {top_plastic_type} with {likelihood:.2f}% likelihood")
# Out:
# 1/1 [==============================] - 0s 56ms/step
# [[9.4345532e-14 2.6943423e-09 1.0437940e-02 2.1287291e-07 9.8956186e-01]]
# 4
# PP
# Manual Input Prediction:
#   Prediction: PP with 98.96% likelihood

# %%
import numpy as np  # Add this line to import the NumPy library
import serial
from sklearn.preprocessing import LabelEncoder


# Open the serial port
ser = serial.Serial('COM3', baudrate=115200)  # Adjust the baudrate as needed

# Initialize a variable to store the received data
received_data = ""

try:
    while True:
        # Read a line of data from the serial port (assuming data is sent as lines)
        line = ser.readline().decode('utf-8').strip()
        
        # Append the received line to the variable
        received_data += line

        # Split the received data into a list of numbers using a comma as the delimiter
        data_values = [float(val) for val in received_data.split(',')]

        # Convert the list of values into a NumPy array
        manual_input = np.array([data_values])

        # Normalize the manual input if needed
        normalized_manual_input = ((manual_input - 0) / (8410000 - 0))

        # Make predictions on manual input
        predictions = model.predict(normalized_manual_input)
        # print(predictions)

        # Get the top prediction
        top_prediction = np.argmax(predictions)
        print(top_prediction)

        top_plastic_type = label_encoder.inverse_transform([top_prediction])[0]
        print(top_plastic_type)
        likelihood = predictions[0][top_prediction] * 100

        # Display the prediction for manual input
        print(f"Manual Input Prediction:")
        print(f"  Prediction: {top_plastic_type} with {likelihood:.2f}% likelihood")

        received_data = ""

        # Send the top plastic type back over serial
        ser.write(top_plastic_type.encode('utf-8'))

except KeyboardInterrupt:
    # Handle Ctrl+C to stop the loop gracefully
    pass

finally:
    # Close the serial port when done
    ser.close()

# Now, you can use the 'received_data' variable for further processing
print("total data:\n", received_data)
# Out:
# 1/1 [==============================] - 0s 64ms/step
# 0
# HDPE
# Manual Input Prediction:
#   Prediction: HDPE with 61.97% likelihood
# 1/1 [==============================] - 0s 38ms/step
# 0
# HDPE
# Manual Input Prediction:
#   Prediction: HDPE with 100.00% likelihood
# 1/1 [==============================] - 0s 20ms/step
# 1
# LDPE
# Manual Input Prediction:
#   Prediction: LDPE with 71.80% likelihood
# 1/1 [==============================] - 0s 28ms/step
# 1
# LDPE
# Manual Input Prediction:
#   Prediction: LDPE with 95.70% likelihood
# 1/1 [==============================] - 0s 22ms/step
# 1
# LDPE
# Manual Input Prediction:
#   Prediction: LDPE with 98.91% likelihood
# 1/1 [==============================] - 0s 22ms/step
# 1
# LDPE
# Manual Input Prediction:
#   Prediction: LDPE with 95.27% likelihood
# 1/1 [==============================] - 0s 32ms/step
# 1
# LDPE
# Manual Input Prediction:
#   Prediction: LDPE with 58.41% likelihood
# 1/1 [==============================] - 0s 37ms/step
# 1
# LDPE
# Manual Input Prediction:
#   Prediction: LDPE with 57.76% likelihood
# 1/1 [==============================] - 0s 28ms/step
# 0
# HDPE
# Manual Input Prediction:
#   Prediction: HDPE with 100.00% likelihood
# 1/1 [==============================] - 0s 24ms/step
# 0
# HDPE
# Manual Input Prediction:
#   Prediction: HDPE with 77.86% likelihood
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# c:\Users\kylej\dev\plastic-scanner\v1.1\Dataset 1\testScanVsModel.ipynb Cell 5 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W4sZmlsZQ%3D%3D?line=11'>12</a> try:
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W4sZmlsZQ%3D%3D?line=12'>13</a>     while True:
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W4sZmlsZQ%3D%3D?line=13'>14</a>         # Read a line of data from the serial port (assuming data is sent as lines)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W4sZmlsZQ%3D%3D?line=14'>15</a>         line = ser.readline().decode('utf-8').strip()
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W4sZmlsZQ%3D%3D?line=16'>17</a>         # Append the received line to the variable
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W4sZmlsZQ%3D%3D?line=17'>18</a>         received_data += line
#
# File c:\Users\kylej\AppData\Local\Programs\Python\Python310\lib\site-packages\serial\serialwin32.py:295, in Serial.read(self, size)
#     293     if not result_ok:
#     294         if win32.GetLastError() != win32.ERROR_OPERATION_ABORTED:
# --> 295             raise SerialException("GetOverlappedResult failed ({!r})".format(ctypes.WinError()))
#     296     read = buf.raw[:rc.value]
#     297 else:
#
# SerialException: GetOverlappedResult failed (PermissionError(13, 'Access is denied.', None, 5))

# %%
import numpy as np
import serial
import csv  # Import the csv module
from sklearn.preprocessing import LabelEncoder

# Open the serial port
ser = serial.Serial('COM3', baudrate=115200)  # Adjust the baudrate as needed

# Create and open a CSV file for writing
csv_file = open('PP2.csv', 'w', newline='')
csv_writer = csv.writer(csv_file)

try:
    while True:
        # Read a line of data from the serial port (assuming data is sent as lines)
        line = ser.readline().decode('utf-8').strip()

        # Split the received data into a list of numbers using a comma as the delimiter
        data_values = [float(val) for val in line.split(',')]

        print(data_values)

        # Write the data values to the CSV file as a new row
        csv_writer.writerow(data_values)

except KeyboardInterrupt:
    # Handle Ctrl+C to stop the loop gracefully
    pass

finally:
    # Close the CSV file and the serial port when done
    csv_file.close()
    ser.close()

# The received data has been saved in the 'received_data.csv' file
print("Data saved to 'PP2.csv'")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\kylej\dev\plastic-scanner\v1.1\Dataset 1\testScanVsModel.ipynb Cell 6 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W5sZmlsZQ%3D%3D?line=15'>16</a> line = ser.readline().decode('utf-8').strip()
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W5sZmlsZQ%3D%3D?line=17'>18</a> # Split the received data into a list of numbers using a comma as the delimiter
# ---> <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W5sZmlsZQ%3D%3D?line=18'>19</a> data_values = [float(val) for val in line.split(',')]
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W5sZmlsZQ%3D%3D?line=20'>21</a> print(data_values)
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W5sZmlsZQ%3D%3D?line=22'>23</a> # Write the data values to the CSV file as a new row
#
# c:\Users\kylej\dev\plastic-scanner\v1.1\Dataset 1\testScanVsModel.ipynb Cell 6 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W5sZmlsZQ%3D%3D?line=15'>16</a> line = ser.readline().decode('utf-8').strip()
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W5sZmlsZQ%3D%3D?line=17'>18</a> # Split the received data into a list of numbers using a comma as the delimiter
# ---> <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W5sZmlsZQ%3D%3D?line=18'>19</a> data_values = [float(val) for val in line.split(',')]
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W5sZmlsZQ%3D%3D?line=20'>21</a> print(data_values)
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W5sZmlsZQ%3D%3D?line=22'>23</a> # Write the data values to the CSV file as a new row
#
# ValueError: could not convert string to float: 'Initialising LCD'
