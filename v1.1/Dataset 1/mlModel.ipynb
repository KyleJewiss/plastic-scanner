# %%
# import pandas as pd
# from imblearn.over_sampling import SMOTE
# from collections import Counter

# # Load your dataset here (replace 'your_dataset.csv' with your actual dataset file)
# # data = pd.read_csv('AllTogether.csv')
# data = pd.read_csv("AllTogetherNewPP.csv")

# # Assuming 'material_type' is the column that indicates the material type
# X = data.drop(columns=['Material_Type'])
# y = data['Material_Type']

# # Initialize SMOTE with the desired number of samples for each class (e.g., 100)
# desired_samples = 2000
# smote = SMOTE(sampling_strategy={material_type: desired_samples for material_type in y.unique()})

# # Apply SMOTE to the dataset
# X_resampled, y_resampled = smote.fit_resample(X, y)

# # Check the new class distribution
# print("Class distribution after SMOTE:", Counter(y_resampled))

# # Now you can use X_resampled and y_resampled as your balanced dataset

# # Create a new DataFrame with the resampled data
# resampled_data = pd.DataFrame(X_resampled, columns=X.columns)
# resampled_data['Material_Type'] = y_resampled

# # Save the resampled data to a CSV file
# resampled_data.to_csv('resampled_datasetNewPPFAT.csv', index=False)
# Out:
# Class distribution after SMOTE: Counter({'PE': 2000, 'ALU': 2000, 'PLA': 2000, 'Other': 2000, 'PP': 2000})

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import EarlyStopping

# Load the dataset
# data = pd.read_csv("AllTogether.csv")
data = pd.read_csv("resampled_datasetNewPPFAT.csv")


# Separate features and labels
X = data.drop(columns=["Material_Type"])
y = data["Material_Type"]

# %%
# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into train and test sets (Normal)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=22)

# # Normalize features
# X_train_normalized = (X_train - X_train.min()) / (X_train.max() - X_train.min())
# X_test_normalized = (X_test - X_train.min()) / (X_train.max() - X_train.min())
X_train_normalized = ((X_train - 0) / (8410000 - 0))
X_test_normalized = ((X_test - 0) / (8410000 - 0))

# Define the model architecture
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(256, activation="relu"),
    tf.keras.layers.Dense(256, activation="relu"),
    tf.keras.layers.Dense(len(label_encoder.classes_), activation="softmax")
])

# %%
# Compile the model
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# Define early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=10,          # Wait for 10 epochs without improvement
    min_delta=0.001,      # Minimum change required to consider an improvement
    verbose=1,            # Print messages about early stopping
    restore_best_weights=True
)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(X_train_normalized, y_train, epochs=500, batch_size=256, validation_split=0.2, callbacks=[early_stopping])
# history = model.fit(X_train_normalized, y_train, epochs=500, batch_size=128, validation_split=0.2)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_normalized, y_test)

# Save the model
# model.save("15_point_plastic_classifier_model.keras")
model.save("15_point_plastic_classifier_model_NewPP.keras")

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss')
plt.legend()
plt.show()

# Plot training and validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/500
# 3/3 [==============================] - 1s 127ms/step - loss: 1.5738 - accuracy: 0.2125 - val_loss: 1.5161 - val_accuracy: 0.2375
# Epoch 2/500
# 3/3 [==============================] - 0s 26ms/step - loss: 1.5045 - accuracy: 0.2406 - val_loss: 1.4635 - val_accuracy: 0.3000
# Epoch 3/500
# 3/3 [==============================] - 0s 21ms/step - loss: 1.4589 - accuracy: 0.3125 - val_loss: 1.4185 - val_accuracy: 0.4688
# Epoch 4/500
# 3/3 [==============================] - 0s 21ms/step - loss: 1.4180 - accuracy: 0.4891 - val_loss: 1.3751 - val_accuracy: 0.4875
# Epoch 5/500
# 3/3 [==============================] - 0s 18ms/step - loss: 1.3705 - accuracy: 0.5078 - val_loss: 1.3214 - val_accuracy: 0.5125
# Epoch 6/500
# 3/3 [==============================] - 0s 22ms/step - loss: 1.3201 - accuracy: 0.5234 - val_loss: 1.2687 - val_accuracy: 0.5250
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1866 - accuracy: 0.9594 - val_loss: 0.1753 - val_accuracy: 0.9250
# Epoch 162/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1906 - accuracy: 0.9391 - val_loss: 0.1741 - val_accuracy: 0.9500
# Epoch 163/500
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1830 - accuracy: 0.9406 - val_loss: 0.1691 - val_accuracy: 0.9625
# Epoch 164/500
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1817 - accuracy: 0.9594 - val_loss: 0.1635 - val_accuracy: 0.9438
# Epoch 165/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1821 - accuracy: 0.9375 - val_loss: 0.1731 - val_accuracy: 0.9625
# Epoch 166/500
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1765 - accuracy: 0.9625 - val_loss: 0.1677 - val_accuracy: 0.9312
# Epoch 167/500
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1809 - accuracy: 0.9297 - val_loss: 0.2244 - val_accuracy: 0.9062
# Epoch 168/500
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1958 - accuracy: 0.9203 - val_loss: 0.1825 - val_accuracy: 0.8938
# Epoch 169/500
# 3/3 [==============================] - 0s 48ms/step - loss: 0.1898 - accuracy: 0.9219 - val_loss: 0.1846 - val_accuracy: 0.9625
# Epoch 170/500
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1769 - accuracy: 0.9563 - val_loss: 0.1809 - val_accuracy: 0.8938
# Epoch 171/500
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1915 - accuracy: 0.9062 - val_loss: 0.2151 - val_accuracy: 0.9312
# Epoch 172/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1874 - accuracy: 0.9359 - val_loss: 0.1760 - val_accuracy: 0.9375
# Epoch 173/500
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1842 - accuracy: 0.9328 - val_loss: 0.1995 - val_accuracy: 0.9438
# Epoch 174/500
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1968 - accuracy: 0.9156 - val_loss: 0.1640 - val_accuracy: 0.9312
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1995 - accuracy: 0.9350

# %%
# Make predictions
predictions = model.predict(X_test_normalized)
predicted_labels = np.argmax(predictions, axis=1)
predicted_plastic_types = label_encoder.inverse_transform(predicted_labels)



# Convert predictions to percentage likelihood
percentage_likelihood = predictions.max(axis=1) * 100

# Display test accuracy and example predictions
print(f"Test Accuracy: {test_accuracy}")
for i in range(15):
    if y_test[i] == predicted_labels[i]:
        CorF = "Correct"
    else:
        CorF = "False"
    print(f"Sample {i+1}: {CorF} Predicted {predicted_plastic_types[i]} with {percentage_likelihood[i]:.2f}% likelihood")




total_params = model.count_params()
total_size_bytes = total_params * 4  # Each parameter is usually a 32-bit float
total_size_mb = total_size_bytes / (1024)  # Convert bytes to megabytes

print(f"Total size of the model: {total_size_mb:.2f} KB")
# Out:
# 7/7 [==============================] - 0s 1ms/step
# Test Accuracy: 0.9350000023841858
# Sample 1: Correct Predicted PP with 64.61% likelihood
# Sample 2: Correct Predicted Other with 99.57% likelihood
# Sample 3: Correct Predicted PLA with 95.28% likelihood
# Sample 4: Correct Predicted PE with 56.74% likelihood
# Sample 5: Correct Predicted ALU with 99.91% likelihood
# Sample 6: Correct Predicted ALU with 99.14% likelihood
# Sample 7: Correct Predicted ALU with 99.84% likelihood
# Sample 8: Correct Predicted PP with 82.66% likelihood
# Sample 9: Correct Predicted PP with 82.08% likelihood
# Sample 10: Correct Predicted PP with 77.64% likelihood
# Sample 11: False Predicted PP with 60.76% likelihood
# Sample 12: Correct Predicted PP with 85.86% likelihood
# Sample 13: Correct Predicted PE with 74.69% likelihood
# Sample 14: Correct Predicted Other with 90.49% likelihood
# Sample 15: Correct Predicted Other with 99.93% likelihood
# Total size of the model: 278.02 KB

# %%
# Make predictions
predictions = model.predict(X_test_normalized)

# Get the top 4 predictions for each sample
top_predictions = np.argsort(predictions, axis=1)[:, -4:]
top_labels = top_predictions[:, ::-1]

# print(predictions)

# Reshape the top_labels array to be 1D
top_labels_1d = top_labels.reshape(-1)

# Inverse transform the labels
top_plastic_types = label_encoder.inverse_transform(top_labels_1d)

# Reshape the top_plastic_types array back to 2D
top_plastic_types = top_plastic_types.reshape(top_labels.shape)

# Get the percentage likelihoods for the top 4 predictions
percentage_likelihoods = np.take_along_axis(predictions, top_predictions, axis=1) * 100

# Display test accuracy and example predictions
print(f"Test Accuracy: {test_accuracy}")
for i in range(len(predicted_labels)):
    num_predictions = min(4, len(np.unique(top_labels[i])))
    if y_test[i] == predicted_labels[i]:
        CorF = "Correct,"
    else:
        CorF = "False,"
    print(f"Sample {i+1}: {CorF} it was {label_encoder.classes_[y_test[i]]}")
    for j in range(num_predictions):
        print(f"  Prediction {j+1}: {top_plastic_types[i][j]} with {percentage_likelihoods[i][3-j]:.2f}% likelihood")
# Out:
# 1/7 [===>..........................] - ETA: 0s
# 7/7 [==============================] - 0s 2ms/step
# Test Accuracy: 0.9350000023841858
# Sample 1: Correct, it was PP
#   Prediction 1: PP with 64.61% likelihood
#   Prediction 2: PE with 35.30% likelihood
#   Prediction 3: PLA with 0.06% likelihood
#   Prediction 4: Other with 0.03% likelihood
# Sample 2: Correct, it was Other
#   Prediction 1: Other with 99.57% likelihood
#   Prediction 2: ALU with 0.29% likelihood
#   Prediction 3: PE with 0.13% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 3: Correct, it was PLA
#   Prediction 1: PLA with 95.28% likelihood
#   Prediction 2: PE with 4.47% likelihood
#   Prediction 3: Other with 0.25% likelihood
#   Prediction 4: PP with 0.01% likelihood
# Sample 4: Correct, it was PE
#   Prediction 1: PE with 56.74% likelihood
#   Prediction 2: PP with 41.80% likelihood
#   Prediction 3: PLA with 1.35% likelihood
#   Prediction 4: Other with 0.11% likelihood
# Sample 5: Correct, it was ALU
#   Prediction 1: ALU with 99.91% likelihood
#   Prediction 2: Other with 0.09% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 6: Correct, it was ALU
#   Prediction 1: ALU with 99.14% likelihood
#   Prediction 2: Other with 0.86% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 7: Correct, it was ALU
#   Prediction 1: ALU with 99.84% likelihood
#   Prediction 2: Other with 0.16% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 8: Correct, it was PP
#   Prediction 1: PP with 82.66% likelihood
#   Prediction 2: PE with 16.78% likelihood
#   Prediction 3: PLA with 0.53% likelihood
#   Prediction 4: Other with 0.03% likelihood
# Sample 9: Correct, it was PP
#   Prediction 1: PP with 82.08% likelihood
#   Prediction 2: PE with 17.55% likelihood
#   Prediction 3: PLA with 0.35% likelihood
#   Prediction 4: Other with 0.03% likelihood
# Sample 10: Correct, it was PP
#   Prediction 1: PP with 77.64% likelihood
#   Prediction 2: PE with 21.57% likelihood
#   Prediction 3: PLA with 0.75% likelihood
#   Prediction 4: Other with 0.03% likelihood
# Sample 11: False, it was PE
#   Prediction 1: PP with 60.76% likelihood
#   Prediction 2: PE with 38.99% likelihood
#   Prediction 3: PLA with 0.20% likelihood
#   Prediction 4: Other with 0.04% likelihood
# Sample 12: Correct, it was PP
#   Prediction 1: PP with 85.86% likelihood
#   Prediction 2: PE with 13.97% likelihood
#   Prediction 3: PLA with 0.16% likelihood
#   Prediction 4: Other with 0.02% likelihood
# Sample 13: Correct, it was PE
#   Prediction 1: PE with 74.69% likelihood
#   Prediction 2: PP with 22.83% likelihood
#   Prediction 3: PLA with 2.18% likelihood
#   Prediction 4: Other with 0.31% likelihood
# Sample 14: Correct, it was Other
#   Prediction 1: Other with 90.49% likelihood
#   Prediction 2: PE with 9.50% likelihood
#   Prediction 3: PLA with 0.01% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 15: Correct, it was Other
#   Prediction 1: Other with 99.93% likelihood
#   Prediction 2: PE with 0.07% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 16: Correct, it was PE
#   Prediction 1: PE with 86.05% likelihood
#   Prediction 2: PP with 13.82% likelihood
#   Prediction 3: Other with 0.10% likelihood
#   Prediction 4: PLA with 0.02% likelihood
# Sample 17: Correct, it was ALU
#   Prediction 1: ALU with 99.89% likelihood
#   Prediction 2: Other with 0.11% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 18: Correct, it was PP
#   Prediction 1: PP with 72.08% likelihood
#   Prediction 2: PE with 26.27% likelihood
#   Prediction 3: PLA with 1.59% likelihood
#   Prediction 4: Other with 0.06% likelihood
# Sample 19: Correct, it was ALU
#   Prediction 1: ALU with 99.48% likelihood
#   Prediction 2: Other with 0.52% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 20: Correct, it was ALU
#   Prediction 1: ALU with 99.92% likelihood
#   Prediction 2: Other with 0.08% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 21: Correct, it was ALU
#   Prediction 1: ALU with 99.89% likelihood
#   Prediction 2: Other with 0.11% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 22: Correct, it was PLA
#   Prediction 1: PLA with 95.93% likelihood
#   Prediction 2: PE with 3.91% likelihood
#   Prediction 3: Other with 0.12% likelihood
#   Prediction 4: PP with 0.04% likelihood
# Sample 23: Correct, it was ALU
#   Prediction 1: ALU with 99.37% likelihood
#   Prediction 2: Other with 0.63% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 24: Correct, it was PE
#   Prediction 1: PE with 70.84% likelihood
#   Prediction 2: PP with 26.06% likelihood
#   Prediction 3: PLA with 2.88% likelihood
#   Prediction 4: Other with 0.21% likelihood
# Sample 25: Correct, it was PE
#   Prediction 1: PE with 96.19% likelihood
#   Prediction 2: Other with 3.77% likelihood
#   Prediction 3: ALU with 0.02% likelihood
#   Prediction 4: PP with 0.01% likelihood
# Sample 26: Correct, it was PP
#   Prediction 1: PP with 88.00% likelihood
#   Prediction 2: PE with 11.86% likelihood
#   Prediction 3: PLA with 0.13% likelihood
#   Prediction 4: Other with 0.01% likelihood
# Sample 27: Correct, it was PP
#   Prediction 1: PP with 64.63% likelihood
#   Prediction 2: PE with 35.30% likelihood
#   Prediction 3: PLA with 0.04% likelihood
#   Prediction 4: Other with 0.02% likelihood
# Sample 28: Correct, it was ALU
#   Prediction 1: ALU with 99.15% likelihood
#   Prediction 2: Other with 0.85% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 29: Correct, it was ALU
#   Prediction 1: ALU with 99.92% likelihood
#   Prediction 2: Other with 0.08% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 30: Correct, it was ALU
#   Prediction 1: ALU with 99.92% likelihood
#   Prediction 2: Other with 0.08% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 31: Correct, it was Other
#   Prediction 1: Other with 99.94% likelihood
#   Prediction 2: PE with 0.06% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 32: Correct, it was PP
#   Prediction 1: PP with 85.28% likelihood
#   Prediction 2: PE with 14.51% likelihood
#   Prediction 3: PLA with 0.19% likelihood
#   Prediction 4: Other with 0.01% likelihood
# Sample 33: Correct, it was PE
#   Prediction 1: PE with 81.42% likelihood
#   Prediction 2: Other with 18.55% likelihood
#   Prediction 3: PP with 0.02% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 34: Correct, it was PP
#   Prediction 1: PP with 81.92% likelihood
#   Prediction 2: PE with 18.00% likelihood
#   Prediction 3: PLA with 0.07% likelihood
#   Prediction 4: Other with 0.01% likelihood
# Sample 35: Correct, it was Other
#   Prediction 1: Other with 99.94% likelihood
#   Prediction 2: PE with 0.06% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 36: False, it was PE
#   Prediction 1: PP with 69.95% likelihood
#   Prediction 2: PE with 29.79% likelihood
#   Prediction 3: PLA with 0.23% likelihood
#   Prediction 4: Other with 0.03% likelihood
# Sample 37: Correct, it was ALU
#   Prediction 1: ALU with 99.88% likelihood
#   Prediction 2: Other with 0.12% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 38: Correct, it was PP
#   Prediction 1: PP with 84.72% likelihood
#   Prediction 2: PE with 15.20% likelihood
#   Prediction 3: PLA with 0.07% likelihood
#   Prediction 4: Other with 0.01% likelihood
# Sample 39: Correct, it was PLA
#   Prediction 1: PLA with 96.89% likelihood
#   Prediction 2: PE with 2.96% likelihood
#   Prediction 3: PP with 0.10% likelihood
#   Prediction 4: Other with 0.06% likelihood
# Sample 40: Correct, it was Other
#   Prediction 1: Other with 99.97% likelihood
#   Prediction 2: PE with 0.03% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 41: Correct, it was Other
#   Prediction 1: Other with 98.30% likelihood
#   Prediction 2: PE with 1.23% likelihood
#   Prediction 3: PLA with 0.39% likelihood
#   Prediction 4: ALU with 0.08% likelihood
# Sample 42: Correct, it was Other
#   Prediction 1: Other with 99.95% likelihood
#   Prediction 2: PE with 0.05% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 43: Correct, it was PE
#   Prediction 1: PE with 50.57% likelihood
#   Prediction 2: PP with 49.04% likelihood
#   Prediction 3: PLA with 0.33% likelihood
#   Prediction 4: Other with 0.07% likelihood
# Sample 44: Correct, it was PP
#   Prediction 1: PP with 86.26% likelihood
#   Prediction 2: PE with 13.53% likelihood
#   Prediction 3: PLA with 0.20% likelihood
#   Prediction 4: Other with 0.01% likelihood
# Sample 45: Correct, it was ALU
#   Prediction 1: ALU with 99.93% likelihood
#   Prediction 2: Other with 0.07% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 46: Correct, it was Other
#   Prediction 1: Other with 98.70% likelihood
#   Prediction 2: ALU with 1.26% likelihood
#   Prediction 3: PE with 0.04% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 47: Correct, it was PP
#   Prediction 1: PP with 68.91% likelihood
#   Prediction 2: PE with 31.01% likelihood
#   Prediction 3: PLA with 0.05% likelihood
#   Prediction 4: Other with 0.02% likelihood
# Sample 48: Correct, it was Other
#   Prediction 1: Other with 99.94% likelihood
#   Prediction 2: PE with 0.06% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 49: Correct, it was PP
#   Prediction 1: PP with 88.24% likelihood
#   Prediction 2: PE with 11.56% likelihood
#   Prediction 3: PLA with 0.19% likelihood
#   Prediction 4: Other with 0.01% likelihood
# Sample 50: False, it was PE
#   Prediction 1: PP with 61.61% likelihood
#   Prediction 2: PE with 38.18% likelihood
#   Prediction 3: PLA with 0.17% likelihood
#   Prediction 4: Other with 0.04% likelihood
# Sample 51: Correct, it was ALU
#   Prediction 1: ALU with 99.47% likelihood
#   Prediction 2: Other with 0.53% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 52: Correct, it was ALU
#   Prediction 1: ALU with 98.96% likelihood
#   Prediction 2: Other with 1.04% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 53: Correct, it was PP
#   Prediction 1: PP with 81.23% likelihood
#   Prediction 2: PE with 18.45% likelihood
#   Prediction 3: PLA with 0.29% likelihood
#   Prediction 4: Other with 0.02% likelihood
# Sample 54: Correct, it was PP
#   Prediction 1: PP with 85.17% likelihood
#   Prediction 2: PE with 14.54% likelihood
#   Prediction 3: PLA with 0.27% likelihood
#   Prediction 4: Other with 0.01% likelihood
# Sample 55: Correct, it was Other
#   Prediction 1: Other with 99.81% likelihood
#   Prediction 2: ALU with 0.11% likelihood
#   Prediction 3: PLA with 0.07% likelihood
#   Prediction 4: PE with 0.01% likelihood
# Sample 56: Correct, it was Other
#   Prediction 1: Other with 99.93% likelihood
#   Prediction 2: PE with 0.07% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 57: Correct, it was PE
#   Prediction 1: PE with 62.79% likelihood
#   Prediction 2: PP with 36.87% likelihood
#   Prediction 3: PLA with 0.25% likelihood
#   Prediction 4: Other with 0.09% likelihood
# Sample 58: Correct, it was PE
#   Prediction 1: PE with 99.10% likelihood
#   Prediction 2: Other with 0.71% likelihood
#   Prediction 3: PP with 0.18% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 59: Correct, it was PP
#   Prediction 1: PP with 83.65% likelihood
#   Prediction 2: PE with 16.09% likelihood
#   Prediction 3: PLA with 0.24% likelihood
#   Prediction 4: Other with 0.02% likelihood
# Sample 60: Correct, it was PE
#   Prediction 1: PE with 77.79% likelihood
#   Prediction 2: PP with 20.33% likelihood
#   Prediction 3: PLA with 1.77% likelihood
#   Prediction 4: Other with 0.11% likelihood
# Sample 61: Correct, it was PE
#   Prediction 1: PE with 67.45% likelihood
#   Prediction 2: PP with 32.36% likelihood
#   Prediction 3: PLA with 0.11% likelihood
#   Prediction 4: Other with 0.07% likelihood
# Sample 62: Correct, it was PP
#   Prediction 1: PP with 82.10% likelihood
#   Prediction 2: PE with 17.81% likelihood
#   Prediction 3: PLA with 0.07% likelihood
#   Prediction 4: Other with 0.01% likelihood
# Sample 63: Correct, it was PP
#   Prediction 1: PP with 78.80% likelihood
#   Prediction 2: PE with 21.07% likelihood
#   Prediction 3: PLA with 0.11% likelihood
#   Prediction 4: Other with 0.02% likelihood
# Sample 64: Correct, it was PE
#   Prediction 1: PE with 97.41% likelihood
#   Prediction 2: PP with 1.42% likelihood
#   Prediction 3: Other with 1.14% likelihood
#   Prediction 4: PLA with 0.03% likelihood
# Sample 65: Correct, it was PP
#   Prediction 1: PP with 80.69% likelihood
#   Prediction 2: PE with 19.02% likelihood
#   Prediction 3: PLA with 0.27% likelihood
#   Prediction 4: Other with 0.02% likelihood
# Sample 66: Correct, it was PP
#   Prediction 1: PP with 69.07% likelihood
#   Prediction 2: PE with 30.55% likelihood
#   Prediction 3: PLA with 0.35% likelihood
#   Prediction 4: Other with 0.03% likelihood
# Sample 67: Correct, it was PLA
#   Prediction 1: PLA with 99.37% likelihood
#   Prediction 2: PE with 0.59% likelihood
#   Prediction 3: Other with 0.02% likelihood
#   Prediction 4: PP with 0.02% likelihood
# Sample 68: Correct, it was Other
#   Prediction 1: Other with 99.94% likelihood
#   Prediction 2: PE with 0.06% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 69: Correct, it was Other
#   Prediction 1: Other with 98.93% likelihood
#   Prediction 2: PLA with 0.60% likelihood
#   Prediction 3: PE with 0.47% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 70: Correct, it was PLA
#   Prediction 1: PLA with 89.63% likelihood
#   Prediction 2: PE with 8.59% likelihood
#   Prediction 3: PP with 1.59% likelihood
#   Prediction 4: Other with 0.19% likelihood
# Sample 71: Correct, it was ALU
#   Prediction 1: ALU with 99.92% likelihood
#   Prediction 2: Other with 0.08% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 72: False, it was PLA
#   Prediction 1: PE with 61.21% likelihood
#   Prediction 2: PLA with 37.40% likelihood
#   Prediction 3: Other with 1.15% likelihood
#   Prediction 4: PP with 0.23% likelihood
# Sample 73: Correct, it was PLA
#   Prediction 1: PLA with 94.12% likelihood
#   Prediction 2: PE with 5.43% likelihood
#   Prediction 3: Other with 0.45% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 74: Correct, it was PLA
#   Prediction 1: PLA with 98.52% likelihood
#   Prediction 2: PE with 1.35% likelihood
#   Prediction 3: PP with 0.10% likelihood
#   Prediction 4: Other with 0.03% likelihood
# Sample 75: Correct, it was ALU
#   Prediction 1: ALU with 99.84% likelihood
#   Prediction 2: Other with 0.16% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 76: Correct, it was PP
#   Prediction 1: PP with 80.55% likelihood
#   Prediction 2: PE with 19.25% likelihood
#   Prediction 3: PLA with 0.18% likelihood
#   Prediction 4: Other with 0.02% likelihood
# Sample 77: Correct, it was Other
#   Prediction 1: Other with 99.94% likelihood
#   Prediction 2: PE with 0.06% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 78: Correct, it was PLA
#   Prediction 1: PLA with 94.69% likelihood
#   Prediction 2: PE with 4.85% likelihood
#   Prediction 3: Other with 0.41% likelihood
#   Prediction 4: PP with 0.05% likelihood
# Sample 79: Correct, it was ALU
#   Prediction 1: ALU with 99.92% likelihood
#   Prediction 2: Other with 0.08% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 80: Correct, it was PE
#   Prediction 1: PE with 97.18% likelihood
#   Prediction 2: Other with 2.78% likelihood
#   Prediction 3: PP with 0.02% likelihood
#   Prediction 4: ALU with 0.02% likelihood
# Sample 81: Correct, it was PLA
#   Prediction 1: PLA with 94.36% likelihood
#   Prediction 2: PE with 5.20% likelihood
#   Prediction 3: Other with 0.38% likelihood
#   Prediction 4: PP with 0.07% likelihood
# Sample 82: Correct, it was PLA
#   Prediction 1: PLA with 99.55% likelihood
#   Prediction 2: PE with 0.33% likelihood
#   Prediction 3: Other with 0.11% likelihood
#   Prediction 4: PP with 0.01% likelihood
# Sample 83: Correct, it was ALU
#   Prediction 1: ALU with 99.91% likelihood
#   Prediction 2: Other with 0.09% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 84: Correct, it was Other
#   Prediction 1: Other with 98.91% likelihood
#   Prediction 2: PLA with 0.71% likelihood
#   Prediction 3: PE with 0.37% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 85: Correct, it was PP
#   Prediction 1: PP with 77.93% likelihood
#   Prediction 2: PE with 20.99% likelihood
#   Prediction 3: PLA with 1.04% likelihood
#   Prediction 4: Other with 0.04% likelihood
# Sample 86: Correct, it was ALU
#   Prediction 1: ALU with 99.93% likelihood
#   Prediction 2: Other with 0.07% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 87: Correct, it was PLA
#   Prediction 1: PLA with 91.94% likelihood
#   Prediction 2: PE with 7.65% likelihood
#   Prediction 3: PP with 0.26% likelihood
#   Prediction 4: Other with 0.15% likelihood
# Sample 88: Correct, it was ALU
#   Prediction 1: ALU with 99.91% likelihood
#   Prediction 2: Other with 0.09% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 89: Correct, it was PE
#   Prediction 1: PE with 96.46% likelihood
#   Prediction 2: PP with 3.37% likelihood
#   Prediction 3: Other with 0.17% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 90: Correct, it was PLA
#   Prediction 1: PLA with 88.34% likelihood
#   Prediction 2: PE with 10.42% likelihood
#   Prediction 3: Other with 0.81% likelihood
#   Prediction 4: PP with 0.42% likelihood
# Sample 91: Correct, it was Other
#   Prediction 1: Other with 94.31% likelihood
#   Prediction 2: PE with 5.67% likelihood
#   Prediction 3: PLA with 0.02% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 92: Correct, it was PP
#   Prediction 1: PP with 58.43% likelihood
#   Prediction 2: PE with 41.49% likelihood
#   Prediction 3: PLA with 0.05% likelihood
#   Prediction 4: Other with 0.03% likelihood
# Sample 93: False, it was PE
#   Prediction 1: PP with 50.87% likelihood
#   Prediction 2: PE with 46.85% likelihood
#   Prediction 3: PLA with 2.18% likelihood
#   Prediction 4: Other with 0.10% likelihood
# Sample 94: Correct, it was PLA
#   Prediction 1: PLA with 85.65% likelihood
#   Prediction 2: PE with 12.88% likelihood
#   Prediction 3: Other with 0.74% likelihood
#   Prediction 4: PP with 0.73% likelihood
# Sample 95: Correct, it was Other
#   Prediction 1: Other with 90.45% likelihood
#   Prediction 2: PE with 9.54% likelihood
#   Prediction 3: PLA with 0.01% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 96: False, it was Other
#   Prediction 1: PLA with 68.94% likelihood
#   Prediction 2: Other with 20.30% likelihood
#   Prediction 3: PE with 10.76% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 97: Correct, it was PP
#   Prediction 1: PP with 85.66% likelihood
#   Prediction 2: PE with 14.20% likelihood
#   Prediction 3: PLA with 0.12% likelihood
#   Prediction 4: Other with 0.01% likelihood
# Sample 98: Correct, it was ALU
#   Prediction 1: ALU with 99.57% likelihood
#   Prediction 2: Other with 0.43% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 99: Correct, it was ALU
#   Prediction 1: ALU with 99.93% likelihood
#   Prediction 2: Other with 0.07% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 100: Correct, it was PLA
#   Prediction 1: PLA with 92.38% likelihood
#   Prediction 2: PE with 6.71% likelihood
#   Prediction 3: PP with 0.49% likelihood
#   Prediction 4: Other with 0.42% likelihood
# Sample 101: Correct, it was Other
#   Prediction 1: Other with 96.57% likelihood
#   Prediction 2: PE with 3.43% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 102: Correct, it was ALU
#   Prediction 1: ALU with 99.19% likelihood
#   Prediction 2: Other with 0.81% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 103: Correct, it was PP
#   Prediction 1: PP with 64.90% likelihood
#   Prediction 2: PE with 35.01% likelihood
#   Prediction 3: PLA with 0.06% likelihood
#   Prediction 4: Other with 0.02% likelihood
# Sample 104: Correct, it was Other
#   Prediction 1: Other with 97.76% likelihood
#   Prediction 2: ALU with 2.24% likelihood
#   Prediction 3: PE with 0.01% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 105: Correct, it was PLA
#   Prediction 1: PLA with 71.26% likelihood
#   Prediction 2: PE with 16.08% likelihood
#   Prediction 3: Other with 12.65% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 106: Correct, it was Other
#   Prediction 1: Other with 99.74% likelihood
#   Prediction 2: PE with 0.26% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 107: Correct, it was PP
#   Prediction 1: PP with 69.51% likelihood
#   Prediction 2: PE with 30.25% likelihood
#   Prediction 3: PLA with 0.22% likelihood
#   Prediction 4: Other with 0.03% likelihood
# Sample 108: Correct, it was ALU
#   Prediction 1: ALU with 99.92% likelihood
#   Prediction 2: Other with 0.08% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 109: Correct, it was Other
#   Prediction 1: Other with 99.70% likelihood
#   Prediction 2: PE with 0.30% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 110: Correct, it was PLA
#   Prediction 1: PLA with 90.57% likelihood
#   Prediction 2: PE with 8.91% likelihood
#   Prediction 3: PP with 0.41% likelihood
#   Prediction 4: Other with 0.11% likelihood
# Sample 111: Correct, it was PLA
#   Prediction 1: PLA with 94.21% likelihood
#   Prediction 2: PE with 5.47% likelihood
#   Prediction 3: PP with 0.19% likelihood
#   Prediction 4: Other with 0.12% likelihood
# Sample 112: Correct, it was ALU
#   Prediction 1: ALU with 99.85% likelihood
#   Prediction 2: Other with 0.15% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 113: Correct, it was PLA
#   Prediction 1: PLA with 99.02% likelihood
#   Prediction 2: PE with 0.91% likelihood
#   Prediction 3: PP with 0.03% likelihood
#   Prediction 4: Other with 0.03% likelihood
# Sample 114: Correct, it was PLA
#   Prediction 1: PLA with 87.82% likelihood
#   Prediction 2: PE with 10.43% likelihood
#   Prediction 3: Other with 1.74% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 115: Correct, it was PLA
#   Prediction 1: PLA with 99.56% likelihood
#   Prediction 2: PE with 0.29% likelihood
#   Prediction 3: Other with 0.15% likelihood
#   Prediction 4: PP with 0.01% likelihood
# Sample 116: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 117: Correct, it was Other
#   Prediction 1: Other with 99.85% likelihood
#   Prediction 2: PE with 0.15% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 118: Correct, it was ALU
#   Prediction 1: ALU with 99.04% likelihood
#   Prediction 2: Other with 0.96% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 119: Correct, it was PP
#   Prediction 1: PP with 71.05% likelihood
#   Prediction 2: PE with 28.88% likelihood
#   Prediction 3: PLA with 0.04% likelihood
#   Prediction 4: Other with 0.02% likelihood
# Sample 120: Correct, it was PE
#   Prediction 1: PE with 82.92% likelihood
#   Prediction 2: PP with 13.64% likelihood
#   Prediction 3: PLA with 2.87% likelihood
#   Prediction 4: Other with 0.57% likelihood
# Sample 121: Correct, it was PE
#   Prediction 1: PE with 67.21% likelihood
#   Prediction 2: PP with 32.54% likelihood
#   Prediction 3: PLA with 0.17% likelihood
#   Prediction 4: Other with 0.08% likelihood
# Sample 122: Correct, it was PE
#   Prediction 1: PE with 71.23% likelihood
#   Prediction 2: PP with 28.16% likelihood
#   Prediction 3: Other with 0.31% likelihood
#   Prediction 4: PLA with 0.29% likelihood
# Sample 123: Correct, it was PP
#   Prediction 1: PP with 71.18% likelihood
#   Prediction 2: PE with 28.75% likelihood
#   Prediction 3: PLA with 0.05% likelihood
#   Prediction 4: Other with 0.02% likelihood
# Sample 124: Correct, it was PP
#   Prediction 1: PP with 79.72% likelihood
#   Prediction 2: PE with 20.09% likelihood
#   Prediction 3: PLA with 0.17% likelihood
#   Prediction 4: Other with 0.02% likelihood
# Sample 125: Correct, it was PP
#   Prediction 1: PP with 86.15% likelihood
#   Prediction 2: PE with 13.73% likelihood
#   Prediction 3: PLA with 0.11% likelihood
#   Prediction 4: Other with 0.01% likelihood
# Sample 126: False, it was PLA
#   Prediction 1: PE with 56.81% likelihood
#   Prediction 2: PLA with 36.14% likelihood
#   Prediction 3: Other with 3.85% likelihood
#   Prediction 4: PP with 3.20% likelihood
# Sample 127: Correct, it was PP
#   Prediction 1: PP with 84.16% likelihood
#   Prediction 2: PE with 15.75% likelihood
#   Prediction 3: PLA with 0.08% likelihood
#   Prediction 4: Other with 0.01% likelihood
# Sample 128: Correct, it was Other
#   Prediction 1: Other with 99.94% likelihood
#   Prediction 2: PE with 0.06% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 129: Correct, it was PP
#   Prediction 1: PP with 77.49% likelihood
#   Prediction 2: PE with 22.19% likelihood
#   Prediction 3: PLA with 0.30% likelihood
#   Prediction 4: Other with 0.02% likelihood
# Sample 130: Correct, it was Other
#   Prediction 1: Other with 98.73% likelihood
#   Prediction 2: PLA with 0.94% likelihood
#   Prediction 3: PE with 0.32% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 131: Correct, it was ALU
#   Prediction 1: ALU with 99.90% likelihood
#   Prediction 2: Other with 0.10% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 132: False, it was PE
#   Prediction 1: PP with 62.78% likelihood
#   Prediction 2: PE with 36.36% likelihood
#   Prediction 3: PLA with 0.79% likelihood
#   Prediction 4: Other with 0.07% likelihood
# Sample 133: Correct, it was ALU
#   Prediction 1: ALU with 99.93% likelihood
#   Prediction 2: Other with 0.07% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 134: Correct, it was PLA
#   Prediction 1: PLA with 99.36% likelihood
#   Prediction 2: PE with 0.52% likelihood
#   Prediction 3: Other with 0.10% likelihood
#   Prediction 4: PP with 0.02% likelihood
# Sample 135: Correct, it was PP
#   Prediction 1: PP with 62.87% likelihood
#   Prediction 2: PE with 37.06% likelihood
#   Prediction 3: PLA with 0.05% likelihood
#   Prediction 4: Other with 0.03% likelihood
# Sample 136: Correct, it was PE
#   Prediction 1: PE with 50.86% likelihood
#   Prediction 2: PP with 48.83% likelihood
#   Prediction 3: PLA with 0.26% likelihood
#   Prediction 4: Other with 0.06% likelihood
# Sample 137: False, it was PE
#   Prediction 1: PP with 52.54% likelihood
#   Prediction 2: PE with 45.90% likelihood
#   Prediction 3: PLA with 1.48% likelihood
#   Prediction 4: Other with 0.08% likelihood
# Sample 138: Correct, it was PLA
#   Prediction 1: PLA with 97.05% likelihood
#   Prediction 2: PE with 2.60% likelihood
#   Prediction 3: PP with 0.31% likelihood
#   Prediction 4: Other with 0.03% likelihood
# Sample 139: Correct, it was Other
#   Prediction 1: Other with 99.89% likelihood
#   Prediction 2: PE with 0.11% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 140: Correct, it was ALU
#   Prediction 1: ALU with 99.92% likelihood
#   Prediction 2: Other with 0.08% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 141: Correct, it was PP
#   Prediction 1: PP with 58.80% likelihood
#   Prediction 2: PE with 41.12% likelihood
#   Prediction 3: PLA with 0.05% likelihood
#   Prediction 4: Other with 0.03% likelihood
# Sample 142: Correct, it was PP
#   Prediction 1: PP with 71.57% likelihood
#   Prediction 2: PE with 28.14% likelihood
#   Prediction 3: PLA with 0.26% likelihood
#   Prediction 4: Other with 0.03% likelihood
# Sample 143: Correct, it was PLA
#   Prediction 1: PLA with 96.87% likelihood
#   Prediction 2: PE with 2.79% likelihood
#   Prediction 3: PP with 0.30% likelihood
#   Prediction 4: Other with 0.04% likelihood
# Sample 144: Correct, it was PE
#   Prediction 1: PE with 61.07% likelihood
#   Prediction 2: PP with 38.77% likelihood
#   Prediction 3: PLA with 0.11% likelihood
#   Prediction 4: Other with 0.06% likelihood
# Sample 145: Correct, it was PE
#   Prediction 1: PE with 82.26% likelihood
#   Prediction 2: PP with 17.14% likelihood
#   Prediction 3: Other with 0.39% likelihood
#   Prediction 4: PLA with 0.21% likelihood
# Sample 146: Correct, it was ALU
#   Prediction 1: ALU with 99.91% likelihood
#   Prediction 2: Other with 0.09% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 147: Correct, it was ALU
#   Prediction 1: ALU with 99.91% likelihood
#   Prediction 2: Other with 0.09% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 148: Correct, it was ALU
#   Prediction 1: ALU with 99.92% likelihood
#   Prediction 2: Other with 0.08% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 149: False, it was PE
#   Prediction 1: PP with 56.21% likelihood
#   Prediction 2: PE with 42.76% likelihood
#   Prediction 3: PLA with 0.97% likelihood
#   Prediction 4: Other with 0.06% likelihood
# Sample 150: Correct, it was PP
#   Prediction 1: PP with 81.31% likelihood
#   Prediction 2: PE with 18.35% likelihood
#   Prediction 3: PLA with 0.31% likelihood
#   Prediction 4: Other with 0.02% likelihood
# Sample 151: Correct, it was ALU
#   Prediction 1: ALU with 99.58% likelihood
#   Prediction 2: Other with 0.42% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 152: Correct, it was PP
#   Prediction 1: PP with 80.10% likelihood
#   Prediction 2: PE with 19.46% likelihood
#   Prediction 3: PLA with 0.41% likelihood
#   Prediction 4: Other with 0.03% likelihood
# Sample 153: Correct, it was Other
#   Prediction 1: Other with 99.94% likelihood
#   Prediction 2: PE with 0.06% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 154: Correct, it was PLA
#   Prediction 1: PLA with 53.78% likelihood
#   Prediction 2: PE with 30.59% likelihood
#   Prediction 3: Other with 15.62% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 155: Correct, it was ALU
#   Prediction 1: ALU with 99.92% likelihood
#   Prediction 2: Other with 0.08% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 156: Correct, it was PP
#   Prediction 1: PP with 84.51% likelihood
#   Prediction 2: PE with 15.30% likelihood
#   Prediction 3: PLA with 0.18% likelihood
#   Prediction 4: Other with 0.01% likelihood
# Sample 157: Correct, it was PP
#   Prediction 1: PP with 69.57% likelihood
#   Prediction 2: PE with 30.37% likelihood
#   Prediction 3: PLA with 0.04% likelihood
#   Prediction 4: Other with 0.02% likelihood
# Sample 158: Correct, it was Other
#   Prediction 1: Other with 97.78% likelihood
#   Prediction 2: PE with 2.00% likelihood
#   Prediction 3: PLA with 0.22% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 159: Correct, it was PLA
#   Prediction 1: PLA with 90.71% likelihood
#   Prediction 2: PE with 8.80% likelihood
#   Prediction 3: PP with 0.39% likelihood
#   Prediction 4: Other with 0.11% likelihood
# Sample 160: Correct, it was ALU
#   Prediction 1: ALU with 99.92% likelihood
#   Prediction 2: Other with 0.08% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 161: Correct, it was PE
#   Prediction 1: PE with 54.64% likelihood
#   Prediction 2: PP with 43.32% likelihood
#   Prediction 3: PLA with 1.93% likelihood
#   Prediction 4: Other with 0.11% likelihood
# Sample 162: False, it was Other
#   Prediction 1: PLA with 75.87% likelihood
#   Prediction 2: PE with 14.30% likelihood
#   Prediction 3: Other with 9.84% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 163: Correct, it was PP
#   Prediction 1: PP with 83.51% likelihood
#   Prediction 2: PE with 16.28% likelihood
#   Prediction 3: PLA with 0.19% likelihood
#   Prediction 4: Other with 0.02% likelihood
# Sample 164: Correct, it was PE
#   Prediction 1: PE with 75.70% likelihood
#   Prediction 2: PP with 23.40% likelihood
#   Prediction 3: PLA with 0.68% likelihood
#   Prediction 4: Other with 0.23% likelihood
# Sample 165: Correct, it was PP
#   Prediction 1: PP with 84.41% likelihood
#   Prediction 2: PE with 15.39% likelihood
#   Prediction 3: PLA with 0.18% likelihood
#   Prediction 4: Other with 0.02% likelihood
# Sample 166: Correct, it was PP
#   Prediction 1: PP with 83.28% likelihood
#   Prediction 2: PE with 16.40% likelihood
#   Prediction 3: PLA with 0.30% likelihood
#   Prediction 4: Other with 0.02% likelihood
# Sample 167: Correct, it was PLA
#   Prediction 1: PLA with 95.71% likelihood
#   Prediction 2: PE with 4.09% likelihood
#   Prediction 3: Other with 0.19% likelihood
#   Prediction 4: PP with 0.01% likelihood
# Sample 168: Correct, it was PE
#   Prediction 1: PE with 53.78% likelihood
#   Prediction 2: PP with 43.62% likelihood
#   Prediction 3: PLA with 2.46% likelihood
#   Prediction 4: Other with 0.14% likelihood
# Sample 169: Correct, it was PP
#   Prediction 1: PP with 80.31% likelihood
#   Prediction 2: PE with 19.26% likelihood
#   Prediction 3: PLA with 0.40% likelihood
#   Prediction 4: Other with 0.03% likelihood
# Sample 170: Correct, it was PP
#   Prediction 1: PP with 81.22% likelihood
#   Prediction 2: PE with 18.69% likelihood
#   Prediction 3: PLA with 0.07% likelihood
#   Prediction 4: Other with 0.01% likelihood
# Sample 171: Correct, it was PLA
#   Prediction 1: PLA with 92.68% likelihood
#   Prediction 2: PE with 6.98% likelihood
#   Prediction 3: PP with 0.17% likelihood
#   Prediction 4: Other with 0.17% likelihood
# Sample 172: Correct, it was ALU
#   Prediction 1: ALU with 99.92% likelihood
#   Prediction 2: Other with 0.08% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 173: Correct, it was PP
#   Prediction 1: PP with 81.60% likelihood
#   Prediction 2: PE with 18.33% likelihood
#   Prediction 3: PLA with 0.06% likelihood
#   Prediction 4: Other with 0.01% likelihood
# Sample 174: Correct, it was PE
#   Prediction 1: PE with 90.00% likelihood
#   Prediction 2: PP with 9.68% likelihood
#   Prediction 3: Other with 0.30% likelihood
#   Prediction 4: PLA with 0.02% likelihood
# Sample 175: Correct, it was PE
#   Prediction 1: PE with 98.63% likelihood
#   Prediction 2: Other with 1.28% likelihood
#   Prediction 3: PP with 0.09% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 176: Correct, it was PLA
#   Prediction 1: PLA with 97.86% likelihood
#   Prediction 2: PE with 1.95% likelihood
#   Prediction 3: PP with 0.15% likelihood
#   Prediction 4: Other with 0.04% likelihood
# Sample 177: Correct, it was Other
#   Prediction 1: Other with 72.79% likelihood
#   Prediction 2: PE with 27.20% likelihood
#   Prediction 3: ALU with 0.01% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 178: Correct, it was PLA
#   Prediction 1: PLA with 86.35% likelihood
#   Prediction 2: PE with 13.30% likelihood
#   Prediction 3: Other with 0.24% likelihood
#   Prediction 4: PP with 0.12% likelihood
# Sample 179: Correct, it was Other
#   Prediction 1: Other with 98.39% likelihood
#   Prediction 2: ALU with 1.60% likelihood
#   Prediction 3: PE with 0.01% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 180: Correct, it was PE
#   Prediction 1: PE with 86.01% likelihood
#   Prediction 2: Other with 11.75% likelihood
#   Prediction 3: PLA with 1.69% likelihood
#   Prediction 4: PP with 0.55% likelihood
# Sample 181: Correct, it was Other
#   Prediction 1: Other with 99.97% likelihood
#   Prediction 2: PE with 0.03% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 182: Correct, it was ALU
#   Prediction 1: ALU with 99.57% likelihood
#   Prediction 2: Other with 0.43% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 183: Correct, it was PLA
#   Prediction 1: PLA with 91.41% likelihood
#   Prediction 2: PE with 8.19% likelihood
#   Prediction 3: PP with 0.28% likelihood
#   Prediction 4: Other with 0.11% likelihood
# Sample 184: Correct, it was PLA
#   Prediction 1: PLA with 85.69% likelihood
#   Prediction 2: PE with 13.00% likelihood
#   Prediction 3: PP with 1.01% likelihood
#   Prediction 4: Other with 0.30% likelihood
# Sample 185: False, it was PE
#   Prediction 1: PP with 53.33% likelihood
#   Prediction 2: PE with 45.19% likelihood
#   Prediction 3: PLA with 1.40% likelihood
#   Prediction 4: Other with 0.08% likelihood
# Sample 186: Correct, it was PP
#   Prediction 1: PP with 85.99% likelihood
#   Prediction 2: PE with 13.85% likelihood
#   Prediction 3: PLA with 0.15% likelihood
#   Prediction 4: Other with 0.01% likelihood
# Sample 187: Correct, it was ALU
#   Prediction 1: ALU with 99.52% likelihood
#   Prediction 2: Other with 0.48% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 188: Correct, it was ALU
#   Prediction 1: ALU with 99.93% likelihood
#   Prediction 2: Other with 0.07% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 189: Correct, it was PLA
#   Prediction 1: PLA with 85.77% likelihood
#   Prediction 2: PE with 13.10% likelihood
#   Prediction 3: PP with 0.82% likelihood
#   Prediction 4: Other with 0.31% likelihood
# Sample 190: Correct, it was Other
#   Prediction 1: Other with 69.75% likelihood
#   Prediction 2: PE with 30.24% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 191: Correct, it was PE
#   Prediction 1: PE with 84.27% likelihood
#   Prediction 2: PLA with 8.42% likelihood
#   Prediction 3: Other with 4.40% likelihood
#   Prediction 4: PP with 2.90% likelihood
# Sample 192: Correct, it was PLA
#   Prediction 1: PLA with 91.07% likelihood
#   Prediction 2: PE with 8.14% likelihood
#   Prediction 3: PP with 0.57% likelihood
#   Prediction 4: Other with 0.23% likelihood
# Sample 193: Correct, it was PLA
#   Prediction 1: PLA with 69.42% likelihood
#   Prediction 2: PE with 26.58% likelihood
#   Prediction 3: PP with 2.60% likelihood
#   Prediction 4: Other with 1.40% likelihood
# Sample 194: Correct, it was PP
#   Prediction 1: PP with 55.84% likelihood
#   Prediction 2: PE with 44.06% likelihood
#   Prediction 3: PLA with 0.06% likelihood
#   Prediction 4: Other with 0.04% likelihood
# Sample 195: False, it was PE
#   Prediction 1: PP with 52.99% likelihood
#   Prediction 2: PE with 45.52% likelihood
#   Prediction 3: PLA with 1.41% likelihood
#   Prediction 4: Other with 0.08% likelihood
# Sample 196: Correct, it was ALU
#   Prediction 1: ALU with 99.93% likelihood
#   Prediction 2: Other with 0.07% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 197: Correct, it was Other
#   Prediction 1: Other with 99.76% likelihood
#   Prediction 2: PE with 0.24% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 198: Correct, it was PE
#   Prediction 1: PE with 97.59% likelihood
#   Prediction 2: PP with 2.20% likelihood
#   Prediction 3: Other with 0.20% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 199: Correct, it was PE
#   Prediction 1: PE with 74.64% likelihood
#   Prediction 2: PP with 25.23% likelihood
#   Prediction 3: Other with 0.08% likelihood
#   Prediction 4: PLA with 0.04% likelihood
# Sample 200: Correct, it was PE
#   Prediction 1: PE with 49.67% likelihood
#   Prediction 2: PP with 49.04% likelihood
#   Prediction 3: PLA with 1.20% likelihood
#   Prediction 4: Other with 0.09% likelihood

# %%
# Get manual input from the user
manual_input = np.array([[1365889,2383139,3943193,6364119,6459881,3520279,1572135,859381,1734251,3039005,5108675,6392189,4980199,2559117,1249619]])  # Replace with your input values

# Normalize the manual input if needed
normalized_manual_input = ((manual_input - 0) / (8388608 - 0))

# Make predictions on manual input
predictions = model.predict(normalized_manual_input)
print(predictions)

# Get the top prediction
top_prediction = np.argmax(predictions)
print(top_prediction)

top_plastic_type = label_encoder.inverse_transform([top_prediction])[0]
print(top_plastic_type)
likelihood = predictions[0][top_prediction] * 100

# Display the prediction for manual input
print(f"Manual Input Prediction:")
print(f"  Prediction: {top_plastic_type} with {likelihood:.2f}% likelihood")
# Out:
# 1/1 [==============================] - 0s 50ms/step
# [[3.7508350e-08 9.3842234e-04 2.7768186e-01 7.0397183e-02 6.5098250e-01]]
# 4
# PP
# Manual Input Prediction:
#   Prediction: PP with 65.10% likelihood

# %%
# Make predictions from manual
manual_input = np.array([[1365889,2383139,3943193,6364119,6459881,3520279,1572135,859381,1734251,3039005,5108675,6392189,4980199,2559117,1249619
]])

# Calculate the column-wise min and max values from your original dataset
min_values = [74296, 1151721, 2379300, 2748695, 3681840, 1997402, 1742243, 942818, 392145, 795677, 1406647, 2482140, 2630495, 1748806, 1249297]
max_values = [1773075, 3755206, 7787954, 8401566, 8405071, 8401566, 7232265, 8185313, 2080604, 4455589, 8402979, 8405071, 8405071, 8403086, 6084492]

# Convert the lists to numpy arrays
min_values = np.array(min_values)
max_values = np.array(max_values)

# Normalize the manual input using the calculated min and max values
normalized_manual_input = (manual_input - min_values) / (max_values - min_values)
# normalized_manual_input = np.array([[0.85611,0.63202,0.53239,0.41068,0.59174,0.39869,0.44654,0.42188,0.8826042,0.67470967,0.34701898,0.42024683,0.34977269,0.16862726,0.1471771]])

print(normalized_manual_input)

predictions = model.predict(normalized_manual_input)
predicted_labels = np.argmax(predictions, axis=1)
predicted_plastic_types = label_encoder.inverse_transform(predicted_labels)

    
## Calculate the percentage likelihoods
percentage_likelihoods = predictions * 100

# Get the indices of the top 4 predicted classes based on percentage likelihoods
top_indices = np.argsort(percentage_likelihoods[0])[::-1][:4]

# Get the labels for the top predicted classes
top_labels = label_encoder.inverse_transform(top_indices)

# Get the predicted label
predicted_label = top_labels[0]

# Get the true label from the original data (replace with your true label)
true_label = 'ALU'  # Replace with the true label

# Calculate the accuracy
if predicted_label == true_label:
    accuracy = "Correct"
else:
    accuracy = "False"

# Print the prediction, label, and accuracy
print(f"Predicted label: {predicted_label}")
print(f"True label: {true_label}")
print(f"Accuracy: {accuracy}")

# Print the percentages for each type
for label, likelihood in zip(top_labels, percentage_likelihoods[0][top_indices]):
    print(f"{label}: {likelihood:.2f}% likelihood")
# Out:
# [[ 7.60306667e-01  4.72988321e-01  2.89146431e-01  6.39573059e-01
#    5.88165389e-01  2.37794816e-01 -3.09849396e-02 -1.15204774e-02
#    7.94870352e-01  6.12945885e-01  5.29138411e-01  6.60154407e-01
#    4.06905026e-01  1.21772904e-01  6.65950391e-05]]
# 1/1 [==============================] - 0s 21ms/step
# Predicted label: PE
# True label: ALU
# Accuracy: False
# PE: 95.33% likelihood
# Other: 4.64% likelihood
# PP: 0.03% likelihood
# PLA: 0.00% likelihood
