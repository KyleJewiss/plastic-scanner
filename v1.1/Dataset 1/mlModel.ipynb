# %%
# import pandas as pd
# from imblearn.over_sampling import SMOTE
# from collections import Counter

# # Load your dataset here (replace 'your_dataset.csv' with your actual dataset file)
# # data = pd.read_csv('AllTogether.csv')
# data = pd.read_csv("AllTogether8Ptest.csv")
# # data = pd.read_csv("HDPEvsLDPE.csv")

# # Assuming 'material_type' is the column that indicates the material type
# X = data.drop(columns=['Material_Type'])
# y = data['Material_Type']

# # Initialize SMOTE with the desired number of samples for each class (e.g., 100)
# desired_samples = 2000
# smote = SMOTE(sampling_strategy={material_type: desired_samples for material_type in y.unique()})

# # Apply SMOTE to the dataset
# X_resampled, y_resampled = smote.fit_resample(X, y)

# # Check the new class distribution
# print("Class distribution after SMOTE:", Counter(y_resampled))

# # Now you can use X_resampled and y_resampled as your balanced dataset

# # Create a new DataFrame with the resampled data
# resampled_data = pd.DataFrame(X_resampled, columns=X.columns)
# resampled_data['Material_Type'] = y_resampled

# # Save the resampled data to a CSV file
# resampled_data.to_csv('resampled_dataset8Ptest.csv', index=False)

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import EarlyStopping

# Load the dataset
data = pd.read_csv("AllTogether8Ptest.csv")
# data = pd.read_csv("resampled_datasetNewPPFAT.csv")
# data = pd.read_csv("resampled_datasetHvL.csv")


# Separate features and labels
X = data.drop(columns=["Material_Type"])
y = data["Material_Type"]

# %%
# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into train and test sets (Normal)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=22)

# # Normalize features
# X_train_normalized = (X_train - X_train.min()) / (X_train.max() - X_train.min())
# X_test_normalized = (X_test - X_train.min()) / (X_train.max() - X_train.min())
X_train_normalized = ((X_train - 0) / (8410000 - 0))
X_test_normalized = ((X_test - 0) / (8410000 - 0))

# Define the model architecture
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(256, activation="relu"),
    tf.keras.layers.Dense(256, activation="relu"),
    tf.keras.layers.Dense(len(label_encoder.classes_), activation="softmax")
])

# %%
# Compile the model
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# Define early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=10,          # Wait for 10 epochs without improvement
    min_delta=0.001,      # Minimum change required to consider an improvement
    verbose=1,            # Print messages about early stopping
    restore_best_weights=True
)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(X_train_normalized, y_train, epochs=100, batch_size=256, validation_split=0.2, callbacks=[early_stopping])
# history = model.fit(X_train_normalized, y_train, epochs=500, batch_size=256, validation_split=0.2)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_normalized, y_test)

# Save the model
# model.save("15_point_plastic_classifier_model.keras")
model.save("15_point_plastic_classifier_model_8Ptest.keras")

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss')
plt.legend()
plt.show()

# Plot training and validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 793ms/step - loss: 1.6366 - accuracy: 0.1512 - val_loss: 1.5825 - val_accuracy: 0.2308
# Epoch 2/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.5933 - accuracy: 0.2098 - val_loss: 1.5342 - val_accuracy: 0.6538
# Epoch 3/100
# 1/1 [==============================] - 0s 49ms/step - loss: 1.5570 - accuracy: 0.5854 - val_loss: 1.4914 - val_accuracy: 0.6731
# Epoch 4/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.5252 - accuracy: 0.5854 - val_loss: 1.4541 - val_accuracy: 0.4808
# Epoch 5/100
# 1/1 [==============================] - 0s 60ms/step - loss: 1.4980 - accuracy: 0.4634 - val_loss: 1.4217 - val_accuracy: 0.4615
# Epoch 6/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.4748 - accuracy: 0.4732 - val_loss: 1.3933 - val_accuracy: 0.5192
# Epoch 7/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1.4549 - accuracy: 0.5220 - val_loss: 1.3691 - val_accuracy: 0.5192
# Epoch 8/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1.4382 - accuracy: 0.5268 - val_loss: 1.3465 - val_accuracy: 0.5192
# Epoch 9/100
# 1/1 [==============================] - 0s 33ms/step - loss: 1.4231 - accuracy: 0.5268 - val_loss: 1.3260 - val_accuracy: 0.5192
# Epoch 10/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.4096 - accuracy: 0.5268 - val_loss: 1.3061 - val_accuracy: 0.5192
# Epoch 11/100
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3968 - accuracy: 0.5268 - val_loss: 1.2871 - val_accuracy: 0.5192
# Epoch 12/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1.3848 - accuracy: 0.5317 - val_loss: 1.2676 - val_accuracy: 0.5192
# Epoch 13/100
# 1/1 [==============================] - 0s 34ms/step - loss: 1.3728 - accuracy: 0.5366 - val_loss: 1.2476 - val_accuracy: 0.5192
# Epoch 14/100
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3602 - accuracy: 0.5366 - val_loss: 1.2274 - val_accuracy: 0.5192
# Epoch 15/100
# 1/1 [==============================] - 0s 34ms/step - loss: 1.3470 - accuracy: 0.5366 - val_loss: 1.2078 - val_accuracy: 0.5192
# Epoch 16/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1.3337 - accuracy: 0.5366 - val_loss: 1.1891 - val_accuracy: 0.5769
# Epoch 17/100
# 1/1 [==============================] - 0s 31ms/step - loss: 1.3201 - accuracy: 0.5707 - val_loss: 1.1708 - val_accuracy: 0.5769
# Epoch 18/100
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3057 - accuracy: 0.5707 - val_loss: 1.1529 - val_accuracy: 0.6923
# Epoch 19/100
# 1/1 [==============================] - 0s 39ms/step - loss: 1.2906 - accuracy: 0.6439 - val_loss: 1.1356 - val_accuracy: 0.7308
# Epoch 20/100
# 1/1 [==============================] - 0s 35ms/step - loss: 1.2751 - accuracy: 0.6829 - val_loss: 1.1184 - val_accuracy: 0.7308
# Epoch 21/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.2587 - accuracy: 0.6829 - val_loss: 1.1015 - val_accuracy: 0.7308
# Epoch 22/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.2417 - accuracy: 0.6829 - val_loss: 1.0847 - val_accuracy: 0.7308
# Epoch 23/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.2241 - accuracy: 0.6878 - val_loss: 1.0676 - val_accuracy: 0.7308
# Epoch 24/100
# 1/1 [==============================] - 0s 41ms/step - loss: 1.2055 - accuracy: 0.6927 - val_loss: 1.0498 - val_accuracy: 0.7115
# Epoch 25/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.1860 - accuracy: 0.6927 - val_loss: 1.0315 - val_accuracy: 0.7115
# Epoch 26/100
# 1/1 [==============================] - 0s 50ms/step - loss: 1.1658 - accuracy: 0.6927 - val_loss: 1.0132 - val_accuracy: 0.7115
# Epoch 27/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.1455 - accuracy: 0.6927 - val_loss: 0.9945 - val_accuracy: 0.7115
# Epoch 28/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1.1249 - accuracy: 0.6927 - val_loss: 0.9754 - val_accuracy: 0.7115
# Epoch 29/100
# 1/1 [==============================] - 0s 35ms/step - loss: 1.1041 - accuracy: 0.6927 - val_loss: 0.9563 - val_accuracy: 0.7115
# Epoch 30/100
# 1/1 [==============================] - 0s 35ms/step - loss: 1.0834 - accuracy: 0.6927 - val_loss: 0.9371 - val_accuracy: 0.7308
# Epoch 31/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.0627 - accuracy: 0.6976 - val_loss: 0.9180 - val_accuracy: 0.7308
# Epoch 32/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.0421 - accuracy: 0.7024 - val_loss: 0.8994 - val_accuracy: 0.7308
# Epoch 33/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.0217 - accuracy: 0.7073 - val_loss: 0.8811 - val_accuracy: 0.7308
# Epoch 34/100
# 1/1 [==============================] - 0s 34ms/step - loss: 1.0015 - accuracy: 0.7073 - val_loss: 0.8634 - val_accuracy: 0.7308
# Epoch 35/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.9816 - accuracy: 0.7073 - val_loss: 0.8467 - val_accuracy: 0.7308
# Epoch 36/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.9624 - accuracy: 0.7073 - val_loss: 0.8311 - val_accuracy: 0.7308
# Epoch 37/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9440 - accuracy: 0.7171 - val_loss: 0.8165 - val_accuracy: 0.7308
# Epoch 38/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.9264 - accuracy: 0.7171 - val_loss: 0.8025 - val_accuracy: 0.7500
# Epoch 39/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.9092 - accuracy: 0.7171 - val_loss: 0.7894 - val_accuracy: 0.7500
# Epoch 40/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.8926 - accuracy: 0.7171 - val_loss: 0.7771 - val_accuracy: 0.7500
# Epoch 41/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.8768 - accuracy: 0.7171 - val_loss: 0.7656 - val_accuracy: 0.7500
# Epoch 42/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.8619 - accuracy: 0.7220 - val_loss: 0.7553 - val_accuracy: 0.7500
# Epoch 43/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.8480 - accuracy: 0.7220 - val_loss: 0.7461 - val_accuracy: 0.7500
# Epoch 44/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.8351 - accuracy: 0.7220 - val_loss: 0.7380 - val_accuracy: 0.7500
# Epoch 45/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.8232 - accuracy: 0.7317 - val_loss: 0.7305 - val_accuracy: 0.7500
# Epoch 46/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.8121 - accuracy: 0.7317 - val_loss: 0.7236 - val_accuracy: 0.7500
# Epoch 47/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.8018 - accuracy: 0.7317 - val_loss: 0.7173 - val_accuracy: 0.7500
# Epoch 48/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.7921 - accuracy: 0.7317 - val_loss: 0.7117 - val_accuracy: 0.7500
# Epoch 49/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.7831 - accuracy: 0.7317 - val_loss: 0.7067 - val_accuracy: 0.7500
# Epoch 50/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.7745 - accuracy: 0.7366 - val_loss: 0.7023 - val_accuracy: 0.7500
# Epoch 51/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.7666 - accuracy: 0.7366 - val_loss: 0.6987 - val_accuracy: 0.7500
# Epoch 52/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.7591 - accuracy: 0.7366 - val_loss: 0.6958 - val_accuracy: 0.7500
# Epoch 53/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.7521 - accuracy: 0.7366 - val_loss: 0.6937 - val_accuracy: 0.7500
# Epoch 54/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.7453 - accuracy: 0.7317 - val_loss: 0.6921 - val_accuracy: 0.7500
# Epoch 55/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.7389 - accuracy: 0.7317 - val_loss: 0.6908 - val_accuracy: 0.7500
# Epoch 56/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.7328 - accuracy: 0.7317 - val_loss: 0.6894 - val_accuracy: 0.7500
# Epoch 57/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.7269 - accuracy: 0.7317 - val_loss: 0.6880 - val_accuracy: 0.7500
# Epoch 58/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.7214 - accuracy: 0.7317 - val_loss: 0.6865 - val_accuracy: 0.7500
# Epoch 59/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.7160 - accuracy: 0.7317 - val_loss: 0.6850 - val_accuracy: 0.7500
# Epoch 60/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.7109 - accuracy: 0.7317 - val_loss: 0.6832 - val_accuracy: 0.7500
# Epoch 61/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.7059 - accuracy: 0.7317 - val_loss: 0.6817 - val_accuracy: 0.7500
# Epoch 62/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.7010 - accuracy: 0.7366 - val_loss: 0.6801 - val_accuracy: 0.7500
# Epoch 63/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.6963 - accuracy: 0.7366 - val_loss: 0.6785 - val_accuracy: 0.7500
# Epoch 64/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.6919 - accuracy: 0.7366 - val_loss: 0.6769 - val_accuracy: 0.7500
# Epoch 65/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6876 - accuracy: 0.7366 - val_loss: 0.6753 - val_accuracy: 0.7500
# Epoch 66/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6835 - accuracy: 0.7366 - val_loss: 0.6737 - val_accuracy: 0.7500
# Epoch 67/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6794 - accuracy: 0.7366 - val_loss: 0.6723 - val_accuracy: 0.7500
# Epoch 68/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6752 - accuracy: 0.7366 - val_loss: 0.6709 - val_accuracy: 0.7500
# Epoch 69/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.6711 - accuracy: 0.7463 - val_loss: 0.6698 - val_accuracy: 0.7500
# Epoch 70/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.6673 - accuracy: 0.7463 - val_loss: 0.6687 - val_accuracy: 0.7500
# Epoch 71/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.6635 - accuracy: 0.7463 - val_loss: 0.6677 - val_accuracy: 0.7500
# Epoch 72/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6598 - accuracy: 0.7512 - val_loss: 0.6664 - val_accuracy: 0.7500
# Epoch 73/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.6561 - accuracy: 0.7512 - val_loss: 0.6650 - val_accuracy: 0.7500
# Epoch 74/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6523 - accuracy: 0.7512 - val_loss: 0.6638 - val_accuracy: 0.7500
# Epoch 75/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6487 - accuracy: 0.7512 - val_loss: 0.6625 - val_accuracy: 0.7500
# Epoch 76/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.6452 - accuracy: 0.7512 - val_loss: 0.6611 - val_accuracy: 0.7500
# Epoch 77/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.6417 - accuracy: 0.7512 - val_loss: 0.6598 - val_accuracy: 0.7500
# Epoch 78/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6382 - accuracy: 0.7512 - val_loss: 0.6585 - val_accuracy: 0.7500
# Epoch 79/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.6347 - accuracy: 0.7512 - val_loss: 0.6573 - val_accuracy: 0.7500
# Epoch 80/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.6312 - accuracy: 0.7512 - val_loss: 0.6557 - val_accuracy: 0.7500
# Epoch 81/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6278 - accuracy: 0.7512 - val_loss: 0.6538 - val_accuracy: 0.7500
# Epoch 82/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6243 - accuracy: 0.7512 - val_loss: 0.6520 - val_accuracy: 0.7500
# Epoch 83/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.6209 - accuracy: 0.7512 - val_loss: 0.6504 - val_accuracy: 0.7500
# Epoch 84/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.6174 - accuracy: 0.7512 - val_loss: 0.6489 - val_accuracy: 0.7500
# Epoch 85/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6140 - accuracy: 0.7512 - val_loss: 0.6473 - val_accuracy: 0.7500
# Epoch 86/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6106 - accuracy: 0.7610 - val_loss: 0.6459 - val_accuracy: 0.7500
# Epoch 87/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6073 - accuracy: 0.7610 - val_loss: 0.6446 - val_accuracy: 0.7500
# Epoch 88/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6039 - accuracy: 0.7610 - val_loss: 0.6434 - val_accuracy: 0.7500
# Epoch 89/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.6005 - accuracy: 0.7659 - val_loss: 0.6422 - val_accuracy: 0.7500
# Epoch 90/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.5971 - accuracy: 0.7707 - val_loss: 0.6410 - val_accuracy: 0.7500
# Epoch 91/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.5938 - accuracy: 0.7756 - val_loss: 0.6396 - val_accuracy: 0.7500
# Epoch 92/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5905 - accuracy: 0.7756 - val_loss: 0.6381 - val_accuracy: 0.7500
# Epoch 93/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.5872 - accuracy: 0.7756 - val_loss: 0.6365 - val_accuracy: 0.7500
# Epoch 94/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.5839 - accuracy: 0.7756 - val_loss: 0.6346 - val_accuracy: 0.7500
# Epoch 95/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.5805 - accuracy: 0.7756 - val_loss: 0.6329 - val_accuracy: 0.7500
# Epoch 96/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5772 - accuracy: 0.7756 - val_loss: 0.6314 - val_accuracy: 0.7500
# Epoch 97/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.5739 - accuracy: 0.7756 - val_loss: 0.6300 - val_accuracy: 0.7500
# Epoch 98/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.5706 - accuracy: 0.7756 - val_loss: 0.6284 - val_accuracy: 0.7500
# Epoch 99/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5673 - accuracy: 0.7756 - val_loss: 0.6268 - val_accuracy: 0.7500
# Epoch 100/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5639 - accuracy: 0.7756 - val_loss: 0.6251 - val_accuracy: 0.7500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8172 - accuracy: 0.6000

# %%
# Make predictions
predictions = model.predict(X_test_normalized)
predicted_labels = np.argmax(predictions, axis=1)
predicted_plastic_types = label_encoder.inverse_transform(predicted_labels)



# Convert predictions to percentage likelihood
percentage_likelihood = predictions.max(axis=1) * 100

# Display test accuracy and example predictions
print(f"Test Accuracy: {test_accuracy}")
for i in range(15):
    if y_test[i] == predicted_labels[i]:
        CorF = "Correct"
    else:
        CorF = "False"
    print(f"Sample {i+1}: {CorF} Predicted {predicted_plastic_types[i]} with {percentage_likelihood[i]:.2f}% likelihood")




total_params = model.count_params()
total_size_bytes = total_params * 4  # Each parameter is usually a 32-bit float
total_size_mb = total_size_bytes / (1024)  # Convert bytes to megabytes

print(f"Total size of the model: {total_size_mb:.2f} KB")
# Out:
# 3/3 [==============================] - 0s 4ms/step
# Test Accuracy: 0.6000000238418579
# Sample 1: Correct Predicted PE with 59.99% likelihood
# Sample 2: False Predicted PE with 60.24% likelihood
# Sample 3: False Predicted PE with 57.23% likelihood
# Sample 4: False Predicted PE with 59.06% likelihood
# Sample 5: Correct Predicted PE with 65.61% likelihood
# Sample 6: False Predicted PE with 61.11% likelihood
# Sample 7: False Predicted PE with 66.29% likelihood
# Sample 8: Correct Predicted Other with 95.34% likelihood
# Sample 9: Correct Predicted PE with 58.59% likelihood
# Sample 10: False Predicted PE with 63.04% likelihood
# Sample 11: False Predicted PE with 61.26% likelihood
# Sample 12: Correct Predicted PE with 58.91% likelihood
# Sample 13: Correct Predicted Other with 96.01% likelihood
# Sample 14: False Predicted PE with 60.36% likelihood
# Sample 15: Correct Predicted Other with 99.92% likelihood
# Total size of the model: 271.02 KB

# %%
# Make predictions
predictions = model.predict(X_test_normalized)

# Get the top 4 predictions for each sample
top_predictions = np.argsort(predictions, axis=1)[:, -4:]
top_labels = top_predictions[:, ::-1]

# print(predictions)

# Reshape the top_labels array to be 1D
top_labels_1d = top_labels.reshape(-1)

# Inverse transform the labels
top_plastic_types = label_encoder.inverse_transform(top_labels_1d)

# Reshape the top_plastic_types array back to 2D
top_plastic_types = top_plastic_types.reshape(top_labels.shape)

# Get the percentage likelihoods for the top 4 predictions
percentage_likelihoods = np.take_along_axis(predictions, top_predictions, axis=1) * 100

# Display test accuracy and example predictions
print(f"Test Accuracy: {test_accuracy}")
for i in range(len(predicted_labels)):
    num_predictions = min(4, len(np.unique(top_labels[i])))
    if y_test[i] == predicted_labels[i]:
        CorF = "Correct,"
    else:
        CorF = "False,"
    print(f"Sample {i+1}: {CorF} it was {label_encoder.classes_[y_test[i]]}")
    for j in range(num_predictions):
        print(f"  Prediction {j+1}: {top_plastic_types[i][j]} with {percentage_likelihoods[i][3-j]:.2f}% likelihood")
# Out:
# 3/3 [==============================] - 0s 2ms/step
# Test Accuracy: 0.6000000238418579
# Sample 1: Correct, it was PE
#   Prediction 1: PE with 59.99% likelihood
#   Prediction 2: PP with 26.47% likelihood
#   Prediction 3: PLA with 10.25% likelihood
#   Prediction 4: Other with 3.25% likelihood
# Sample 2: False, it was PP
#   Prediction 1: PE with 60.24% likelihood
#   Prediction 2: PP with 27.68% likelihood
#   Prediction 3: PLA with 9.20% likelihood
#   Prediction 4: Other with 2.84% likelihood
# Sample 3: False, it was PLA
#   Prediction 1: PE with 57.23% likelihood
#   Prediction 2: PP with 28.28% likelihood
#   Prediction 3: PLA with 12.71% likelihood
#   Prediction 4: Other with 1.76% likelihood
# Sample 4: False, it was PP
#   Prediction 1: PE with 59.06% likelihood
#   Prediction 2: PP with 28.39% likelihood
#   Prediction 3: PLA with 9.74% likelihood
#   Prediction 4: Other with 2.78% likelihood
# Sample 5: Correct, it was PE
#   Prediction 1: PE with 65.61% likelihood
#   Prediction 2: PP with 18.30% likelihood
#   Prediction 3: Other with 9.30% likelihood
#   Prediction 4: PLA with 6.66% likelihood
# Sample 6: False, it was PP
#   Prediction 1: PE with 61.11% likelihood
#   Prediction 2: PP with 27.00% likelihood
#   Prediction 3: PLA with 8.91% likelihood
#   Prediction 4: Other with 2.95% likelihood
# Sample 7: False, it was Other
#   Prediction 1: PE with 66.29% likelihood
#   Prediction 2: PP with 19.09% likelihood
#   Prediction 3: PLA with 7.30% likelihood
#   Prediction 4: Other with 7.24% likelihood
# Sample 8: Correct, it was Other
#   Prediction 1: Other with 95.34% likelihood
#   Prediction 2: PE with 3.67% likelihood
#   Prediction 3: PP with 0.59% likelihood
#   Prediction 4: PLA with 0.37% likelihood
# Sample 9: Correct, it was PE
#   Prediction 1: PE with 58.59% likelihood
#   Prediction 2: PP with 28.20% likelihood
#   Prediction 3: PLA with 10.44% likelihood
#   Prediction 4: Other with 2.74% likelihood
# Sample 10: False, it was PP
#   Prediction 1: PE with 63.04% likelihood
#   Prediction 2: PP with 24.30% likelihood
#   Prediction 3: PLA with 8.32% likelihood
#   Prediction 4: Other with 4.27% likelihood
# Sample 11: False, it was PP
#   Prediction 1: PE with 61.26% likelihood
#   Prediction 2: PP with 26.63% likelihood
#   Prediction 3: PLA with 8.75% likelihood
#   Prediction 4: Other with 3.32% likelihood
# Sample 12: Correct, it was PE
#   Prediction 1: PE with 58.91% likelihood
#   Prediction 2: PP with 28.26% likelihood
#   Prediction 3: PLA with 10.07% likelihood
#   Prediction 4: Other with 2.73% likelihood
# Sample 13: Correct, it was Other
#   Prediction 1: Other with 96.01% likelihood
#   Prediction 2: PE with 3.13% likelihood
#   Prediction 3: PP with 0.51% likelihood
#   Prediction 4: PLA with 0.33% likelihood
# Sample 14: False, it was PLA
#   Prediction 1: PE with 60.36% likelihood
#   Prediction 2: PP with 18.96% likelihood
#   Prediction 3: PLA with 10.83% likelihood
#   Prediction 4: Other with 9.64% likelihood
# Sample 15: Correct, it was Other
#   Prediction 1: Other with 99.92% likelihood
#   Prediction 2: PE with 0.06% likelihood
#   Prediction 3: ALU with 0.01% likelihood
#   Prediction 4: PP with 0.01% likelihood
# Sample 16: Correct, it was PE
#   Prediction 1: PE with 56.92% likelihood
#   Prediction 2: PP with 27.57% likelihood
#   Prediction 3: PLA with 12.50% likelihood
#   Prediction 4: Other with 2.99% likelihood
# Sample 17: False, it was PLA
#   Prediction 1: PE with 58.04% likelihood
#   Prediction 2: PP with 25.44% likelihood
#   Prediction 3: PLA with 12.17% likelihood
#   Prediction 4: Other with 4.32% likelihood
# Sample 18: Correct, it was PE
#   Prediction 1: PE with 60.15% likelihood
#   Prediction 2: PP with 27.01% likelihood
#   Prediction 3: PLA with 9.87% likelihood
#   Prediction 4: Other with 2.93% likelihood
# Sample 19: Correct, it was PE
#   Prediction 1: PE with 65.08% likelihood
#   Prediction 2: PP with 16.62% likelihood
#   Prediction 3: Other with 11.89% likelihood
#   Prediction 4: PLA with 6.19% likelihood
# Sample 20: Correct, it was PE
#   Prediction 1: PE with 63.20% likelihood
#   Prediction 2: Other with 18.34% likelihood
#   Prediction 3: PP with 13.73% likelihood
#   Prediction 4: PLA with 4.43% likelihood
# Sample 21: Correct, it was PE
#   Prediction 1: PE with 58.16% likelihood
#   Prediction 2: PP with 27.31% likelihood
#   Prediction 3: PLA with 11.03% likelihood
#   Prediction 4: Other with 3.49% likelihood
# Sample 22: Correct, it was Other
#   Prediction 1: Other with 99.82% likelihood
#   Prediction 2: PE with 0.14% likelihood
#   Prediction 3: PP with 0.01% likelihood
#   Prediction 4: ALU with 0.01% likelihood
# Sample 23: Correct, it was ALU
#   Prediction 1: ALU with 95.81% likelihood
#   Prediction 2: Other with 4.19% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 24: False, it was PLA
#   Prediction 1: PE with 58.60% likelihood
#   Prediction 2: Other with 19.30% likelihood
#   Prediction 3: PP with 14.69% likelihood
#   Prediction 4: PLA with 6.93% likelihood
# Sample 25: False, it was PP
#   Prediction 1: PE with 59.46% likelihood
#   Prediction 2: PP with 28.24% likelihood
#   Prediction 3: PLA with 9.59% likelihood
#   Prediction 4: Other with 2.68% likelihood
# Sample 26: Correct, it was PE
#   Prediction 1: PE with 65.86% likelihood
#   Prediction 2: PP with 18.24% likelihood
#   Prediction 3: Other with 9.39% likelihood
#   Prediction 4: PLA with 6.35% likelihood
# Sample 27: Correct, it was PE
#   Prediction 1: PE with 64.67% likelihood
#   Prediction 2: PP with 21.35% likelihood
#   Prediction 3: PLA with 7.37% likelihood
#   Prediction 4: Other with 6.51% likelihood
# Sample 28: False, it was PP
#   Prediction 1: PE with 60.13% likelihood
#   Prediction 2: PP with 27.99% likelihood
#   Prediction 3: PLA with 9.11% likelihood
#   Prediction 4: Other with 2.75% likelihood
# Sample 29: Correct, it was ALU
#   Prediction 1: ALU with 96.29% likelihood
#   Prediction 2: Other with 3.71% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 30: False, it was PP
#   Prediction 1: PE with 60.99% likelihood
#   Prediction 2: PP with 26.56% likelihood
#   Prediction 3: PLA with 9.33% likelihood
#   Prediction 4: Other with 3.09% likelihood
# Sample 31: Correct, it was ALU
#   Prediction 1: ALU with 98.66% likelihood
#   Prediction 2: Other with 1.34% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 32: False, it was PP
#   Prediction 1: PE with 59.22% likelihood
#   Prediction 2: PP with 28.41% likelihood
#   Prediction 3: PLA with 9.56% likelihood
#   Prediction 4: Other with 2.77% likelihood
# Sample 33: False, it was PP
#   Prediction 1: PE with 60.95% likelihood
#   Prediction 2: PP with 26.88% likelihood
#   Prediction 3: PLA with 8.95% likelihood
#   Prediction 4: Other with 3.18% likelihood
# Sample 34: Correct, it was PE
#   Prediction 1: PE with 60.62% likelihood
#   Prediction 2: PP with 26.51% likelihood
#   Prediction 3: PLA with 9.80% likelihood
#   Prediction 4: Other with 3.04% likelihood
# Sample 35: Correct, it was PE
#   Prediction 1: PE with 59.92% likelihood
#   Prediction 2: PP with 27.22% likelihood
#   Prediction 3: PLA with 9.95% likelihood
#   Prediction 4: Other with 2.88% likelihood
# Sample 36: Correct, it was PE
#   Prediction 1: PE with 61.96% likelihood
#   Prediction 2: Other with 19.47% likelihood
#   Prediction 3: PP with 12.94% likelihood
#   Prediction 4: PLA with 5.20% likelihood
# Sample 37: Correct, it was Other
#   Prediction 1: Other with 99.70% likelihood
#   Prediction 2: PE with 0.24% likelihood
#   Prediction 3: PP with 0.03% likelihood
#   Prediction 4: PLA with 0.02% likelihood
# Sample 38: Correct, it was Other
#   Prediction 1: Other with 93.45% likelihood
#   Prediction 2: PE with 5.11% likelihood
#   Prediction 3: PP with 0.87% likelihood
#   Prediction 4: PLA with 0.53% likelihood
# Sample 39: Correct, it was Other
#   Prediction 1: Other with 96.08% likelihood
#   Prediction 2: PE with 3.10% likelihood
#   Prediction 3: PP with 0.49% likelihood
#   Prediction 4: PLA with 0.30% likelihood
# Sample 40: Correct, it was PE
#   Prediction 1: PE with 61.15% likelihood
#   Prediction 2: PP with 23.56% likelihood
#   Prediction 3: PLA with 8.86% likelihood
#   Prediction 4: Other with 6.36% likelihood
# Sample 41: False, it was PP
#   Prediction 1: PE with 60.30% likelihood
#   Prediction 2: PP with 27.38% likelihood
#   Prediction 3: PLA with 9.39% likelihood
#   Prediction 4: Other with 2.90% likelihood
# Sample 42: Correct, it was Other
#   Prediction 1: Other with 99.74% likelihood
#   Prediction 2: PE with 0.21% likelihood
#   Prediction 3: PP with 0.02% likelihood
#   Prediction 4: PLA with 0.02% likelihood
# Sample 43: Correct, it was ALU
#   Prediction 1: ALU with 93.07% likelihood
#   Prediction 2: Other with 6.93% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 44: Correct, it was PE
#   Prediction 1: PE with 62.26% likelihood
#   Prediction 2: PP with 24.41% likelihood
#   Prediction 3: PLA with 8.90% likelihood
#   Prediction 4: Other with 4.36% likelihood
# Sample 45: False, it was PP
#   Prediction 1: PE with 61.90% likelihood
#   Prediction 2: PP with 25.92% likelihood
#   Prediction 3: PLA with 8.73% likelihood
#   Prediction 4: Other with 3.41% likelihood
# Sample 46: Correct, it was PE
#   Prediction 1: PE with 62.92% likelihood
#   Prediction 2: PP with 17.53% likelihood
#   Prediction 3: Other with 12.36% likelihood
#   Prediction 4: PLA with 7.08% likelihood
# Sample 47: Correct, it was PE
#   Prediction 1: PE with 61.61% likelihood
#   Prediction 2: PP with 25.60% likelihood
#   Prediction 3: PLA with 9.14% likelihood
#   Prediction 4: Other with 3.61% likelihood
# Sample 48: Correct, it was PE
#   Prediction 1: PE with 64.56% likelihood
#   Prediction 2: PP with 21.49% likelihood
#   Prediction 3: PLA with 7.67% likelihood
#   Prediction 4: Other with 6.17% likelihood
# Sample 49: False, it was PP
#   Prediction 1: PE with 63.54% likelihood
#   Prediction 2: PP with 23.95% likelihood
#   Prediction 3: PLA with 8.23% likelihood
#   Prediction 4: Other with 4.22% likelihood
# Sample 50: False, it was PE
#   Prediction 1: Other with 74.38% likelihood
#   Prediction 2: PE with 19.96% likelihood
#   Prediction 3: PP with 3.75% likelihood
#   Prediction 4: PLA with 1.79% likelihood
# Sample 51: Correct, it was PE
#   Prediction 1: PE with 60.37% likelihood
#   Prediction 2: PP with 26.87% likelihood
#   Prediction 3: PLA with 9.46% likelihood
#   Prediction 4: Other with 3.26% likelihood
# Sample 52: Correct, it was Other
#   Prediction 1: Other with 99.74% likelihood
#   Prediction 2: PE with 0.21% likelihood
#   Prediction 3: PP with 0.02% likelihood
#   Prediction 4: PLA with 0.02% likelihood
# Sample 53: False, it was PP
#   Prediction 1: PE with 58.75% likelihood
#   Prediction 2: PP with 28.73% likelihood
#   Prediction 3: PLA with 9.90% likelihood
#   Prediction 4: Other with 2.59% likelihood
# Sample 54: Correct, it was PE
#   Prediction 1: PE with 61.78% likelihood
#   Prediction 2: PP with 24.98% likelihood
#   Prediction 3: PLA with 9.10% likelihood
#   Prediction 4: Other with 4.07% likelihood
# Sample 55: Correct, it was ALU
#   Prediction 1: ALU with 95.80% likelihood
#   Prediction 2: Other with 4.20% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 56: False, it was PLA
#   Prediction 1: PE with 57.76% likelihood
#   Prediction 2: PP with 27.34% likelihood
#   Prediction 3: PLA with 12.95% likelihood
#   Prediction 4: Other with 1.93% likelihood
# Sample 57: Correct, it was PE
#   Prediction 1: PE with 62.98% likelihood
#   Prediction 2: Other with 18.37% likelihood
#   Prediction 3: PP with 13.38% likelihood
#   Prediction 4: PLA with 4.90% likelihood
# Sample 58: False, it was PP
#   Prediction 1: PE with 61.40% likelihood
#   Prediction 2: PP with 25.91% likelihood
#   Prediction 3: PLA with 9.15% likelihood
#   Prediction 4: Other with 3.49% likelihood
# Sample 59: False, it was PP
#   Prediction 1: PE with 61.23% likelihood
#   Prediction 2: PP with 26.32% likelihood
#   Prediction 3: PLA with 9.17% likelihood
#   Prediction 4: Other with 3.24% likelihood
# Sample 60: False, it was PP
#   Prediction 1: PE with 62.20% likelihood
#   Prediction 2: PP with 25.95% likelihood
#   Prediction 3: PLA with 8.53% likelihood
#   Prediction 4: Other with 3.28% likelihood
# Sample 61: Correct, it was PE
#   Prediction 1: PE with 63.31% likelihood
#   Prediction 2: PP with 23.83% likelihood
#   Prediction 3: PLA with 8.45% likelihood
#   Prediction 4: Other with 4.34% likelihood
# Sample 62: Correct, it was Other
#   Prediction 1: Other with 99.87% likelihood
#   Prediction 2: PE with 0.10% likelihood
#   Prediction 3: PP with 0.01% likelihood
#   Prediction 4: PLA with 0.01% likelihood
# Sample 63: False, it was PLA
#   Prediction 1: PE with 55.78% likelihood
#   Prediction 2: PP with 29.08% likelihood
#   Prediction 3: PLA with 13.61% likelihood
#   Prediction 4: Other with 1.52% likelihood
# Sample 64: False, it was PP
#   Prediction 1: PE with 62.49% likelihood
#   Prediction 2: PP with 25.04% likelihood
#   Prediction 3: PLA with 8.46% likelihood
#   Prediction 4: Other with 3.97% likelihood
# Sample 65: Correct, it was PE
#   Prediction 1: PE with 60.74% likelihood
#   Prediction 2: PP with 26.44% likelihood
#   Prediction 3: PLA with 9.60% likelihood
#   Prediction 4: Other with 3.18% likelihood

# %%
# Get manual input from the user
manual_input = np.array([[1365889,2383139,3943193,6364119,6459881,3520279,1572135,859381,1734251,3039005,5108675,6392189,4980199,2559117,1249619]])  # Replace with your input values

# Normalize the manual input if needed
normalized_manual_input = ((manual_input - 0) / (8388608 - 0))

# Make predictions on manual input
predictions = model.predict(normalized_manual_input)
print(predictions)

# Get the top prediction
top_prediction = np.argmax(predictions)
print(top_prediction)

top_plastic_type = label_encoder.inverse_transform([top_prediction])[0]
print(top_plastic_type)
likelihood = predictions[0][top_prediction] * 100

# Display the prediction for manual input
print(f"Manual Input Prediction:")
print(f"  Prediction: {top_plastic_type} with {likelihood:.2f}% likelihood")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\kylej\dev\plastic-scanner\v1.1\Dataset 1\mlModel.ipynb Cell 7 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/mlModel.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> normalized_manual_input = ((manual_input - 0) / (8388608 - 0))
#       <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/mlModel.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a> # Make predictions on manual input
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/mlModel.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a> predictions = model.predict(normalized_manual_input)
#       <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/mlModel.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a> print(predictions)
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/mlModel.ipynb#W6sZmlsZQ%3D%3D?line=10'>11</a> # Get the top prediction
#
# File c:\Users\kylej\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_file6tz79y7o.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "c:\Users\kylej\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py", line 2341, in predict_function  *
#         return step_function(self, iterator)
#     File "c:\Users\kylej\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py", line 2327, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\kylej\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py", line 2315, in run_step  **
#         outputs = model.predict_step(data)
#     File "c:\Users\kylej\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py", line 2283, in predict_step
#         return self(x, training=False)
#     File "c:\Users\kylej\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "c:\Users\kylej\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_3" is incompatible with the layer: expected shape=(None, 8), found shape=(None, 15)

# %%
# Make predictions from manual
manual_input = np.array([[1365889,2383139,3943193,6364119,6459881,3520279,1572135,859381,1734251,3039005,5108675,6392189,4980199,2559117,1249619
]])

# Calculate the column-wise min and max values from your original dataset
min_values = [74296, 1151721, 2379300, 2748695, 3681840, 1997402, 1742243, 942818, 392145, 795677, 1406647, 2482140, 2630495, 1748806, 1249297]
max_values = [1773075, 3755206, 7787954, 8401566, 8405071, 8401566, 7232265, 8185313, 2080604, 4455589, 8402979, 8405071, 8405071, 8403086, 6084492]

# Convert the lists to numpy arrays
min_values = np.array(min_values)
max_values = np.array(max_values)

# Normalize the manual input using the calculated min and max values
normalized_manual_input = (manual_input - min_values) / (max_values - min_values)
# normalized_manual_input = np.array([[0.85611,0.63202,0.53239,0.41068,0.59174,0.39869,0.44654,0.42188,0.8826042,0.67470967,0.34701898,0.42024683,0.34977269,0.16862726,0.1471771]])

print(normalized_manual_input)

predictions = model.predict(normalized_manual_input)
predicted_labels = np.argmax(predictions, axis=1)
predicted_plastic_types = label_encoder.inverse_transform(predicted_labels)

    
## Calculate the percentage likelihoods
percentage_likelihoods = predictions * 100

# Get the indices of the top 4 predicted classes based on percentage likelihoods
top_indices = np.argsort(percentage_likelihoods[0])[::-1][:4]

# Get the labels for the top predicted classes
top_labels = label_encoder.inverse_transform(top_indices)

# Get the predicted label
predicted_label = top_labels[0]

# Get the true label from the original data (replace with your true label)
true_label = 'ALU'  # Replace with the true label

# Calculate the accuracy
if predicted_label == true_label:
    accuracy = "Correct"
else:
    accuracy = "False"

# Print the prediction, label, and accuracy
print(f"Predicted label: {predicted_label}")
print(f"True label: {true_label}")
print(f"Accuracy: {accuracy}")

# Print the percentages for each type
for label, likelihood in zip(top_labels, percentage_likelihoods[0][top_indices]):
    print(f"{label}: {likelihood:.2f}% likelihood")
# Out:
# [[ 7.60306667e-01  4.72988321e-01  2.89146431e-01  6.39573059e-01
#    5.88165389e-01  2.37794816e-01 -3.09849396e-02 -1.15204774e-02
#    7.94870352e-01  6.12945885e-01  5.29138411e-01  6.60154407e-01
#    4.06905026e-01  1.21772904e-01  6.65950391e-05]]
# 1/1 [==============================] - 0s 40ms/step
# Predicted label: PE
# True label: ALU
# Accuracy: False
# PE: 100.00% likelihood
# PP: 0.00% likelihood
# Other: 0.00% likelihood
# ALU: 0.00% likelihood
