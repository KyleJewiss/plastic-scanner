# %%
from tensorflow.keras.models import load_model
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import EarlyStopping

# Load the model
# model = load_model("15_point_plastic_classifier_model.keras")
model = load_model("15_point_plastic_classifier_model_NewPPFAT.keras")

# %%
# data = pd.read_csv("AllTogether.csv")
# data = pd.read_csv("resampled_dataset.csv")
data = pd.read_csv("resampled_datasetNewPP.csv")

# Separate features and labels
X = data.drop(columns=["Material_Type"])
y = data["Material_Type"]

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into train and test sets (Normal)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=54)


# Normalize the manual input if needed
X_test_normalized = ((X_test - 0) / (8410000 - 0))
# X_test_normalized = (X_test - X_train.min()) / (X_train.max() - X_train.min())

# Make predictions
predictions = model.predict(X_test_normalized)
predicted_labels = np.argmax(predictions, axis=1)
predicted_plastic_types = label_encoder.inverse_transform(predicted_labels)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_normalized, y_test)

# Make predictions
predictions = model.predict(X_test_normalized)

# Get the top 4 predictions for each sample
top_predictions = np.argsort(predictions, axis=1)[:, -4:]
top_labels = top_predictions[:, ::-1]

# print(predictions)

# Reshape the top_labels array to be 1D
top_labels_1d = top_labels.reshape(-1)

# Inverse transform the labels
top_plastic_types = label_encoder.inverse_transform(top_labels_1d)

# Reshape the top_plastic_types array back to 2D
top_plastic_types = top_plastic_types.reshape(top_labels.shape)

# Get the percentage likelihoods for the top 4 predictions
percentage_likelihoods = np.take_along_axis(predictions, top_predictions, axis=1) * 100

# Display test accuracy and example predictions
print(f"Test Accuracy: {test_accuracy}")
for i in range(len(predicted_labels)):
    num_predictions = min(4, len(np.unique(top_labels[i])))
    if y_test[i] == predicted_labels[i]:
        CorF = "Correct,"
    else:
        CorF = "False,"
    print(f"Sample {i+1}: {CorF} it was {label_encoder.classes_[y_test[i]]}")
    for j in range(num_predictions):
        print(f"  Prediction {j+1}: {top_plastic_types[i][j]} with {percentage_likelihoods[i][3-j]:.2f}% likelihood")
# Out:
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0277 - accuracy: 0.9900
# 7/7 [==============================] - 0s 2ms/step
# Test Accuracy: 0.9900000095367432
# Sample 1: Correct, it was PLA
#   Prediction 1: PLA with 99.99% likelihood
#   Prediction 2: PE with 0.01% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 2: Correct, it was PE
#   Prediction 1: PE with 99.71% likelihood
#   Prediction 2: PP with 0.29% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 3: Correct, it was PLA
#   Prediction 1: PLA with 99.96% likelihood
#   Prediction 2: PE with 0.02% likelihood
#   Prediction 3: Other with 0.02% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 4: Correct, it was PP
#   Prediction 1: PP with 97.64% likelihood
#   Prediction 2: PE with 2.36% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 5: Correct, it was ALU
#   Prediction 1: ALU with 99.99% likelihood
#   Prediction 2: Other with 0.01% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 6: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 7: Correct, it was PE
#   Prediction 1: PE with 98.11% likelihood
#   Prediction 2: PP with 1.86% likelihood
#   Prediction 3: PLA with 0.02% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 8: Correct, it was PLA
#   Prediction 1: PLA with 99.94% likelihood
#   Prediction 2: PE with 0.05% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 9: Correct, it was PLA
#   Prediction 1: PLA with 99.94% likelihood
#   Prediction 2: PE with 0.05% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 10: Correct, it was PE
#   Prediction 1: PE with 98.16% likelihood
#   Prediction 2: Other with 1.84% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 11: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 12: Correct, it was PE
#   Prediction 1: PE with 99.92% likelihood
#   Prediction 2: PP with 0.07% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 13: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 14: Correct, it was PP
#   Prediction 1: PP with 99.91% likelihood
#   Prediction 2: PE with 0.09% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 15: Correct, it was PP
#   Prediction 1: PP with 99.89% likelihood
#   Prediction 2: PE with 0.11% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 16: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 17: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 18: Correct, it was PP
#   Prediction 1: PP with 96.86% likelihood
#   Prediction 2: PE with 3.14% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 19: Correct, it was PE
#   Prediction 1: PE with 87.37% likelihood
#   Prediction 2: PLA with 12.63% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 20: Correct, it was PP
#   Prediction 1: PP with 99.68% likelihood
#   Prediction 2: PE with 0.32% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 21: Correct, it was Other
#   Prediction 1: Other with 99.80% likelihood
#   Prediction 2: ALU with 0.20% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 22: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 23: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 24: Correct, it was ALU
#   Prediction 1: ALU with 99.99% likelihood
#   Prediction 2: Other with 0.01% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
# Sample 25: Correct, it was PP
#   Prediction 1: PP with 80.93% likelihood
#   Prediction 2: PE with 19.07% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 26: Correct, it was PE
#   Prediction 1: PE with 98.74% likelihood
#   Prediction 2: PP with 1.18% likelihood
#   Prediction 3: PLA with 0.08% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 27: Correct, it was PP
#   Prediction 1: PP with 99.55% likelihood
#   Prediction 2: PE with 0.45% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 28: Correct, it was PLA
#   Prediction 1: PLA with 99.97% likelihood
#   Prediction 2: PE with 0.03% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 29: Correct, it was PLA
#   Prediction 1: PLA with 99.87% likelihood
#   Prediction 2: PE with 0.13% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 30: Correct, it was PE
#   Prediction 1: PE with 98.55% likelihood
#   Prediction 2: PP with 1.45% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 31: Correct, it was PLA
#   Prediction 1: PLA with 99.99% likelihood
#   Prediction 2: PE with 0.01% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 32: Correct, it was PE
#   Prediction 1: PE with 97.92% likelihood
#   Prediction 2: PP with 2.08% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 33: Correct, it was PLA
#   Prediction 1: PLA with 99.96% likelihood
#   Prediction 2: PE with 0.03% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 34: Correct, it was PP
#   Prediction 1: PP with 98.91% likelihood
#   Prediction 2: PE with 1.09% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 35: Correct, it was PE
#   Prediction 1: PE with 99.74% likelihood
#   Prediction 2: PP with 0.25% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 36: Correct, it was PE
#   Prediction 1: PE with 66.85% likelihood
#   Prediction 2: PP with 33.15% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 37: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 38: Correct, it was PLA
#   Prediction 1: PLA with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 39: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 40: Correct, it was PE
#   Prediction 1: PE with 99.95% likelihood
#   Prediction 2: PP with 0.05% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 41: Correct, it was PE
#   Prediction 1: PE with 99.95% likelihood
#   Prediction 2: PP with 0.05% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 42: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 43: Correct, it was PLA
#   Prediction 1: PLA with 98.68% likelihood
#   Prediction 2: PE with 1.03% likelihood
#   Prediction 3: Other with 0.29% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 44: Correct, it was PP
#   Prediction 1: PP with 90.63% likelihood
#   Prediction 2: PE with 9.37% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 45: Correct, it was PP
#   Prediction 1: PP with 98.92% likelihood
#   Prediction 2: PE with 1.07% likelihood
#   Prediction 3: PLA with 0.01% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 46: Correct, it was PE
#   Prediction 1: PE with 99.99% likelihood
#   Prediction 2: Other with 0.01% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 47: Correct, it was Other
#   Prediction 1: Other with 99.99% likelihood
#   Prediction 2: ALU with 0.01% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
# Sample 48: Correct, it was ALU
#   Prediction 1: ALU with 99.99% likelihood
#   Prediction 2: Other with 0.01% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 49: Correct, it was ALU
#   Prediction 1: ALU with 99.98% likelihood
#   Prediction 2: Other with 0.02% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 50: Correct, it was PE
#   Prediction 1: PE with 97.30% likelihood
#   Prediction 2: PLA with 2.70% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 51: Correct, it was ALU
#   Prediction 1: ALU with 99.99% likelihood
#   Prediction 2: Other with 0.01% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
# Sample 52: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 53: Correct, it was PP
#   Prediction 1: PP with 95.47% likelihood
#   Prediction 2: PE with 4.53% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 54: Correct, it was PLA
#   Prediction 1: PLA with 95.89% likelihood
#   Prediction 2: Other with 3.73% likelihood
#   Prediction 3: PE with 0.39% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 55: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 56: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 57: Correct, it was PP
#   Prediction 1: PP with 99.90% likelihood
#   Prediction 2: PE with 0.10% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 58: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 59: Correct, it was PE
#   Prediction 1: PE with 99.20% likelihood
#   Prediction 2: PP with 0.80% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 60: Correct, it was ALU
#   Prediction 1: ALU with 99.98% likelihood
#   Prediction 2: Other with 0.02% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 61: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 62: Correct, it was PP
#   Prediction 1: PP with 99.57% likelihood
#   Prediction 2: PE with 0.43% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 63: False, it was Other
#   Prediction 1: PLA with 66.96% likelihood
#   Prediction 2: Other with 32.58% likelihood
#   Prediction 3: PE with 0.46% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 64: Correct, it was PE
#   Prediction 1: PE with 99.99% likelihood
#   Prediction 2: PP with 0.01% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 65: Correct, it was PLA
#   Prediction 1: PLA with 99.99% likelihood
#   Prediction 2: PE with 0.01% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 66: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 67: Correct, it was PP
#   Prediction 1: PP with 97.60% likelihood
#   Prediction 2: PE with 2.40% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 68: Correct, it was ALU
#   Prediction 1: ALU with 99.99% likelihood
#   Prediction 2: Other with 0.01% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 69: Correct, it was PLA
#   Prediction 1: PLA with 99.99% likelihood
#   Prediction 2: PE with 0.01% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 70: Correct, it was PE
#   Prediction 1: PE with 99.84% likelihood
#   Prediction 2: PP with 0.16% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 71: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 72: Correct, it was PLA
#   Prediction 1: PLA with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 73: Correct, it was PLA
#   Prediction 1: PLA with 96.83% likelihood
#   Prediction 2: Other with 2.24% likelihood
#   Prediction 3: PE with 0.93% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 74: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 75: Correct, it was Other
#   Prediction 1: Other with 99.92% likelihood
#   Prediction 2: PE with 0.08% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 76: Correct, it was PP
#   Prediction 1: PP with 94.69% likelihood
#   Prediction 2: PE with 5.15% likelihood
#   Prediction 3: PLA with 0.16% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 77: Correct, it was PE
#   Prediction 1: PE with 95.31% likelihood
#   Prediction 2: PLA with 4.10% likelihood
#   Prediction 3: Other with 0.59% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 78: Correct, it was PE
#   Prediction 1: PE with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 79: Correct, it was ALU
#   Prediction 1: ALU with 99.99% likelihood
#   Prediction 2: Other with 0.01% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
# Sample 80: Correct, it was ALU
#   Prediction 1: ALU with 99.92% likelihood
#   Prediction 2: Other with 0.08% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 81: Correct, it was PP
#   Prediction 1: PP with 98.03% likelihood
#   Prediction 2: PE with 1.97% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 82: False, it was PE
#   Prediction 1: PLA with 66.64% likelihood
#   Prediction 2: PE with 33.05% likelihood
#   Prediction 3: Other with 0.31% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 83: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 84: Correct, it was PE
#   Prediction 1: PE with 97.68% likelihood
#   Prediction 2: PP with 2.25% likelihood
#   Prediction 3: PLA with 0.07% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 85: Correct, it was PE
#   Prediction 1: PE with 99.16% likelihood
#   Prediction 2: PP with 0.51% likelihood
#   Prediction 3: PLA with 0.33% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 86: Correct, it was PLA
#   Prediction 1: PLA with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 87: Correct, it was PLA
#   Prediction 1: PLA with 93.53% likelihood
#   Prediction 2: Other with 6.07% likelihood
#   Prediction 3: PE with 0.40% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 88: Correct, it was PP
#   Prediction 1: PP with 97.87% likelihood
#   Prediction 2: PE with 2.13% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 89: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 90: Correct, it was PE
#   Prediction 1: PE with 99.94% likelihood
#   Prediction 2: PP with 0.06% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 91: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 92: Correct, it was PE
#   Prediction 1: PE with 99.99% likelihood
#   Prediction 2: PLA with 0.01% likelihood
#   Prediction 3: PP with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 93: Correct, it was Other
#   Prediction 1: Other with 99.98% likelihood
#   Prediction 2: PE with 0.02% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 94: Correct, it was ALU
#   Prediction 1: ALU with 99.99% likelihood
#   Prediction 2: Other with 0.01% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
# Sample 95: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 96: Correct, it was PE
#   Prediction 1: PE with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 97: Correct, it was Other
#   Prediction 1: Other with 99.99% likelihood
#   Prediction 2: ALU with 0.01% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
# Sample 98: Correct, it was PLA
#   Prediction 1: PLA with 99.69% likelihood
#   Prediction 2: PE with 0.30% likelihood
#   Prediction 3: Other with 0.01% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 99: Correct, it was PLA
#   Prediction 1: PLA with 99.89% likelihood
#   Prediction 2: PE with 0.11% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 100: Correct, it was PP
#   Prediction 1: PP with 99.38% likelihood
#   Prediction 2: PE with 0.62% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 101: Correct, it was PP
#   Prediction 1: PP with 99.84% likelihood
#   Prediction 2: PE with 0.16% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 102: Correct, it was PLA
#   Prediction 1: PLA with 99.95% likelihood
#   Prediction 2: PE with 0.05% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 103: Correct, it was PLA
#   Prediction 1: PLA with 99.99% likelihood
#   Prediction 2: PE with 0.01% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 104: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 105: Correct, it was PLA
#   Prediction 1: PLA with 99.77% likelihood
#   Prediction 2: PE with 0.16% likelihood
#   Prediction 3: Other with 0.07% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 106: Correct, it was PLA
#   Prediction 1: PLA with 99.86% likelihood
#   Prediction 2: PE with 0.12% likelihood
#   Prediction 3: Other with 0.02% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 107: Correct, it was PP
#   Prediction 1: PP with 87.11% likelihood
#   Prediction 2: PE with 12.88% likelihood
#   Prediction 3: PLA with 0.01% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 108: Correct, it was PE
#   Prediction 1: PE with 93.07% likelihood
#   Prediction 2: PLA with 6.58% likelihood
#   Prediction 3: Other with 0.35% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 109: Correct, it was Other
#   Prediction 1: Other with 99.98% likelihood
#   Prediction 2: PE with 0.01% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 110: Correct, it was ALU
#   Prediction 1: ALU with 99.98% likelihood
#   Prediction 2: Other with 0.02% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 111: Correct, it was ALU
#   Prediction 1: ALU with 99.93% likelihood
#   Prediction 2: Other with 0.07% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 112: Correct, it was PP
#   Prediction 1: PP with 99.76% likelihood
#   Prediction 2: PE with 0.24% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 113: Correct, it was PE
#   Prediction 1: PE with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 114: Correct, it was PP
#   Prediction 1: PP with 99.52% likelihood
#   Prediction 2: PE with 0.48% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 115: Correct, it was PE
#   Prediction 1: PE with 98.78% likelihood
#   Prediction 2: PP with 1.22% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 116: Correct, it was PE
#   Prediction 1: PE with 99.94% likelihood
#   Prediction 2: PP with 0.06% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 117: Correct, it was PE
#   Prediction 1: PE with 99.79% likelihood
#   Prediction 2: PP with 0.21% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 118: Correct, it was ALU
#   Prediction 1: ALU with 99.97% likelihood
#   Prediction 2: Other with 0.03% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 119: Correct, it was PLA
#   Prediction 1: PLA with 93.08% likelihood
#   Prediction 2: Other with 6.52% likelihood
#   Prediction 3: PE with 0.39% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 120: Correct, it was PP
#   Prediction 1: PP with 99.68% likelihood
#   Prediction 2: PE with 0.32% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 121: Correct, it was PE
#   Prediction 1: PE with 99.38% likelihood
#   Prediction 2: PP with 0.57% likelihood
#   Prediction 3: PLA with 0.03% likelihood
#   Prediction 4: Other with 0.02% likelihood
# Sample 122: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 123: Correct, it was PE
#   Prediction 1: PE with 99.40% likelihood
#   Prediction 2: Other with 0.60% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 124: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 125: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PLA with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
# Sample 126: Correct, it was PE
#   Prediction 1: PE with 99.98% likelihood
#   Prediction 2: PP with 0.02% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 127: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PLA with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
# Sample 128: Correct, it was PP
#   Prediction 1: PP with 99.53% likelihood
#   Prediction 2: PE with 0.47% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 129: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 130: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 131: Correct, it was PLA
#   Prediction 1: PLA with 99.95% likelihood
#   Prediction 2: PE with 0.03% likelihood
#   Prediction 3: Other with 0.02% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 132: Correct, it was PP
#   Prediction 1: PP with 92.31% likelihood
#   Prediction 2: PE with 7.61% likelihood
#   Prediction 3: PLA with 0.08% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 133: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 134: Correct, it was PP
#   Prediction 1: PP with 99.01% likelihood
#   Prediction 2: PE with 0.99% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 135: Correct, it was PP
#   Prediction 1: PP with 96.75% likelihood
#   Prediction 2: PE with 3.25% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 136: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 137: Correct, it was PE
#   Prediction 1: PE with 99.79% likelihood
#   Prediction 2: PLA with 0.16% likelihood
#   Prediction 3: PP with 0.05% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 138: Correct, it was PP
#   Prediction 1: PP with 99.77% likelihood
#   Prediction 2: PE with 0.23% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 139: Correct, it was PLA
#   Prediction 1: PLA with 99.95% likelihood
#   Prediction 2: PE with 0.05% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 140: Correct, it was ALU
#   Prediction 1: ALU with 99.99% likelihood
#   Prediction 2: Other with 0.01% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
# Sample 141: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 142: Correct, it was ALU
#   Prediction 1: ALU with 99.99% likelihood
#   Prediction 2: Other with 0.01% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
# Sample 143: Correct, it was PP
#   Prediction 1: PP with 96.74% likelihood
#   Prediction 2: PE with 3.26% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 144: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 145: Correct, it was PE
#   Prediction 1: PE with 93.43% likelihood
#   Prediction 2: PP with 6.56% likelihood
#   Prediction 3: PLA with 0.01% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 146: Correct, it was PLA
#   Prediction 1: PLA with 99.77% likelihood
#   Prediction 2: PE with 0.22% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 147: Correct, it was PLA
#   Prediction 1: PLA with 99.88% likelihood
#   Prediction 2: Other with 0.12% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 148: Correct, it was PP
#   Prediction 1: PP with 99.52% likelihood
#   Prediction 2: PE with 0.48% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 149: Correct, it was PP
#   Prediction 1: PP with 99.85% likelihood
#   Prediction 2: PE with 0.15% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 150: Correct, it was PLA
#   Prediction 1: PLA with 99.95% likelihood
#   Prediction 2: PE with 0.05% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 151: Correct, it was PE
#   Prediction 1: PE with 94.69% likelihood
#   Prediction 2: PLA with 2.84% likelihood
#   Prediction 3: Other with 2.47% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 152: Correct, it was PLA
#   Prediction 1: PLA with 96.35% likelihood
#   Prediction 2: Other with 3.18% likelihood
#   Prediction 3: PE with 0.47% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 153: Correct, it was Other
#   Prediction 1: Other with 99.98% likelihood
#   Prediction 2: PE with 0.02% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 154: Correct, it was PE
#   Prediction 1: PE with 99.98% likelihood
#   Prediction 2: PP with 0.02% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 155: Correct, it was PE
#   Prediction 1: PE with 98.82% likelihood
#   Prediction 2: PP with 1.15% likelihood
#   Prediction 3: PLA with 0.03% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 156: Correct, it was Other
#   Prediction 1: Other with 99.75% likelihood
#   Prediction 2: ALU with 0.25% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 157: Correct, it was PP
#   Prediction 1: PP with 95.00% likelihood
#   Prediction 2: PE with 4.99% likelihood
#   Prediction 3: PLA with 0.01% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 158: Correct, it was PP
#   Prediction 1: PP with 99.93% likelihood
#   Prediction 2: PE with 0.07% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 159: Correct, it was PLA
#   Prediction 1: PLA with 99.95% likelihood
#   Prediction 2: PE with 0.04% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 160: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 161: Correct, it was PLA
#   Prediction 1: PLA with 99.99% likelihood
#   Prediction 2: Other with 0.01% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 162: Correct, it was PP
#   Prediction 1: PP with 99.76% likelihood
#   Prediction 2: PE with 0.24% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 163: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 164: Correct, it was PP
#   Prediction 1: PP with 98.98% likelihood
#   Prediction 2: PE with 1.01% likelihood
#   Prediction 3: PLA with 0.01% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 165: Correct, it was PP
#   Prediction 1: PP with 97.46% likelihood
#   Prediction 2: PE with 2.54% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 166: Correct, it was PLA
#   Prediction 1: PLA with 99.69% likelihood
#   Prediction 2: PE with 0.22% likelihood
#   Prediction 3: Other with 0.08% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 167: Correct, it was ALU
#   Prediction 1: ALU with 99.97% likelihood
#   Prediction 2: Other with 0.03% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 168: Correct, it was PE
#   Prediction 1: PE with 97.34% likelihood
#   Prediction 2: PP with 2.62% likelihood
#   Prediction 3: PLA with 0.04% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 169: Correct, it was PLA
#   Prediction 1: PLA with 99.95% likelihood
#   Prediction 2: Other with 0.05% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 170: Correct, it was Other
#   Prediction 1: Other with 99.55% likelihood
#   Prediction 2: PLA with 0.43% likelihood
#   Prediction 3: PE with 0.02% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 171: Correct, it was PP
#   Prediction 1: PP with 94.65% likelihood
#   Prediction 2: PE with 5.35% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 172: Correct, it was PP
#   Prediction 1: PP with 97.02% likelihood
#   Prediction 2: PE with 2.98% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 173: Correct, it was PE
#   Prediction 1: PE with 54.71% likelihood
#   Prediction 2: PP with 45.28% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 174: Correct, it was Other
#   Prediction 1: Other with 99.46% likelihood
#   Prediction 2: PE with 0.54% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 175: Correct, it was PLA
#   Prediction 1: PLA with 99.99% likelihood
#   Prediction 2: PE with 0.01% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 176: Correct, it was PLA
#   Prediction 1: PLA with 99.91% likelihood
#   Prediction 2: PE with 0.08% likelihood
#   Prediction 3: Other with 0.01% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 177: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 178: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 179: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 180: Correct, it was PE
#   Prediction 1: PE with 89.77% likelihood
#   Prediction 2: PLA with 10.23% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 181: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 182: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 183: Correct, it was PE
#   Prediction 1: PE with 99.81% likelihood
#   Prediction 2: PLA with 0.14% likelihood
#   Prediction 3: PP with 0.06% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 184: Correct, it was PP
#   Prediction 1: PP with 87.92% likelihood
#   Prediction 2: PE with 12.08% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 185: Correct, it was PLA
#   Prediction 1: PLA with 99.94% likelihood
#   Prediction 2: PE with 0.06% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 186: Correct, it was PLA
#   Prediction 1: PLA with 99.86% likelihood
#   Prediction 2: PE with 0.12% likelihood
#   Prediction 3: Other with 0.02% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 187: Correct, it was PE
#   Prediction 1: PE with 99.89% likelihood
#   Prediction 2: PLA with 0.11% likelihood
#   Prediction 3: PP with 0.01% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 188: Correct, it was Other
#   Prediction 1: Other with 99.99% likelihood
#   Prediction 2: PE with 0.01% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 189: Correct, it was PLA
#   Prediction 1: PLA with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 190: Correct, it was PLA
#   Prediction 1: PLA with 99.99% likelihood
#   Prediction 2: Other with 0.01% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 191: Correct, it was ALU
#   Prediction 1: ALU with 99.98% likelihood
#   Prediction 2: Other with 0.02% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 192: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 193: Correct, it was PP
#   Prediction 1: PP with 96.68% likelihood
#   Prediction 2: PE with 3.32% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 194: Correct, it was ALU
#   Prediction 1: ALU with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 195: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 196: Correct, it was PP
#   Prediction 1: PP with 98.63% likelihood
#   Prediction 2: PE with 1.37% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 197: Correct, it was PP
#   Prediction 1: PP with 98.98% likelihood
#   Prediction 2: PE with 1.02% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 198: Correct, it was ALU
#   Prediction 1: ALU with 99.99% likelihood
#   Prediction 2: Other with 0.01% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
# Sample 199: Correct, it was ALU
#   Prediction 1: ALU with 99.99% likelihood
#   Prediction 2: Other with 0.01% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
# Sample 200: Correct, it was PLA
#   Prediction 1: PLA with 97.78% likelihood
#   Prediction 2: Other with 2.22% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood

# %%
exclude_alu_indices = y != 'ALU'
X_filtered = X[exclude_alu_indices]
y_filtered = y_encoded[exclude_alu_indices]
# Split the filtered data into train and test sets (Filtered ALU)
X_train, X_test, y_train, y_test = train_test_split(X_filtered, y_filtered, test_size=0.2, random_state=50)
#features
X_test_normalized = ((X_test - 0) / (8410000 - 0))

# Make predictions
predictions = model.predict(X_test_normalized)
predicted_labels = np.argmax(predictions, axis=1)
predicted_plastic_types = label_encoder.inverse_transform(predicted_labels)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_normalized, y_test)

# Make predictions
predictions = model.predict(X_test_normalized)

# Get the top 4 predictions for each sample
top_predictions = np.argsort(predictions, axis=1)[:, -4:]
top_labels = top_predictions[:, ::-1]

# print(predictions)

# Reshape the top_labels array to be 1D
top_labels_1d = top_labels.reshape(-1)

# Inverse transform the labels
top_plastic_types = label_encoder.inverse_transform(top_labels_1d)

# Reshape the top_plastic_types array back to 2D
top_plastic_types = top_plastic_types.reshape(top_labels.shape)

# Get the percentage likelihoods for the top 4 predictions
percentage_likelihoods = np.take_along_axis(predictions, top_predictions, axis=1) * 100

# Display test accuracy and example predictions
print(f"Test Accuracy: {test_accuracy}")
for i in range(len(predicted_labels)):
    num_predictions = min(4, len(np.unique(top_labels[i])))
    if y_test[i] == predicted_labels[i]:
        CorF = "Correct,"
    else:
        CorF = "False,"
    print(f"Sample {i+1}: {CorF} it was {label_encoder.classes_[y_test[i]]}")
    for j in range(num_predictions):
        print(f"  Prediction {j+1}: {top_plastic_types[i][j]} with {percentage_likelihoods[i][3-j]:.2f}% likelihood")
# Out:
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 1.0000
# 5/5 [==============================] - 0s 1ms/step
# Test Accuracy: 1.0
# Sample 1: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 2: Correct, it was PE
#   Prediction 1: PE with 100.00% likelihood
#   Prediction 2: PLA with 0.00% likelihood
#   Prediction 3: PP with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 3: Correct, it was PLA
#   Prediction 1: PLA with 99.99% likelihood
#   Prediction 2: PE with 0.01% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 4: Correct, it was PP
#   Prediction 1: PP with 90.71% likelihood
#   Prediction 2: PE with 9.29% likelihood
#   Prediction 3: PLA with 0.01% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 5: Correct, it was PE
#   Prediction 1: PE with 85.62% likelihood
#   Prediction 2: PP with 14.21% likelihood
#   Prediction 3: PLA with 0.17% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 6: Correct, it was PP
#   Prediction 1: PP with 95.47% likelihood
#   Prediction 2: PE with 4.53% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 7: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 8: Correct, it was PLA
#   Prediction 1: PLA with 99.90% likelihood
#   Prediction 2: PE with 0.10% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 9: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 10: Correct, it was PP
#   Prediction 1: PP with 99.64% likelihood
#   Prediction 2: PE with 0.36% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 11: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 12: Correct, it was PP
#   Prediction 1: PP with 98.49% likelihood
#   Prediction 2: PE with 1.51% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 13: Correct, it was PP
#   Prediction 1: PP with 99.19% likelihood
#   Prediction 2: PE with 0.81% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 14: Correct, it was PE
#   Prediction 1: PE with 99.75% likelihood
#   Prediction 2: PLA with 0.25% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 15: Correct, it was PP
#   Prediction 1: PP with 97.57% likelihood
#   Prediction 2: PE with 2.43% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 16: Correct, it was PLA
#   Prediction 1: PLA with 99.95% likelihood
#   Prediction 2: PE with 0.03% likelihood
#   Prediction 3: Other with 0.02% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 17: Correct, it was PP
#   Prediction 1: PP with 97.99% likelihood
#   Prediction 2: PE with 2.01% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 18: Correct, it was PE
#   Prediction 1: PE with 98.32% likelihood
#   Prediction 2: PP with 1.68% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 19: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 20: Correct, it was PLA
#   Prediction 1: PLA with 96.30% likelihood
#   Prediction 2: Other with 3.02% likelihood
#   Prediction 3: PE with 0.69% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 21: Correct, it was PLA
#   Prediction 1: PLA with 88.60% likelihood
#   Prediction 2: PE with 10.06% likelihood
#   Prediction 3: Other with 1.35% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 22: Correct, it was PP
#   Prediction 1: PP with 99.95% likelihood
#   Prediction 2: PE with 0.05% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 23: Correct, it was PLA
#   Prediction 1: PLA with 99.77% likelihood
#   Prediction 2: PE with 0.22% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 24: Correct, it was PE
#   Prediction 1: PE with 99.74% likelihood
#   Prediction 2: Other with 0.26% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 25: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 26: Correct, it was PLA
#   Prediction 1: PLA with 94.51% likelihood
#   Prediction 2: Other with 5.08% likelihood
#   Prediction 3: PE with 0.41% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 27: Correct, it was PP
#   Prediction 1: PP with 97.01% likelihood
#   Prediction 2: PE with 2.98% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 28: Correct, it was PLA
#   Prediction 1: PLA with 99.99% likelihood
#   Prediction 2: PE with 0.01% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 29: Correct, it was PE
#   Prediction 1: PE with 91.42% likelihood
#   Prediction 2: PP with 8.58% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 30: Correct, it was PP
#   Prediction 1: PP with 60.62% likelihood
#   Prediction 2: PE with 39.33% likelihood
#   Prediction 3: PLA with 0.04% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 31: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 32: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 33: Correct, it was PLA
#   Prediction 1: PLA with 99.88% likelihood
#   Prediction 2: Other with 0.12% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 34: Correct, it was PE
#   Prediction 1: PE with 99.96% likelihood
#   Prediction 2: Other with 0.04% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 35: Correct, it was PE
#   Prediction 1: PE with 97.68% likelihood
#   Prediction 2: PP with 2.25% likelihood
#   Prediction 3: PLA with 0.07% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 36: Correct, it was PE
#   Prediction 1: PE with 100.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 37: Correct, it was PE
#   Prediction 1: PE with 99.95% likelihood
#   Prediction 2: PP with 0.05% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 38: Correct, it was PLA
#   Prediction 1: PLA with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 39: Correct, it was PP
#   Prediction 1: PP with 81.21% likelihood
#   Prediction 2: PE with 18.77% likelihood
#   Prediction 3: PLA with 0.01% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 40: Correct, it was Other
#   Prediction 1: Other with 98.62% likelihood
#   Prediction 2: PE with 1.38% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 41: Correct, it was PE
#   Prediction 1: PE with 99.63% likelihood
#   Prediction 2: PP with 0.22% likelihood
#   Prediction 3: PLA with 0.15% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 42: Correct, it was PLA
#   Prediction 1: PLA with 99.46% likelihood
#   Prediction 2: PE with 0.53% likelihood
#   Prediction 3: Other with 0.01% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 43: Correct, it was PP
#   Prediction 1: PP with 99.84% likelihood
#   Prediction 2: PE with 0.16% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 44: Correct, it was PLA
#   Prediction 1: PLA with 99.75% likelihood
#   Prediction 2: PE with 0.25% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 45: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 46: Correct, it was PP
#   Prediction 1: PP with 91.49% likelihood
#   Prediction 2: PE with 8.37% likelihood
#   Prediction 3: PLA with 0.14% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 47: Correct, it was PP
#   Prediction 1: PP with 99.57% likelihood
#   Prediction 2: PE with 0.43% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 48: Correct, it was PE
#   Prediction 1: PE with 99.94% likelihood
#   Prediction 2: Other with 0.06% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 49: Correct, it was PE
#   Prediction 1: PE with 99.66% likelihood
#   Prediction 2: PLA with 0.28% likelihood
#   Prediction 3: PP with 0.06% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 50: Correct, it was PLA
#   Prediction 1: PLA with 99.95% likelihood
#   Prediction 2: PE with 0.05% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 51: Correct, it was PP
#   Prediction 1: PP with 99.93% likelihood
#   Prediction 2: PE with 0.07% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 52: Correct, it was PP
#   Prediction 1: PP with 99.93% likelihood
#   Prediction 2: PE with 0.07% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 53: Correct, it was PP
#   Prediction 1: PP with 99.68% likelihood
#   Prediction 2: PE with 0.32% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 54: Correct, it was PE
#   Prediction 1: PE with 97.92% likelihood
#   Prediction 2: PP with 2.08% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 55: Correct, it was PLA
#   Prediction 1: PLA with 99.95% likelihood
#   Prediction 2: Other with 0.05% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 56: Correct, it was PE
#   Prediction 1: PE with 97.06% likelihood
#   Prediction 2: Other with 2.90% likelihood
#   Prediction 3: PLA with 0.03% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 57: Correct, it was PE
#   Prediction 1: PE with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 58: Correct, it was PLA
#   Prediction 1: PLA with 99.94% likelihood
#   Prediction 2: PE with 0.05% likelihood
#   Prediction 3: Other with 0.02% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 59: Correct, it was PP
#   Prediction 1: PP with 99.54% likelihood
#   Prediction 2: PE with 0.46% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 60: Correct, it was PLA
#   Prediction 1: PLA with 99.89% likelihood
#   Prediction 2: PE with 0.11% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 61: Correct, it was PE
#   Prediction 1: PE with 99.96% likelihood
#   Prediction 2: PLA with 0.02% likelihood
#   Prediction 3: Other with 0.02% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 62: Correct, it was PE
#   Prediction 1: PE with 99.02% likelihood
#   Prediction 2: PP with 0.95% likelihood
#   Prediction 3: PLA with 0.03% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 63: Correct, it was PP
#   Prediction 1: PP with 79.15% likelihood
#   Prediction 2: PE with 20.85% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 64: Correct, it was PP
#   Prediction 1: PP with 99.43% likelihood
#   Prediction 2: PE with 0.57% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 65: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 66: Correct, it was PP
#   Prediction 1: PP with 95.32% likelihood
#   Prediction 2: PE with 4.68% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 67: Correct, it was PLA
#   Prediction 1: PLA with 99.87% likelihood
#   Prediction 2: PE with 0.09% likelihood
#   Prediction 3: Other with 0.04% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 68: Correct, it was PLA
#   Prediction 1: PLA with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 69: Correct, it was PE
#   Prediction 1: PE with 99.86% likelihood
#   Prediction 2: PP with 0.06% likelihood
#   Prediction 3: Other with 0.05% likelihood
#   Prediction 4: PLA with 0.03% likelihood
# Sample 70: Correct, it was PE
#   Prediction 1: PE with 99.16% likelihood
#   Prediction 2: PP with 0.51% likelihood
#   Prediction 3: PLA with 0.33% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 71: Correct, it was PLA
#   Prediction 1: PLA with 99.52% likelihood
#   Prediction 2: PE with 0.47% likelihood
#   Prediction 3: Other with 0.01% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 72: Correct, it was Other
#   Prediction 1: Other with 99.88% likelihood
#   Prediction 2: ALU with 0.12% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 73: Correct, it was PP
#   Prediction 1: PP with 99.54% likelihood
#   Prediction 2: PE with 0.46% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 74: Correct, it was PP
#   Prediction 1: PP with 98.52% likelihood
#   Prediction 2: PE with 1.48% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 75: Correct, it was PP
#   Prediction 1: PP with 99.95% likelihood
#   Prediction 2: PE with 0.05% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 76: Correct, it was PLA
#   Prediction 1: PLA with 99.92% likelihood
#   Prediction 2: PE with 0.08% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 77: Correct, it was Other
#   Prediction 1: Other with 99.83% likelihood
#   Prediction 2: PE with 0.17% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 78: Correct, it was Other
#   Prediction 1: Other with 99.51% likelihood
#   Prediction 2: PE with 0.49% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 79: Correct, it was PP
#   Prediction 1: PP with 97.58% likelihood
#   Prediction 2: PE with 2.39% likelihood
#   Prediction 3: PLA with 0.03% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 80: Correct, it was PP
#   Prediction 1: PP with 98.05% likelihood
#   Prediction 2: PE with 1.95% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 81: Correct, it was PE
#   Prediction 1: PE with 98.79% likelihood
#   Prediction 2: PP with 1.17% likelihood
#   Prediction 3: PLA with 0.03% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 82: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 83: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 84: Correct, it was PLA
#   Prediction 1: PLA with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 85: Correct, it was PE
#   Prediction 1: PE with 95.76% likelihood
#   Prediction 2: PP with 3.97% likelihood
#   Prediction 3: PLA with 0.27% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 86: Correct, it was PP
#   Prediction 1: PP with 99.83% likelihood
#   Prediction 2: PE with 0.17% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 87: Correct, it was PLA
#   Prediction 1: PLA with 99.99% likelihood
#   Prediction 2: PE with 0.01% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 88: Correct, it was PE
#   Prediction 1: PE with 97.65% likelihood
#   Prediction 2: Other with 2.35% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 89: Correct, it was PP
#   Prediction 1: PP with 96.74% likelihood
#   Prediction 2: PE with 3.26% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 90: Correct, it was PP
#   Prediction 1: PP with 90.63% likelihood
#   Prediction 2: PE with 9.37% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 91: Correct, it was PP
#   Prediction 1: PP with 99.57% likelihood
#   Prediction 2: PE with 0.43% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 92: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 93: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 94: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 95: Correct, it was PLA
#   Prediction 1: PLA with 99.96% likelihood
#   Prediction 2: PE with 0.03% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 96: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 97: Correct, it was PE
#   Prediction 1: PE with 100.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 98: Correct, it was PE
#   Prediction 1: PE with 93.43% likelihood
#   Prediction 2: PP with 6.56% likelihood
#   Prediction 3: PLA with 0.01% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 99: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 100: Correct, it was PE
#   Prediction 1: PE with 100.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 101: Correct, it was PP
#   Prediction 1: PP with 99.61% likelihood
#   Prediction 2: PE with 0.39% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 102: Correct, it was PE
#   Prediction 1: PE with 90.94% likelihood
#   Prediction 2: PP with 9.06% likelihood
#   Prediction 3: PLA with 0.01% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 103: Correct, it was PP
#   Prediction 1: PP with 99.85% likelihood
#   Prediction 2: PE with 0.15% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 104: Correct, it was PE
#   Prediction 1: PE with 99.92% likelihood
#   Prediction 2: PP with 0.07% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 105: Correct, it was PLA
#   Prediction 1: PLA with 99.86% likelihood
#   Prediction 2: PE with 0.12% likelihood
#   Prediction 3: Other with 0.02% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 106: Correct, it was PP
#   Prediction 1: PP with 99.83% likelihood
#   Prediction 2: PE with 0.17% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 107: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 108: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 109: Correct, it was PE
#   Prediction 1: PE with 99.99% likelihood
#   Prediction 2: PP with 0.01% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 110: Correct, it was PLA
#   Prediction 1: PLA with 99.99% likelihood
#   Prediction 2: PE with 0.01% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 111: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 112: Correct, it was PP
#   Prediction 1: PP with 98.39% likelihood
#   Prediction 2: PE with 1.61% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 113: Correct, it was PP
#   Prediction 1: PP with 98.98% likelihood
#   Prediction 2: PE with 1.01% likelihood
#   Prediction 3: PLA with 0.01% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 114: Correct, it was Other
#   Prediction 1: Other with 99.64% likelihood
#   Prediction 2: PLA with 0.35% likelihood
#   Prediction 3: PE with 0.01% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 115: Correct, it was Other
#   Prediction 1: Other with 99.99% likelihood
#   Prediction 2: PE with 0.01% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 116: Correct, it was PP
#   Prediction 1: PP with 99.90% likelihood
#   Prediction 2: PE with 0.10% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 117: Correct, it was PLA
#   Prediction 1: PLA with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 118: Correct, it was PP
#   Prediction 1: PP with 99.87% likelihood
#   Prediction 2: PE with 0.13% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 119: Correct, it was PE
#   Prediction 1: PE with 100.00% likelihood
#   Prediction 2: Other with 0.00% likelihood
#   Prediction 3: PP with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 120: Correct, it was PLA
#   Prediction 1: PLA with 99.83% likelihood
#   Prediction 2: PE with 0.17% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 121: Correct, it was PE
#   Prediction 1: PE with 99.55% likelihood
#   Prediction 2: PLA with 0.31% likelihood
#   Prediction 3: PP with 0.14% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 122: Correct, it was PE
#   Prediction 1: PE with 98.87% likelihood
#   Prediction 2: PP with 1.13% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 123: Correct, it was Other
#   Prediction 1: Other with 99.47% likelihood
#   Prediction 2: PE with 0.53% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 124: Correct, it was Other
#   Prediction 1: Other with 99.99% likelihood
#   Prediction 2: PE with 0.01% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 125: Correct, it was PLA
#   Prediction 1: PLA with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 126: Correct, it was PE
#   Prediction 1: PE with 99.99% likelihood
#   Prediction 2: PP with 0.01% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 127: Correct, it was PP
#   Prediction 1: PP with 97.00% likelihood
#   Prediction 2: PE with 2.99% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 128: Correct, it was PLA
#   Prediction 1: PLA with 99.94% likelihood
#   Prediction 2: PE with 0.05% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 129: Correct, it was PE
#   Prediction 1: PE with 100.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 130: Correct, it was PLA
#   Prediction 1: PLA with 99.75% likelihood
#   Prediction 2: PE with 0.25% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 131: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 132: Correct, it was PLA
#   Prediction 1: PLA with 99.99% likelihood
#   Prediction 2: PE with 0.01% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 133: Correct, it was PE
#   Prediction 1: PE with 93.50% likelihood
#   Prediction 2: PP with 6.44% likelihood
#   Prediction 3: PLA with 0.06% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 134: Correct, it was PP
#   Prediction 1: PP with 94.69% likelihood
#   Prediction 2: PE with 5.15% likelihood
#   Prediction 3: PLA with 0.16% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 135: Correct, it was PP
#   Prediction 1: PP with 99.76% likelihood
#   Prediction 2: PE with 0.24% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 136: Correct, it was PP
#   Prediction 1: PP with 99.72% likelihood
#   Prediction 2: PE with 0.28% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 137: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 138: Correct, it was PLA
#   Prediction 1: PLA with 95.40% likelihood
#   Prediction 2: PE with 4.55% likelihood
#   Prediction 3: Other with 0.05% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 139: Correct, it was PP
#   Prediction 1: PP with 99.89% likelihood
#   Prediction 2: PE with 0.11% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 140: Correct, it was Other
#   Prediction 1: Other with 99.96% likelihood
#   Prediction 2: ALU with 0.04% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
# Sample 141: Correct, it was PLA
#   Prediction 1: PLA with 98.08% likelihood
#   Prediction 2: PE with 1.92% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 142: Correct, it was PE
#   Prediction 1: PE with 94.69% likelihood
#   Prediction 2: PLA with 2.84% likelihood
#   Prediction 3: Other with 2.47% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 143: Correct, it was Other
#   Prediction 1: Other with 99.99% likelihood
#   Prediction 2: PE with 0.01% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 144: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 145: Correct, it was PLA
#   Prediction 1: PLA with 94.90% likelihood
#   Prediction 2: PE with 4.89% likelihood
#   Prediction 3: Other with 0.21% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 146: Correct, it was PLA
#   Prediction 1: PLA with 98.74% likelihood
#   Prediction 2: PE with 0.82% likelihood
#   Prediction 3: Other with 0.43% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 147: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 148: Correct, it was PLA
#   Prediction 1: PLA with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 149: Correct, it was PLA
#   Prediction 1: PLA with 99.99% likelihood
#   Prediction 2: Other with 0.01% likelihood
#   Prediction 3: PE with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 150: Correct, it was PLA
#   Prediction 1: PLA with 99.99% likelihood
#   Prediction 2: PE with 0.01% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
# Sample 151: Correct, it was PE
#   Prediction 1: PE with 100.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PLA with 0.00% likelihood
# Sample 152: Correct, it was PE
#   Prediction 1: PE with 91.95% likelihood
#   Prediction 2: PP with 8.05% likelihood
#   Prediction 3: PLA with 0.01% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 153: Correct, it was PP
#   Prediction 1: PP with 99.42% likelihood
#   Prediction 2: PE with 0.58% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 154: Correct, it was PP
#   Prediction 1: PP with 98.03% likelihood
#   Prediction 2: PE with 1.97% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 155: Correct, it was Other
#   Prediction 1: Other with 100.00% likelihood
#   Prediction 2: PLA with 0.00% likelihood
#   Prediction 3: ALU with 0.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
# Sample 156: Correct, it was PE
#   Prediction 1: PE with 98.43% likelihood
#   Prediction 2: PP with 0.84% likelihood
#   Prediction 3: PLA with 0.73% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 157: Correct, it was PP
#   Prediction 1: PP with 99.90% likelihood
#   Prediction 2: PE with 0.10% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 158: Correct, it was PE
#   Prediction 1: PE with 94.41% likelihood
#   Prediction 2: PP with 5.56% likelihood
#   Prediction 3: PLA with 0.03% likelihood
#   Prediction 4: Other with 0.00% likelihood
# Sample 159: Correct, it was Other
#   Prediction 1: Other with 99.83% likelihood
#   Prediction 2: PE with 0.17% likelihood
#   Prediction 3: PLA with 0.00% likelihood
#   Prediction 4: ALU with 0.00% likelihood
# Sample 160: Correct, it was PLA
#   Prediction 1: PLA with 100.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Other with 0.00% likelihood
#   Prediction 4: PP with 0.00% likelihood

# %%
# Get manual input from the user
manual_input = np.array([[1271389,2107581,3534859,5988057,6233631,3880377,1498541,985865,1561809,2707983,4719147,6111335,5063453,2701889,1262325]])  # Replace with your input values

# Normalize the manual input if needed
normalized_manual_input = ((manual_input - 0) / (8410000 - 0))

# Make predictions on manual input
predictions = model.predict(normalized_manual_input)
print(predictions)

# Get the top prediction
top_prediction = np.argmax(predictions)
print(top_prediction)

top_plastic_type = label_encoder.inverse_transform([top_prediction])[0]
print(top_plastic_type)
likelihood = predictions[0][top_prediction] * 100

# Display the prediction for manual input
print(f"Manual Input Prediction:")
print(f"  Prediction: {top_plastic_type} with {likelihood:.2f}% likelihood")
# Out:
# 1/1 [==============================] - 0s 53ms/step
# [[9.4345532e-14 2.6943423e-09 1.0437940e-02 2.1287291e-07 9.8956186e-01]]
# 4
# PP
# Manual Input Prediction:
#   Prediction: PP with 98.96% likelihood

# %%
import numpy as np  # Add this line to import the NumPy library
import serial
from sklearn.preprocessing import LabelEncoder


# Open the serial port
ser = serial.Serial('COM3', baudrate=115200)  # Adjust the baudrate as needed

# Initialize a variable to store the received data
received_data = ""

try:
    while True:
        # Read a line of data from the serial port (assuming data is sent as lines)
        line = ser.readline().decode('utf-8').strip()
        
        # Append the received line to the variable
        received_data += line

        # Split the received data into a list of numbers using a comma as the delimiter
        data_values = [float(val) for val in received_data.split(',')]

        # Convert the list of values into a NumPy array
        manual_input = np.array([data_values])

        # Normalize the manual input if needed
        normalized_manual_input = ((manual_input - 0) / (8410000 - 0))

        # Make predictions on manual input
        predictions = model.predict(normalized_manual_input)
        # print(predictions)

        # Get the top prediction
        top_prediction = np.argmax(predictions)
        print(top_prediction)

        top_plastic_type = label_encoder.inverse_transform([top_prediction])[0]
        print(top_plastic_type)
        likelihood = predictions[0][top_prediction] * 100

        # Display the prediction for manual input
        print(f"Manual Input Prediction:")
        print(f"  Prediction: {top_plastic_type} with {likelihood:.2f}% likelihood")

        received_data = ""

except KeyboardInterrupt:
    # Handle Ctrl+C to stop the loop gracefully
    pass

finally:
    # Close the serial port when done
    ser.close()

# Now, you can use the 'received_data' variable for further processing
print("total data:\n", received_data)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 4
# PP
# Manual Input Prediction:
#   Prediction: PP with 98.85% likelihood
# 1/1 [==============================] - 0s 25ms/step
# 2
# PE
# Manual Input Prediction:
#   Prediction: PE with 98.52% likelihood
# 1/1 [==============================] - 0s 25ms/step
# 4
# PP
# Manual Input Prediction:
#   Prediction: PP with 96.93% likelihood
# 1/1 [==============================] - 0s 22ms/step
# 4
# PP
# Manual Input Prediction:
#   Prediction: PP with 94.44% likelihood
# 1/1 [==============================] - 0s 34ms/step
# 2
# PE
# Manual Input Prediction:
#   Prediction: PE with 97.24% likelihood
# 1/1 [==============================] - 0s 25ms/step
# 2
# PE
# Manual Input Prediction:
#   Prediction: PE with 98.75% likelihood
# 1/1 [==============================] - 0s 22ms/step
# 4
# PP
# Manual Input Prediction:
#   Prediction: PP with 99.94% likelihood
# 1/1 [==============================] - 0s 27ms/step
# 4
# PP
# Manual Input Prediction:
#   Prediction: PP with 99.97% likelihood
# 1/1 [==============================] - 0s 25ms/step
# 2
# PE
# Manual Input Prediction:
#   Prediction: PE with 59.90% likelihood
# 1/1 [==============================] - 0s 26ms/step
# 2
# PE
# Manual Input Prediction:
#   Prediction: PE with 99.85% likelihood
# 1/1 [==============================] - 0s 25ms/step
# 2
# PE
# Manual Input Prediction:
#   Prediction: PE with 99.77% likelihood
# 1/1 [==============================] - 0s 22ms/step
# 2
# PE
# Manual Input Prediction:
#   Prediction: PE with 99.70% likelihood
# 1/1 [==============================] - 0s 21ms/step
# 4
# PP
# Manual Input Prediction:
#   Prediction: PP with 98.58% likelihood
# 1/1 [==============================] - 0s 25ms/step
# 2
# PE
# Manual Input Prediction:
#   Prediction: PE with 99.98% likelihood
# 1/1 [==============================] - 0s 21ms/step
# 2
# PE
# Manual Input Prediction:
#   Prediction: PE with 99.42% likelihood
# 1/1 [==============================] - 0s 22ms/step
# 4
# PP
# Manual Input Prediction:
#   Prediction: PP with 97.97% likelihood
# 1/1 [==============================] - 0s 24ms/step
# 2
# PE
# Manual Input Prediction:
#   Prediction: PE with 93.00% likelihood
# 1/1 [==============================] - 0s 25ms/step
# 2
# PE
# Manual Input Prediction:
#   Prediction: PE with 96.69% likelihood
# 1/1 [==============================] - 0s 27ms/step
# 4
# PP
# Manual Input Prediction:
#   Prediction: PP with 99.96% likelihood
# 1/1 [==============================] - 0s 26ms/step
# 4
# PP
# Manual Input Prediction:
#   Prediction: PP with 99.60% likelihood
# 1/1 [==============================] - 0s 29ms/step
# 4
# PP
# Manual Input Prediction:
#   Prediction: PP with 98.40% likelihood
# 1/1 [==============================] - 0s 25ms/step
# 2
# PE
# Manual Input Prediction:
#   Prediction: PE with 97.42% likelihood
# 1/1 [==============================] - 0s 29ms/step
# 2
# PE
# Manual Input Prediction:
#   Prediction: PE with 54.28% likelihood
# 1/1 [==============================] - 0s 23ms/step
# 2
# PE
# Manual Input Prediction:
#   Prediction: PE with 98.68% likelihood
# total data:

# %%
import numpy as np
import serial
import csv  # Import the csv module
from sklearn.preprocessing import LabelEncoder

# Open the serial port
ser = serial.Serial('COM3', baudrate=115200)  # Adjust the baudrate as needed

# Create and open a CSV file for writing
csv_file = open('diffTestPP.csv', 'w', newline='')
csv_writer = csv.writer(csv_file)

try:
    while True:
        # Read a line of data from the serial port (assuming data is sent as lines)
        line = ser.readline().decode('utf-8').strip()

        # Split the received data into a list of numbers using a comma as the delimiter
        data_values = [float(val) for val in line.split(',')]

        print(data_values)

        # Write the data values to the CSV file as a new row
        csv_writer.writerow(data_values)

except KeyboardInterrupt:
    # Handle Ctrl+C to stop the loop gracefully
    pass

finally:
    # Close the CSV file and the serial port when done
    csv_file.close()
    ser.close()

# The received data has been saved in the 'received_data.csv' file
print("Data saved to 'received_data.csv'")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\kylej\dev\plastic-scanner\v1.1\Dataset 1\testScanVsModel.ipynb Cell 6 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W5sZmlsZQ%3D%3D?line=15'>16</a> line = ser.readline().decode('utf-8').strip()
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W5sZmlsZQ%3D%3D?line=17'>18</a> # Split the received data into a list of numbers using a comma as the delimiter
# ---> <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W5sZmlsZQ%3D%3D?line=18'>19</a> data_values = [float(val) for val in line.split(',')]
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W5sZmlsZQ%3D%3D?line=20'>21</a> print(data_values)
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W5sZmlsZQ%3D%3D?line=22'>23</a> # Write the data values to the CSV file as a new row
#
# c:\Users\kylej\dev\plastic-scanner\v1.1\Dataset 1\testScanVsModel.ipynb Cell 6 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W5sZmlsZQ%3D%3D?line=15'>16</a> line = ser.readline().decode('utf-8').strip()
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W5sZmlsZQ%3D%3D?line=17'>18</a> # Split the received data into a list of numbers using a comma as the delimiter
# ---> <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W5sZmlsZQ%3D%3D?line=18'>19</a> data_values = [float(val) for val in line.split(',')]
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W5sZmlsZQ%3D%3D?line=20'>21</a> print(data_values)
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset%201/testScanVsModel.ipynb#W5sZmlsZQ%3D%3D?line=22'>23</a> # Write the data values to the CSV file as a new row
#
# ValueError: could not convert string to float: 'Initialising LCD'
