# %%
from tensorflow.keras.models import load_model
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import EarlyStopping

# Load the model
# model = load_model("15_point_plastic_classifier_model8.keras")
# model = load_model("15_point_plastic_classifier_model_30_09.keras")
# model = load_model("15_point_plastic_classifier_model_2_10_HvL.keras")
model = load_model("test_model.keras")

# %%
# data = pd.read_csv("test_resampled.csv")
# data = pd.read_csv("resampled_dataset8_PVC.csv")
data = pd.read_csv("AllTogetherHvL2.csv")

# Separate features and labels
X = data.drop(columns=["Material_Type"])
y = data["Material_Type"]

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# SERIAL ############################

import numpy as np  # Add this line to import the NumPy library
import serial
from sklearn.preprocessing import LabelEncoder


# Open the serial port
ser = serial.Serial('COM3', baudrate=115200)  # Adjust the baudrate as needed

# Initialize a variable to store the received data
received_data = ""

# print(label_encoder.classes_)

try:
    while True:
        # Read a line of data from the serial port (assuming data is sent as lines)
        line = ser.readline().decode('utf-8').strip()

        # Split the received data into a list of numbers using a comma as the delimiter
        data_values = [float(val) for val in line.split(',')]

        # Normalize the data values if needed
        normalized_data = [(val - 0) / (8410000 - 0) for val in data_values]

        print(normalized_data)

        # Make predictions on the normalized data
        predictions = model.predict([normalized_data])  # Convert normalized_data to a list

        # Format the model so that its easier to read in terminal 
        formatted_predictions = np.around(predictions, 4)

        # Get the top prediction
        top_prediction = np.argmax(predictions)

        # top_plastic_type = label_encoder.inverse_transform([top_prediction])[0]
        # print(top_plastic_type)
        # likelihood = predictions[0][top_prediction] * 100
        

        # if predictions.shape[1] == 6:
        #     plastic_types = ["HDPE", "LDPE", "PET", "PP", "PVC", "Unknown"]
        # else:
        #     plastic_types = ["PE", "PET", "PP", "PVC", "Unknown"]
        plastic_types = ["PE", "PET", "PLA", "PP", "PVC", "Unknown"]
        
        top_plastic_type = plastic_types[top_prediction]

        likelihood = predictions[0][top_prediction] * 100


        # Display the prediction for manual input
        print(f"Manual Input Prediction:")
        print(f"  Prediction: {top_plastic_type} with {likelihood:.2f}% likelihood")

        likelihood_str = round(likelihood)-1

        received_data = ""

        # Send the top plastic type back over serial
        # ser.write(top_plastic_type.encode('utf-8'))
        # ser.write(str(likelihood_str).encode('utf-8'))
        data_to_send = f"{top_plastic_type},{likelihood_str}"  # Combine the data fields with a comma delimiter
        ser.write(data_to_send.encode('utf-8'))

except KeyboardInterrupt:
    # Handle Ctrl+C to stop the loop gracefully
    pass

finally:
    # Close the serial port when done
    ser.close()

# Now, you can use the 'received_data' variable for further processing
print("total data:\n", received_data)
# Out:
# [0.19838180737217598, 0.34751474435196195, 0.5339133174791915, 0.8480771700356718, 0.8373570749108205, 0.4730600475624257, 0.2451126040428062, 0.11265219976218788, 0.2583304399524376, 0.42859060642092744, 0.688219857312723, 0.8448455410225921, 0.6581332936979786, 0.36313781212841856, 0.18006099881093937]
# 1/1 [==============================] - 0s 93ms/step
# Manual Input Prediction:
#   Prediction: PLA with 100.00% likelihood
# [0.08202651605231867, 0.187194887039239, 0.23903697978596908, 0.5602174791914387, 0.548428418549346, 0.3190384066587396, 0.16216444708680142, 0.08485219976218787, 0.12775065398335314, 0.2087344827586207, 0.40413400713436387, 0.5541865636147444, 0.4247442330558858, 0.24159536266349585, 0.12471902497027348]
# 1/1 [==============================] - 0s 61ms/step
# Manual Input Prediction:
#   Prediction: PVC with 99.71% likelihood
# [0.06314423305588585, 0.14988406658739595, 0.20726504161712248, 0.5236557669441142, 0.5329042806183115, 0.33815374554102257, 0.12958394768133175, 0.05451307966706302, 0.10215422116527943, 0.1744705112960761, 0.3643085612366231, 0.5325425683709869, 0.44077633769322233, 0.23554827586206897, 0.08926004756242568]
# 1/1 [==============================] - 0s 47ms/step
# Manual Input Prediction:
#   Prediction: PVC with 100.00% likelihood
# [0.30178989298454223, 0.5412005945303211, 0.892222711058264, 0.9944158145065398, 0.9945620689655172, 0.8654957193816885, 0.4160053507728894, 0.2001694411414982, 0.40312116527942926, 0.701238644470868, 0.9947047562425684, 0.99444887039239, 0.994659096313912, 0.6487701545778835, 0.3150593341260404]
# 1/1 [==============================] - 0s 46ms/step
# Manual Input Prediction:
#   Prediction: PE with 90.60% likelihood
# [0.09263888228299644, 0.1598809750297265, 0.2465294887039239, 0.38833923900118905, 0.3660719381688466, 0.20430927467300833, 0.10807241379310345, 0.06320487514863259, 0.1204821640903686, 0.19958038049940546, 0.318953983353151, 0.37903127229488703, 0.28335541022592153, 0.15425481569560048, 0.08585124851367419]
# 1/1 [==============================] - 0s 55ms/step
# Manual Input Prediction:
#   Prediction: PP with 70.59% likelihood
# [0.09082152199762188, 0.15614684898929845, 0.2446141498216409, 0.37840844233055887, 0.32937895362663494, 0.1693665873959572, 0.1136564803804994, 0.0717601664684899, 0.11957514863258026, 0.1997741973840666, 0.31554256837098693, 0.3576804994054697, 0.249828418549346, 0.1421730083234245, 0.09320820451843044]
# 1/1 [==============================] - 0s 44ms/step
# Manual Input Prediction:
#   Prediction: PE with 79.78% likelihood
# [0.16824720570749108, 0.28327003567181924, 0.4157625445897741, 0.5953665873959572, 0.5453185493460166, 0.30658656361474435, 0.15998133174791915, 0.07971831153388823, 0.21377609988109395, 0.33998537455410227, 0.5041128418549347, 0.5740717003567182, 0.42849048751486324, 0.23464197384066587, 0.12027265160523187]
# 1/1 [==============================] - 0s 45ms/step
# Manual Input Prediction:
#   Prediction: PP with 65.35% likelihood
# [0.16916730083234244, 0.28551355529131983, 0.4187910820451843, 0.597530677764566, 0.5415608799048751, 0.2999848989298454, 0.15809191438763376, 0.07874518430439953, 0.2154039239001189, 0.34270428061831154, 0.5064950059453032, 0.5723135552913199, 0.4215516052318668, 0.22941058263971462, 0.1188781212841855]
# 1/1 [==============================] - 0s 46ms/step
# Manual Input Prediction:
#   Prediction: PP with 61.04% likelihood
# [0.17140653983353152, 0.28872211652794294, 0.43015802615933413, 0.6188393579072533, 0.5355475624256837, 0.2991718192627824, 0.16482104637336503, 0.08316753864447086, 0.21788168846611178, 0.34949952437574316, 0.522684066587396, 0.5809411414982164, 0.4195706302021403, 0.23333258026159334, 0.12479013079667063]
# 1/1 [==============================] - 0s 53ms/step
# Manual Input Prediction:
#   Prediction: PP with 84.24% likelihood
# [0.17039988109393578, 0.28635850178359096, 0.4209473246135553, 0.5860148632580262, 0.5202571938168846, 0.29255089179548155, 0.15862508917954815, 0.08019512485136741, 0.21641747919143875, 0.34441105826397145, 0.5025851367419738, 0.55739774078478, 0.40896991676575506, 0.22682889417360286, 0.12005029726516052]
# 1/1 [==============================] - 0s 47ms/step
# Manual Input Prediction:
#   Prediction: PE with 83.61% likelihood
# [0.20119179548156957, 0.34030832342449463, 0.5224193816884661, 0.7417290130796671, 0.7245019024970274, 0.41376444708680143, 0.2150217598097503, 0.11898489892984543, 0.2537651605231867, 0.415507372175981, 0.6242583828775268, 0.7338170035671819, 0.5735661117717004, 0.3188614744351962, 0.16926575505350772]
# 1/1 [==============================] - 0s 47ms/step
# Manual Input Prediction:
#   Prediction: PE with 96.33% likelihood
# [0.14065243757431628, 0.25041391200951246, 0.3847756242568371, 0.4693573127229489, 0.577805112960761, 0.26592711058263974, 0.15312425683709868, 0.08201200951248513, 0.1878281807372176, 0.3117932223543401, 0.4199026159334126, 0.551259096313912, 0.3523627824019025, 0.20585576694411414, 0.11617728894173603]
# 1/1 [==============================] - 0s 45ms/step
# Manual Input Prediction:
#   Prediction: PE with 100.00% likelihood
# [0.1942576694411415, 0.3191035671819263, 0.4762453032104637, 0.5835473246135553, 0.5535254458977408, 0.27881605231866824, 0.165340903686088, 0.08040368608799049, 0.242425564803805, 0.38548382877526755, 0.5252674197384066, 0.5681768133174792, 0.4156923900118906, 0.22229857312722948, 0.12354898929845422]
# 1/1 [==============================] - 0s 43ms/step
# Manual Input Prediction:
#   Prediction: PE with 99.96% likelihood
# [0.02168026159334126, 0.0538871581450654, 0.06217063020214031, 0.16020677764565994, 0.22766837098692033, 0.16221082045184304, 0.06960820451843044, 0.03632092746730083, 0.03735184304399524, 0.05808858501783591, 0.11240463733650416, 0.19516682520808562, 0.19502390011890605, 0.1160807372175981, 0.053051010701545775]
# 1/1 [==============================] - 0s 46ms/step
# Manual Input Prediction:
#   Prediction: PLA with 67.40% likelihood
# [0.022861712247324615, 0.06279346016646849, 0.09482746730083234, 0.27405434007134366, 0.2795810939357907, 0.1601242568370987, 0.06627764565992865, 0.01712592152199762, 0.0411756242568371, 0.0772717003567182, 0.18444030915576695, 0.2777934601664685, 0.21955755053507728, 0.11260963139120095, 0.04137705112960761]
# 1/1 [==============================] - 0s 43ms/step
# Manual Input Prediction:
#   Prediction: PVC with 88.45% likelihood
# [0.04416420927467301, 0.08866052318668252, 0.13605172413793104, 0.27336777645659927, 0.27767574316290133, 0.16236206896551725, 0.06532758620689655, 0.018026991676575507, 0.06438727705112961, 0.11164244946492272, 0.20669381688466112, 0.2790053507728894, 0.22107384066587396, 0.11359274673008324, 0.04194970273483948]
# 1/1 [==============================] - 0s 46ms/step
# Manual Input Prediction:
#   Prediction: PVC with 99.97% likelihood
# [0.023261474435196196, 0.056706183115338885, 0.11447883472057074, 0.22960606420927468, 0.1968410225921522, 0.1579152199762188, 0.05594542211652794, 0.01655683709869203, 0.038115219976218785, 0.08314066587395957, 0.17166718192627825, 0.2163049940546968, 0.18201200951248514, 0.10960107015457789, 0.03654447086801427]
# 1/1 [==============================] - 0s 48ms/step
# Manual Input Prediction:
#   Prediction: PET with 98.48% likelihood
# [0.040369916765755055, 0.0742486325802616, 0.10935969084423305, 0.173289774078478, 0.1977268727705113, 0.17473234244946492, 0.0637718192627824, 0.0339230677764566, 0.05454542211652794, 0.08944316290130797, 0.14063151010701547, 0.18686218787158146, 0.18797966706302022, 0.12012092746730084, 0.04889334126040428]
# 1/1 [==============================] - 0s 49ms/step
# Manual Input Prediction:
#   Prediction: PVC with 73.29% likelihood
# [0.031315457788347205, 0.0675294887039239, 0.09126218787158145, 0.17250856123662306, 0.15234019024970274, 0.07717134363852557, 0.05215089179548157, 0.018529964328180736, 0.04660844233055886, 0.07731307966706302, 0.13183864447086802, 0.1634322235434007, 0.11503269916765756, 0.0650331747919144, 0.035890725326991675]
# 1/1 [==============================] - 0s 51ms/step
# Manual Input Prediction:
#   Prediction: PET with 79.10% likelihood
# [0.02069191438763377, 0.057710225921521995, 0.08292282996432818, 0.24054256837098692, 0.26984316290130794, 0.16539155766944114, 0.06223745541022592, 0.015670986920332936, 0.037380618311533886, 0.06841129607609989, 0.16085029726516054, 0.2550683709869203, 0.21764577883472058, 0.11411403091557669, 0.03879702734839477]
# 1/1 [==============================] - 0s 48ms/step
# Manual Input Prediction:
#   Prediction: PVC with 94.46% likelihood
# [0.032132104637336505, 0.0663294887039239, 0.0958063020214031, 0.18135279429250892, 0.19697229488703924, 0.15939322235434006, 0.06530166468489892, 0.02893923900118906, 0.047033888228299646, 0.0793975029726516, 0.13974019024970274, 0.19232473246135554, 0.17996183115338882, 0.11287812128418549, 0.0473332936979786]
# 1/1 [==============================] - 0s 48ms/step
# Manual Input Prediction:
#   Prediction: PLA with 69.30% likelihood
# [0.17827360285374555, 0.34079298454221163, 0.4533941736028537, 0.7167741973840666, 0.6768850178359096, 0.383459096313912, 0.2673975029726516, 0.10136373365041618, 0.24944244946492272, 0.38755065398335314, 0.5848519619500595, 0.7024576694411415, 0.529133531510107, 0.3224847800237812, 0.1832912009512485]
# 1/1 [==============================] - 0s 46ms/step
# Manual Input Prediction:
#   Prediction: PLA with 100.00% likelihood
# [0.1986269916765755, 0.3629275862068965, 0.5506640903686087, 0.9414947681331748, 0.8900105826397147, 0.47684815695600474, 0.2878550535077289, 0.1276804994054697, 0.276276694411415, 0.4573751486325803, 0.7539756242568371, 0.9277875148632581, 0.689451724137931, 0.38462770511296074, 0.20894542211652795]
# 1/1 [==============================] - 0s 48ms/step
# Manual Input Prediction:
#   Prediction: PLA with 100.00% likelihood
# [0.19692497027348393, 0.3500938168846611, 0.5326560047562425, 0.882079548156956, 0.862118787158145, 0.4540759809750297, 0.2492191438763377, 0.11381248513674197, 0.25905291319857315, 0.4295551724137931, 0.7048331747919144, 0.8774122473246135, 0.6621180737217598, 0.3539604042806183, 0.18256611177170035]
# 1/1 [==============================] - 0s 46ms/step
# Manual Input Prediction:
#   Prediction: PLA with 100.00% likelihood
# [0.16692925089179547, 0.293536385255648, 0.47346076099881096, 0.8437549346016647, 0.7455782401902497, 0.4005126040428062, 0.20951521997621878, 0.08429143876337693, 0.21788644470868015, 0.3729406658739596, 0.6591827586206896, 0.8042003567181927, 0.5761042806183115, 0.30259274673008324, 0.14477728894173603]
# 1/1 [==============================] - 0s 44ms/step
# Manual Input Prediction:
#   Prediction: PP with 51.80% likelihood
# [0.1441808561236623, 0.2587872770511296, 0.43470832342449467, 0.8548976218787158, 0.7913190249702735, 0.36536206896551726, 0.1787206896551724, 0.06553757431629013, 0.18838275862068965, 0.3328624256837099, 0.6376621878715815, 0.8250412604042806, 0.5777347205707491, 0.2684895362663496, 0.12095945303210463]
# 1/1 [==============================] - 0s 78ms/step
# Manual Input Prediction:
#   Prediction: Unknown with 99.99% likelihood
# [0.14945814506539834, 0.2573323424494649, 0.44354042806183114, 0.8439658739595719, 0.6998013079667063, 0.3311187871581451, 0.1905563614744352, 0.06965101070154578, 0.1950267538644471, 0.34542485136741974, 0.6423896551724138, 0.7740816884661118, 0.5127145065398335, 0.25569690844233056, 0.12741510107015458]
# 1/1 [==============================] - 0s 46ms/step
# Manual Input Prediction:
#   Prediction: Unknown with 99.92% likelihood
# [0.17252663495838289, 0.2993259215219976, 0.44681367419738405, 0.698898335315101, 0.6078636147443519, 0.3490626634958383, 0.2064219976218787, 0.10097205707491082, 0.21937086801426872, 0.3582983353151011, 0.5718997621878715, 0.6601891795481569, 0.48324506539833534, 0.28019916765755054, 0.15459036860879904]
# 1/1 [==============================] - 0s 43ms/step
# Manual Input Prediction:
#   Prediction: PLA with 100.00% likelihood
# [0.1683665873959572, 0.2961180737217598, 0.46753781212841855, 0.8239632580261593, 0.7277382877526754, 0.3969304399524376, 0.21639560047562426, 0.08770356718192628, 0.22129191438763376, 0.3733508917954816, 0.6486479191438763, 0.7860348394768133, 0.5674491082045184, 0.3099960760998811, 0.15048882282996434]
# 1/1 [==============================] - 0s 46ms/step
# Manual Input Prediction:
#   Prediction: PLA with 99.52% likelihood
# [0.14482651605231867, 0.25934851367419737, 0.41658894173602856, 0.8097651605231867, 0.775935196195006, 0.36963293697978594, 0.17874518430439953, 0.06848739595719382, 0.1930923900118906, 0.3303492271105826, 0.6119618311533889, 0.7995078478002378, 0.5769038049940547, 0.2751908442330559, 0.12446623067776456]
# 1/1 [==============================] - 0s 45ms/step
# Manual Input Prediction:
#   Prediction: Unknown with 99.30% likelihood
# [0.14430023781212842, 0.2595090368608799, 0.4084854934601665, 0.7884928656361474, 0.7753035671819263, 0.38468002378121285, 0.18016516052318668, 0.06848525564803805, 0.19040083234244948, 0.323356837098692, 0.5963810939357908, 0.7882529131985732, 0.5836771700356718, 0.2832976218787158, 0.12480868014268728]
# 1/1 [==============================] - 0s 58ms/step
# Manual Input Prediction:
#   Prediction: Unknown with 98.54% likelihood
# [0.14924934601664686, 0.2641290130796671, 0.42021581450653983, 0.7928224732461355, 0.7735428061831153, 0.3924281807372176, 0.18505457788347204, 0.07313400713436385, 0.19719488703923901, 0.33517419738406656, 0.6068545778834721, 0.7883030915576694, 0.5851632580261593, 0.29071902497027347, 0.13029952437574316]
# 1/1 [==============================] - 0s 47ms/step
# Manual Input Prediction:
#   Prediction: Unknown with 78.18% likelihood
# [0.2010165279429251, 0.35742532699167656, 0.559823900118906, 0.955806302021403, 0.8815035671819262, 0.5307406658739596, 0.2853668252080856, 0.13747502972651604, 0.2646781212841855, 0.4464912009512485, 0.7548912009512485, 0.9236793103448275, 0.710315933412604, 0.4104189060642093, 0.21338061831153388]
# 1/1 [==============================] - 0s 44ms/step
# Manual Input Prediction:
#   Prediction: PLA with 100.00% likelihood
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# c:\Users\kylej\dev\plastic-scanner\v1.1\Dataset_3\Model_Scan.ipynb Cell 3 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset_3/Model_Scan.ipynb#W2sZmlsZQ%3D%3D?line=15'>16</a> try:
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset_3/Model_Scan.ipynb#W2sZmlsZQ%3D%3D?line=16'>17</a>     while True:
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset_3/Model_Scan.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a>         # Read a line of data from the serial port (assuming data is sent as lines)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset_3/Model_Scan.ipynb#W2sZmlsZQ%3D%3D?line=18'>19</a>         line = ser.readline().decode('utf-8').strip()
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset_3/Model_Scan.ipynb#W2sZmlsZQ%3D%3D?line=20'>21</a>         # Split the received data into a list of numbers using a comma as the delimiter
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset_3/Model_Scan.ipynb#W2sZmlsZQ%3D%3D?line=21'>22</a>         data_values = [float(val) for val in line.split(',')]
#
# File c:\Users\kylej\AppData\Local\Programs\Python\Python310\lib\site-packages\serial\serialwin32.py:295, in Serial.read(self, size)
#     293     if not result_ok:
#     294         if win32.GetLastError() != win32.ERROR_OPERATION_ABORTED:
# --> 295             raise SerialException("GetOverlappedResult failed ({!r})".format(ctypes.WinError()))
#     296     read = buf.raw[:rc.value]
#     297 else:
#
# SerialException: GetOverlappedResult failed (PermissionError(13, 'Access is denied.', None, 5))

# %%
# BLUETOOTH ############################

import numpy as np  # Add this line to import the NumPy library
import serial
from sklearn.preprocessing import LabelEncoder


# Open the serial port
ser = serial.Serial('COM5', baudrate=9600)  # Adjust the baudrate as needed

# Initialize a variable to store the received data
received_data = ""

# print(label_encoder.classes_)

try:
    while True:
        # Read a line of data from the serial port (assuming data is sent as lines)
        line = ser.readline().decode('utf-8').strip()

        # Split the received data into a list of numbers using a comma as the delimiter
        data_values = [float(val) for val in line.split(',')]

        print(line)
        
        # Normalize the data values if needed
        normalized_data = [(val - 0) / (8410000 - 0) for val in data_values]
        
        # Make predictions on the normalized data
        predictions = model.predict([normalized_data])  # Convert normalized_data to a list
        
        # Format the model so that its easier to read in terminal 
        formatted_predictions = np.around(predictions, 4)

        # Get the top prediction
        top_prediction = np.argmax(predictions)

        # top_plastic_type = label_encoder.inverse_transform([top_prediction])[0]
        # print(top_plastic_type)
        # likelihood = predictions[0][top_prediction] * 100
        

        if predictions.shape[1] == 6:
            plastic_types = ["HDPE", "LDPE", "PET", "PP", "PVC", "Unknown"]
        else:
            plastic_types = ["PE", "PET", "PP", "PVC", "Unknown"]
        
        top_plastic_type = plastic_types[top_prediction]

        likelihood = predictions[0][top_prediction] * 100


        # Display the prediction for manual input
        print(f"Manual Input Prediction:")
        print(f"  Prediction: {top_plastic_type} with {likelihood:.2f}% likelihood")

        received_data = ""

        # Send the top plastic type back over serial
        ser.write(top_plastic_type.encode('utf-8'))

except KeyboardInterrupt:
    # Handle Ctrl+C to stop the loop gracefully
    pass

finally:
    # Close the serial port when done
    ser.close()

# Now, you can use the 'received_data' variable for further processing
print("total data:\n", received_data)
# Out:
# 119321,287819,354879,560039,506083,301235,281843,85611,191977,307133,444089,527393,404247,294575,187015
# 1/1 [==============================] - 0s 64ms/step
# Manual Input Prediction:
#   Prediction: Unknown with 100.00% likelihood
# 122473,301271,371609,570943,509503,302061,284127,86429,198185,321961,467317,547811,414103,298939,188095
# 1/1 [==============================] - 0s 80ms/step
# Manual Input Prediction:
#   Prediction: Unknown with 100.00% likelihood
# 1528343,2627215,4009529,6046059,5871169,3421355,1687081,887537,1958225,3213977,4995435,6002077,4696003,2577697,1296459
# 1/1 [==============================] - 0s 53ms/step
# Manual Input Prediction:
#   Prediction: HDPE with 99.97% likelihood

# %%
import numpy as np
import serial
import csv  # Import the csv module
from sklearn.preprocessing import LabelEncoder

# Open the serial port
ser = serial.Serial('COM3', baudrate=115200)  # Adjust the baudrate as needed

# Create and open a CSV file for writing
csv_file = open('test.csv', 'w', newline='')
csv_writer = csv.writer(csv_file)

try:
    while True:
        # Read a line of data from the serial port (assuming data is sent as lines)
        line = ser.readline().decode('utf-8').strip()

        # Split the received data into a list of numbers using a comma as the delimiter
        data_values = [float(val) for val in line.split(',')]

        print(data_values)

        # Write the data values to the CSV file as a new row
        csv_writer.writerow(data_values)

except KeyboardInterrupt:
    # Handle Ctrl+C to stop the loop gracefully
    pass

finally:
    # Close the CSV file and the serial port when done
    csv_file.close()
    ser.close()

# The received data has been saved in the 'received_data.csv' file
print("Data saved to 'PP2.csv'")
# Out:
# [317403.0, 684321.0, 908709.0, 2289715.0, 1956663.0, 928169.0, 692277.0, 348519.0, 469453.0, 759823.0, 1575701.0, 2107307.0, 1440553.0, 818941.0, 524185.0]
# [259395.0, 614275.0, 711041.0, 1870485.0, 2300269.0, 1498237.0, 769377.0, 416501.0, 414509.0, 641059.0, 1284597.0, 2096531.0, 1910133.0, 1144423.0, 600129.0]
# [310337.0, 653941.0, 772553.0, 1780665.0, 2283699.0, 1412817.0, 745563.0, 361903.0, 452595.0, 684341.0, 1271683.0, 2057913.0, 1899625.0, 1105365.0, 564659.0]
# [229703.0, 490717.0, 580165.0, 1023621.0, 1349483.0, 1329633.0, 597707.0, 320907.0, 341285.0, 520547.0, 801279.0, 1227201.0, 1391697.0, 985119.0, 471803.0]
# [276689.0, 567133.0, 637737.0, 1326943.0, 1861363.0, 1407777.0, 632605.0, 331803.0, 393769.0, 572231.0, 935303.0, 1545137.0, 1618891.0, 1020467.0, 478371.0]
# [320387.0, 626899.0, 1056739.0, 1610545.0, 1051259.0, 620101.0, 486417.0, 213485.0, 464643.0, 835453.0, 1331923.0, 1328081.0, 830879.0, 554047.0, 350835.0]
# [1677513.0, 2947145.0, 4459625.0, 7208427.0, 7168379.0, 4099761.0, 2099237.0, 943259.0, 2190369.0, 3603603.0, 5821265.0, 7247505.0, 5671345.0, 3117509.0, 1530357.0]
# [1487349.0, 2616421.0, 4026337.0, 6236991.0, 6046303.0, 3371259.0, 1853283.0, 828867.0, 1941743.0, 3209009.0, 5064977.0, 6126555.0, 4720899.0, 2641705.0, 1343551.0]
# [1666617.0, 2975939.0, 4402195.0, 7309801.0, 6577479.0, 3800425.0, 2149877.0, 910257.0, 2199623.0, 3586517.0, 5835829.0, 6991909.0, 5224539.0, 2992825.0, 1537017.0]
# [1657127.0, 2970263.0, 4425667.0, 7407113.0, 6778593.0, 3965621.0, 2150607.0, 940769.0, 2192419.0, 3597061.0, 5896869.0, 7139143.0, 5406059.0, 3075707.0, 1552831.0]
# [1681123.0, 2943693.0, 4445699.0, 7196131.0, 7092237.0, 4125011.0, 2121153.0, 930589.0, 2190245.0, 3593615.0, 5800079.0, 7186877.0, 5636577.0, 3136383.0, 1532817.0]
# [1671173.0, 2965759.0, 4437873.0, 7268023.0, 7016629.0, 4099953.0, 2117313.0, 931923.0, 2197603.0, 3600245.0, 5832777.0, 7187889.0, 5586953.0, 3124723.0, 1533755.0]
# [1659947.0, 2922759.0, 4431609.0, 7307579.0, 6861273.0, 4017677.0, 2095493.0, 922427.0, 2178037.0, 3581757.0, 5861559.0, 7140551.0, 5469903.0, 3074745.0, 1517187.0]
# [1438465.0, 2697199.0, 3838551.0, 6065591.0, 5486639.0, 2697749.0, 2052697.0, 817675.0, 1962967.0, 3179251.0, 4956937.0, 5826113.0, 4105965.0, 2386853.0, 1442639.0]
# [1688061.0, 3021223.0, 4648507.0, 8137725.0, 7394197.0, 4447319.0, 2461105.0, 1126725.0, 2232629.0, 3732919.0, 6382071.0, 7823921.0, 5959359.0, 3474741.0, 1802511.0]
# [1675917.0, 3032701.0, 4598181.0, 8144017.0, 7353733.0, 4412591.0, 2498201.0, 1135031.0, 2229989.0, 3710999.0, 6348819.0, 7791373.0, 5914957.0, 3474981.0, 1825137.0]
# [1692665.0, 3015893.0, 4607371.0, 7936051.0, 7766845.0, 4088109.0, 2302071.0, 1072079.0, 2229837.0, 3710811.0, 6251097.0, 7894839.0, 5962285.0, 3220455.0, 1695979.0]
# [1532341.0, 2671685.0, 3992471.0, 6898095.0, 5961087.0, 3301527.0, 1833059.0, 858303.0, 1990617.0, 3228795.0, 5371147.0, 6384669.0, 4606083.0, 2579905.0, 1356061.0]
# [1316995.0, 2400935.0, 3687519.0, 5438773.0, 5253389.0, 3158611.0, 1592569.0, 1171171.0, 1738977.0, 2933347.0, 4515753.0, 5367455.0, 4262283.0, 2435045.0, 1412273.0]
# [1404021.0, 2761857.0, 4508739.0, 7753541.0, 7293157.0, 4181759.0, 2229501.0, 1118243.0, 1976057.0, 3539067.0, 6108911.0, 7567055.0, 5768051.0, 3221923.0, 1682247.0]
# [1561261.0, 2779669.0, 4428153.0, 6846551.0, 6405751.0, 3803017.0, 1992119.0, 1047631.0, 2057757.0, 3513799.0, 5641805.0, 6685209.0, 5133349.0, 2909953.0, 1524901.0]
# [1146715.0, 2128739.0, 2815389.0, 5919151.0, 6629225.0, 3999475.0, 1855795.0, 995995.0, 1575085.0, 2426019.0, 4427625.0, 6424023.0, 5397931.0, 2956805.0, 1436065.0]
# [1369023.0, 2677555.0, 4396943.0, 8108657.0, 7230159.0, 4158777.0, 2229585.0, 1088411.0, 1919793.0, 3444819.0, 6242195.0, 7726433.0, 5729809.0, 3212327.0, 1668071.0]
# [1459473.0, 2575437.0, 3941037.0, 6720447.0, 5591675.0, 3188625.0, 1759459.0, 829321.0, 1896925.0, 3137223.0, 5236065.0, 6096007.0, 4358203.0, 2468979.0, 1294847.0]
# [1763943.0, 3124841.0, 4976841.0, 8083649.0, 8025765.0, 4462715.0, 2337677.0, 1122629.0, 2331121.0, 3928227.0, 6467503.0, 8100415.0, 6319875.0, 3422005.0, 1735791.0]
# [1814215.0, 3117201.0, 4483671.0, 7361773.0, 8093199.0, 4609135.0, 2389425.0, 1190117.0, 2336215.0, 3695109.0, 5904001.0, 7782521.0, 6390319.0, 3515581.0, 1801891.0]
# [1847169.0, 3229023.0, 5083283.0, 8243533.0, 8303851.0, 4670123.0, 2380509.0, 1110613.0, 2398567.0, 4056373.0, 6709409.0, 8304379.0, 6659623.0, 3536601.0, 1749101.0]
# [1774277.0, 3115053.0, 5045757.0, 8310201.0, 8311347.0, 4299239.0, 2163699.0, 877125.0, 2314201.0, 3971043.0, 6738451.0, 8309887.0, 6430009.0, 3250483.0, 1530441.0]
# [1776137.0, 3093039.0, 4625543.0, 7288205.0, 7536827.0, 3945099.0, 2126597.0, 960461.0, 2324379.0, 3788279.0, 5972753.0, 7533985.0, 5844211.0, 3043901.0, 1525213.0]
# [1676777.0, 3023295.0, 4413773.0, 7099831.0, 7257529.0, 3777891.0, 2064045.0, 909633.0, 2275313.0, 3687583.0, 5813769.0, 7303147.0, 5570427.0, 2926131.0, 1497843.0]
# [1756301.0, 3048203.0, 4794071.0, 7340095.0, 7194621.0, 4191555.0, 2201433.0, 1177899.0, 2228315.0, 3651097.0, 5612773.0, 6973915.0, 5718681.0, 3265761.0, 1725011.0]
# [1891603.0, 3416703.0, 5242793.0, 7752181.0, 7793207.0, 3958643.0, 2374971.0, 1083733.0, 2514809.0, 4222189.0, 6489551.0, 7829017.0, 5936653.0, 3194093.0, 1737291.0]
# [1921771.0, 3345241.0, 5008307.0, 7726379.0, 7797957.0, 4005353.0, 2321529.0, 1052511.0, 2496759.0, 4061089.0, 6340711.0, 7806655.0, 5931269.0, 3192607.0, 1692569.0]
# [1903859.0, 3372585.0, 5045281.0, 7654807.0, 7680665.0, 3858837.0, 2314989.0, 1037431.0, 2501057.0, 4094877.0, 6293099.0, 7679719.0, 5783225.0, 3108843.0, 1693237.0]
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# c:\Users\kylej\dev\plastic-scanner\v1.1\Dataset_3\Model_Scan.ipynb Cell 5 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset_3/Model_Scan.ipynb#W4sZmlsZQ%3D%3D?line=12'>13</a> try:
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset_3/Model_Scan.ipynb#W4sZmlsZQ%3D%3D?line=13'>14</a>     while True:
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset_3/Model_Scan.ipynb#W4sZmlsZQ%3D%3D?line=14'>15</a>         # Read a line of data from the serial port (assuming data is sent as lines)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset_3/Model_Scan.ipynb#W4sZmlsZQ%3D%3D?line=15'>16</a>         line = ser.readline().decode('utf-8').strip()
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset_3/Model_Scan.ipynb#W4sZmlsZQ%3D%3D?line=17'>18</a>         # Split the received data into a list of numbers using a comma as the delimiter
#      <a href='vscode-notebook-cell:/c%3A/Users/kylej/dev/plastic-scanner/v1.1/Dataset_3/Model_Scan.ipynb#W4sZmlsZQ%3D%3D?line=18'>19</a>         data_values = [float(val) for val in line.split(',')]
#
# File c:\Users\kylej\AppData\Local\Programs\Python\Python310\lib\site-packages\serial\serialwin32.py:295, in Serial.read(self, size)
#     293     if not result_ok:
#     294         if win32.GetLastError() != win32.ERROR_OPERATION_ABORTED:
# --> 295             raise SerialException("GetOverlappedResult failed ({!r})".format(ctypes.WinError()))
#     296     read = buf.raw[:rc.value]
#     297 else:
#
# SerialException: GetOverlappedResult failed (PermissionError(13, 'Access is denied.', None, 5))

# %%
# B8D61A0C805E

# Incoming ################
import serial

# Replace 'COM4' with the COM port for your ESP32
ser = serial.Serial('COM4', baudrate=9600)  # Adjust the baud rate as needed

print('hello there')
# received_data = ser.read()
received_data = ser.readline().decode('utf-8').strip()
print(received_data)
ser.close()


# # Outgoing ###############
# import serial

# # Replace 'COM5' with the COM port for your ESP32
# ser = serial.Serial('COM4', baudrate=9600)  # Adjust the baud rate as needed

# data_to_send = "data is sending"
# ser.write(data_to_send.encode('utf-8'))
# ser.close()
# Out:
# hello there
# 1385393,2398163,4084737,8385713,7460407,5009789,2125057,1380039,1776669,3140987,6216139,7962293,6261095,3584457,1761127
