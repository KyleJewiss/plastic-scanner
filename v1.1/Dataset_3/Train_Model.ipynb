# %%
# import pandas as pd
# from imblearn.over_sampling import SMOTE
# from collections import Counter

# # Load your dataset here (replace 'your_dataset.csv' with your actual dataset file)
# # data = pd.read_csv('AllTogethertest.csv')
# data = pd.read_csv('AllTogether_30_09.csv')

# # Assuming 'material_type' is the column that indicates the material type
# X = data.drop(columns=['Material_Type'])
# y = data['Material_Type']

# # Initialize SMOTE with the desired number of samples for each class (e.g., 100)
# desired_samples = 6000
# smote = SMOTE(sampling_strategy={material_type: desired_samples for material_type in y.unique()})

# # Apply SMOTE to the dataset
# X_resampled, y_resampled = smote.fit_resample(X, y)

# # Check the new class distribution
# print("Class distribution after SMOTE:", Counter(y_resampled))

# # Now you can use X_resampled and y_resampled as your balanced dataset

# # Create a new DataFrame with the resampled data
# resampled_data = pd.DataFrame(X_resampled, columns=X.columns)
# resampled_data['Material_Type'] = y_resampled

# # Save the resampled data to a CSV file
# resampled_data.to_csv('test_resampled.csv', index=False)

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import EarlyStopping

# Load the dataset
data = pd.read_csv("test_resampled.csv")
# data = pd.read_csv("AllTogethertest.csv")
# data = pd.read_csv("resampled_dataset8_PVC.csv")


# Separate features and labels
X = data.drop(columns=["Material_Type"])
y = data["Material_Type"]

# %%
# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into train and test sets (Normal)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.3, random_state=42)

# # Normalize features
# X_train_normalized = (X_train - X_train.min()) / (X_train.max() - X_train.min())
# X_test_normalized = (X_test - X_train.min()) / (X_train.max() - X_train.min())
X_train_normalized = ((X_train - 0) / (8410000 - 0))
X_test_normalized = ((X_test - 0) / (8410000 - 0))

# Define the model architecture
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(256, activation="relu"),
    tf.keras.layers.Dense(128, activation="relu"),
    # tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(len(label_encoder.classes_), activation="softmax")
])

# %%
# Compile the model
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(X_train_normalized, y_train, epochs=5000, batch_size=256, validation_split=0.3, callbacks=[early_stopping])
# history = model.fit(X_train_normalized, y_train, epochs=500, batch_size=256, validation_split=0.2)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_normalized, y_test)

# Save the model
# model.save("15_point_plastic_classifier_model_30_09.keras")
# model.save("3_point_plastic_classifier_model.keras")
# model.save("test_model.keras")

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss')
plt.legend()
plt.show()

# Plot training and validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/5000
# 58/58 [==============================] - 1s 6ms/step - loss: 1.4101 - accuracy: 0.4190 - val_loss: 1.1750 - val_accuracy: 0.5585
# Epoch 2/5000
# 58/58 [==============================] - 0s 4ms/step - loss: 1.0550 - accuracy: 0.5921 - val_loss: 0.9480 - val_accuracy: 0.6242
# Epoch 3/5000
# 58/58 [==============================] - 0s 3ms/step - loss: 0.9006 - accuracy: 0.6373 - val_loss: 0.8535 - val_accuracy: 0.6754
# Epoch 4/5000
# 58/58 [==============================] - 0s 3ms/step - loss: 0.8288 - accuracy: 0.6524 - val_loss: 0.7932 - val_accuracy: 0.6888
# Epoch 5/5000
# 58/58 [==============================] - 0s 3ms/step - loss: 0.7813 - accuracy: 0.6866 - val_loss: 0.7488 - val_accuracy: 0.6786
# Epoch 6/5000
# 58/58 [==============================] - 0s 5ms/step - loss: 0.7461 - accuracy: 0.6988 - val_loss: 0.7205 - val_accuracy: 0.7240
# Epoch 7/5000
# 58/58 [==============================] - 0s 5ms/step - loss: 0.7194 - accuracy: 0.7109 - val_loss: 0.6924 - val_accuracy: 0.7453
# Epoch 8/5000
# 58/58 [==============================] - 0s 4ms/step - loss: 0.6909 - accuracy: 0.7376 - val_loss: 0.6632 - val_accuracy: 0.7394
# Epoch 9/5000
# 58/58 [==============================] - 0s 4ms/step - loss: 0.6710 - accuracy: 0.7362 - val_loss: 0.6372 - val_accuracy: 0.7680
# Epoch 10/5000
# 58/58 [==============================] - 0s 4ms/step - loss: 0.6417 - accuracy: 0.7637 - val_loss: 0.6190 - val_accuracy: 0.7718
# Epoch 11/5000
# 58/58 [==============================] - 0s 4ms/step - loss: 0.6232 - accuracy: 0.7695 - val_loss: 0.5955 - val_accuracy: 0.7883
# Epoch 12/5000
# 58/58 [==============================] - 0s 3ms/step - loss: 0.6039 - accuracy: 0.7728 - val_loss: 0.5754 - val_accuracy: 0.7853
# Epoch 13/5000
# 58/58 [==============================] - 0s 4ms/step - loss: 0.5936 - accuracy: 0.7725 - val_loss: 0.5814 - val_accuracy: 0.7527
# Epoch 14/5000
# 58/58 [==============================] - 0s 4ms/step - loss: 0.5730 - accuracy: 0.7815 - val_loss: 0.5483 - val_accuracy: 0.8032
# Epoch 15/5000
# 58/58 [==============================] - 0s 4ms/step - loss: 0.5584 - accuracy: 0.7854 - val_loss: 0.5489 - val_accuracy: 0.8038
# Epoch 16/5000
# 58/58 [==============================] - 0s 4ms/step - loss: 0.5450 - accuracy: 0.7892 - val_loss: 0.5286 - val_accuracy: 0.8013
# Epoch 17/5000
# 58/58 [==============================] - 0s 4ms/step - loss: 0.5330 - accuracy: 0.7947 - val_loss: 0.5035 - val_accuracy: 0.8045
# Epoch 18/5000
# 58/58 [==============================] - 0s 5ms/step - loss: 0.5213 - accuracy: 0.7959 - val_loss: 0.5062 - val_accuracy: 0.7996
# Epoch 19/5000
# 58/58 [==============================] - 0s 4ms/step - loss: 0.5096 - accuracy: 0.8017 - val_loss: 0.4868 - val_accuracy: 0.8086
# Epoch 20/5000
# 58/58 [==============================] - 0s 3ms/step - loss: 0.5090 - accuracy: 0.8028 - val_loss: 0.4855 - val_accuracy: 0.8072
# Epoch 21/5000
# 58/58 [==============================] - 0s 3ms/step - loss: 0.4905 - accuracy: 0.8107 - val_loss: 0.4641 - val_accuracy: 0.8199
# Epoch 22/5000
# 58/58 [==============================] - 0s 4ms/step - loss: 0.4804 - accuracy: 0.8154 - val_loss: 0.4728 - val_accuracy: 0.8226
# Epoch 23/5000
# 58/58 [==============================] - 0s 3ms/step - loss: 0.4712 - accuracy: 0.8209 - val_loss: 0.4491 - val_accuracy: 0.8294
# Epoch 24/5000
# 58/58 [==============================] - 0s 4ms/step - loss: 0.4729 - accuracy: 0.8158 - val_loss: 0.4380 - val_accuracy: 0.8356
# Epoch 25/5000
# 58/58 [==============================] - 0s 4ms/step - loss: 0.4568 - accuracy: 0.8263 - val_loss: 0.4340 - val_accuracy: 0.8370
# Epoch 26/5000
# 58/58 [==============================] - 0s 4ms/step - loss: 0.4462 - accuracy: 0.8311 - val_loss: 0.4312 - val_accuracy: 0.8388
# Epoch 27/5000
# 58/58 [==============================] - 0s 4ms/step - loss: 0.4434 - accuracy: 0.8329 - val_loss: 0.4256 - val_accuracy: 0.8484
# Epoch 28/5000
# 58/58 [==============================] - 0s 3ms/step - loss: 0.4328 - accuracy: 0.8375 - val_loss: 0.4080 - val_accuracy: 0.8486
# Epoch 29/5000
# 58/58 [==============================] - 0s 3ms/step - loss: 0.4278 - accuracy: 0.8417 - val_loss: 0.4011 - val_accuracy: 0.8491
# Epoch 30/5000
# 58/58 [==============================] - 0s 3ms/step - loss: 0.4187 - accuracy: 0.8417 - val_loss: 0.4165 - val_accuracy: 0.8411
# Epoch 31/5000
# 58/58 [==============================] - 0s 4ms/step - loss: 0.4207 - accuracy: 0.8415 - val_loss: 0.4005 - val_accuracy: 0.8502
# Epoch 32/5000
# 58/58 [==============================] - 0s 4ms/step - loss: 0.4065 - accuracy: 0.8479 - val_loss: 0.4044 - val_accuracy: 0.8613
# Epoch 33/5000
# 58/58 [==============================] - 0s 4ms/step - loss: 0.4006 - accuracy: 0.8517 - val_loss: 0.3846 - val_accuracy: 0.8564
# Epoch 34/5000
# 58/58 [==============================] - 0s 3ms/step - loss: 0.3993 - accuracy: 0.8518 - val_loss: 0.3811 - val_accuracy: 0.8515
# Epoch 35/5000
# 58/58 [==============================] - 0s 3ms/step - loss: 0
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0740 - accuracy: 0.9778 - val_loss: 0.0812 - val_accuracy: 0.9744
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0829 - accuracy: 0.9761

# %%
# Make predictions
predictions = model.predict(X_test_normalized)
predicted_labels = np.argmax(predictions, axis=1)
predicted_plastic_types = label_encoder.inverse_transform(predicted_labels)



# Convert predictions to percentage likelihood
percentage_likelihood = predictions.max(axis=1) * 100

# Display test accuracy and example predictions
print(f"Test Accuracy: {test_accuracy}")
for i in range(15):
    if y_test[i] == predicted_labels[i]:
        CorF = "Correct"
    else:
        CorF = "False"
    print(f"Sample {i+1}: {CorF} Predicted {predicted_plastic_types[i]} with {percentage_likelihood[i]:.2f}% likelihood")




total_params = model.count_params()
total_size_bytes = total_params * 4  # Each parameter is usually a 32-bit float
total_size_mb = total_size_bytes / (1024)  # Convert bytes to megabytes

print(f"Total size of the model: {total_size_mb:.2f} KB")
# Out:
# 282/282 [==============================] - 0s 1ms/step
# Test Accuracy: 0.976111114025116
# Sample 1: Correct Predicted PE with 100.00% likelihood
# Sample 2: Correct Predicted PVC with 99.97% likelihood
# Sample 3: Correct Predicted PVC with 98.50% likelihood
# Sample 4: Correct Predicted Unknown with 96.45% likelihood
# Sample 5: Correct Predicted PE with 99.92% likelihood
# Sample 6: Correct Predicted PET with 99.82% likelihood
# Sample 7: Correct Predicted PE with 100.00% likelihood
# Sample 8: Correct Predicted PET with 99.41% likelihood
# Sample 9: Correct Predicted PET with 99.99% likelihood
# Sample 10: Correct Predicted PVC with 90.03% likelihood
# Sample 11: Correct Predicted PET with 98.06% likelihood
# Sample 12: Correct Predicted PVC with 99.59% likelihood
# Sample 13: Correct Predicted PE with 99.99% likelihood
# Sample 14: Correct Predicted PP with 97.10% likelihood
# Sample 15: False Predicted PE with 67.04% likelihood
# Total size of the model: 147.02 KB

# %%
# Make predictions
predictions = model.predict(X_test_normalized)

# Get the top 4 predictions for each sample
top_predictions = np.argsort(predictions, axis=1)[:, -5:]
top_labels = top_predictions[:, ::-1]

# print(predictions)

# Reshape the top_labels array to be 1D
top_labels_1d = top_labels.reshape(-1)

# Inverse transform the labels
top_plastic_types = label_encoder.inverse_transform(top_labels_1d)

# Reshape the top_plastic_types array back to 2D
top_plastic_types = top_plastic_types.reshape(top_labels.shape)

# Get the percentage likelihoods for the top 4 predictions
percentage_likelihoods = np.take_along_axis(predictions, top_predictions, axis=1) * 100

# Display test accuracy and example predictions
print(f"Test Accuracy: {test_accuracy}")
for i in range(len(predicted_labels)):
    num_predictions = min(5, len(np.unique(top_labels[i])))
    if y_test[i] == predicted_labels[i]:
        CorF = "Correct,"
    else:
        CorF = "False,"
    print(f"Sample {i+1}: {CorF} it was {label_encoder.classes_[y_test[i]]}")
    for j in range(num_predictions):
        print(f"  Prediction {j+1}: {top_plastic_types[i][j]} with {percentage_likelihoods[i][1-j]:.2f}% likelihood") #put in '1' for HvL and '3' for the others
# Out:
# 282/282 [==============================] - 0s 1ms/step
# Test Accuracy: 0.976111114025116
# Sample 1: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 100.00% likelihood
#   Prediction 4: PVC with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 2: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 99.97% likelihood
#   Prediction 4: PP with 0.02% likelihood
#   Prediction 5: PET with 0.01% likelihood
# Sample 3: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PET with 98.50% likelihood
#   Prediction 4: PP with 1.14% likelihood
#   Prediction 5: PE with 0.36% likelihood
# Sample 4: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PE with 96.45% likelihood
#   Prediction 4: PET with 3.55% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 5: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.92% likelihood
#   Prediction 4: PVC with 0.08% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 6: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: Unknown with 99.82% likelihood
#   Prediction 4: PP with 0.10% likelihood
#   Prediction 5: PE with 0.08% likelihood
# Sample 7: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 100.00% likelihood
#   Prediction 4: PVC with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 99.41% likelihood
#   Prediction 4: PVC with 0.39% likelihood
#   Prediction 5: PE with 0.20% likelihood
# Sample 9: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PE with 99.99% likelihood
#   Prediction 4: Unknown with 0.01% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 10: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 90.03% likelihood
#   Prediction 4: PE with 9.97% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 11: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 98.06% likelihood
#   Prediction 4: PVC with 1.94% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 12: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 99.59% likelihood
#   Prediction 4: PE with 0.41% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 13: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.99% likelihood
#   Prediction 4: PVC with 0.01% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 14: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 97.10% likelihood
#   Prediction 4: PVC with 2.90% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 15: False, it was PP
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 67.04% likelihood
#   Prediction 4: PVC with 32.96% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 16: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 99.21% likelihood
#   Prediction 4: PVC with 0.79% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 17: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 18: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PVC with 99.84% likelihood
#   Prediction 4: PE with 0.16% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 19: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 20: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 98.68% likelihood
#   Prediction 4: PVC with 1.32% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 21: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 99.61% likelihood
#   Prediction 4: PVC with 0.39% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 22: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.98% likelihood
#   Prediction 4: PVC with 0.02% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 23: Correct, it was PET
#   Prediction 1: PET with 0.02% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.87% likelihood
#   Prediction 4: PVC with 0.10% likelihood
#   Prediction 5: PE with 0.02% likelihood
# Sample 24: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: Unknown with 99.94% likelihood
#   Prediction 4: PP with 0.03% likelihood
#   Prediction 5: PE with 0.02% likelihood
# Sample 25: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 62.97% likelihood
#   Prediction 4: PVC with 36.99% likelihood
#   Prediction 5: PE with 0.04% likelihood
# Sample 26: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 27: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 95.28% likelihood
#   Prediction 4: PVC with 4.72% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 28: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 100.00% likelihood
#   Prediction 4: PVC with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 29: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 99.24% likelihood
#   Prediction 4: PE with 0.66% likelihood
#   Prediction 5: PET with 0.10% likelihood
# Sample 30: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.97% likelihood
#   Prediction 4: PVC with 0.03% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 31: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PVC with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 32: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PVC with 0.00% likelihood
# Sample 33: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 95.38% likelihood
#   Prediction 4: PE with 4.39% likelihood
#   Prediction 5: PET with 0.24% likelihood
# Sample 34: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 74.70% likelihood
#   Prediction 4: PVC with 25.21% likelihood
#   Prediction 5: PET with 0.09% likelihood
# Sample 35: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PET with 99.98% likelihood
#   Prediction 4: PE with 0.02% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 36: False, it was PVC
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PP with 73.68% likelihood
#   Prediction 4: PE with 26.30% likelihood
#   Prediction 5: PET with 0.02% likelihood
# Sample 37: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 38: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: Unknown with 0.00% likelihood
#   Prediction 5: PVC with 0.00% likelihood
# Sample 39: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 95.43% likelihood
#   Prediction 4: PE with 4.55% likelihood
#   Prediction 5: PET with 0.02% likelihood
# Sample 40: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 97.77% likelihood
#   Prediction 4: PVC with 2.23% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 41: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PVC with 99.66% likelihood
#   Prediction 4: Unknown with 0.25% likelihood
#   Prediction 5: PET with 0.09% likelihood
# Sample 42: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PVC with 99.97% likelihood
#   Prediction 4: Unknown with 0.02% likelihood
#   Prediction 5: PP with 0.01% likelihood
# Sample 43: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 44: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: PE with 99.70% likelihood
#   Prediction 4: Unknown with 0.16% likelihood
#   Prediction 5: PP with 0.15% likelihood
# Sample 45: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 98.79% likelihood
#   Prediction 4: PVC with 1.21% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 46: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PVC with 55.66% likelihood
#   Prediction 4: Unknown with 44.33% likelihood
#   Prediction 5: PET with 0.01% likelihood
# Sample 47: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PE with 99.97% likelihood
#   Prediction 4: PVC with 0.03% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 48: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PP with 99.57% likelihood
#   Prediction 4: Unknown with 0.39% likelihood
#   Prediction 5: PET with 0.04% likelihood
# Sample 49: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 90.11% likelihood
#   Prediction 4: PVC with 9.89% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 50: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PVC with 99.76% likelihood
#   Prediction 4: PP with 0.23% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 51: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PVC with 99.99% likelihood
#   Prediction 4: PE with 0.01% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 52: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 97.35% likelihood
#   Prediction 4: PVC with 2.65% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 53: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 86.05% likelihood
#   Prediction 4: PE with 13.95% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 54: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 99.42% likelihood
#   Prediction 4: PVC with 0.54% likelihood
#   Prediction 5: PET with 0.04% likelihood
# Sample 55: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.99% likelihood
#   Prediction 4: PVC with 0.01% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 56: Correct, it was Unknown
#   Prediction 1: Unknown with 0.25% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PVC with 99.10% likelihood
#   Prediction 4: PP with 0.39% likelihood
#   Prediction 5: PET with 0.26% likelihood
# Sample 57: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: Unknown with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 58: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.80% likelihood
#   Prediction 4: PVC with 0.20% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 59: Correct, it was Unknown
#   Prediction 1: Unknown with 0.01% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PE with 99.44% likelihood
#   Prediction 4: PP with 0.52% likelihood
#   Prediction 5: PET with 0.03% likelihood
# Sample 60: Correct, it was PET
#   Prediction 1: PET with 0.02% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 98.96% likelihood
#   Prediction 4: PVC with 0.92% likelihood
#   Prediction 5: PE with 0.10% likelihood
# Sample 61: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 99.92% likelihood
#   Prediction 4: PVC with 0.07% likelihood
#   Prediction 5: PE with 0.01% likelihood
# Sample 62: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.65% likelihood
#   Prediction 4: PVC with 0.33% likelihood
#   Prediction 5: PE with 0.02% likelihood
# Sample 63: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 94.74% likelihood
#   Prediction 4: PVC with 5.26% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 64: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PP with 99.95% likelihood
#   Prediction 4: PE with 0.04% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 65: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PVC with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 66: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 98.64% likelihood
#   Prediction 4: PE with 1.32% likelihood
#   Prediction 5: PET with 0.04% likelihood
# Sample 67: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 99.23% likelihood
#   Prediction 4: PVC with 0.77% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 68: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 94.77% likelihood
#   Prediction 4: PVC with 5.23% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 69: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: Unknown with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 70: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 99.38% likelihood
#   Prediction 4: PVC with 0.62% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 71: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 99.98% likelihood
#   Prediction 4: PVC with 0.01% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 72: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 100.00% likelihood
#   Prediction 4: PVC with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 73: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PP with 99.84% likelihood
#   Prediction 4: PE with 0.16% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 74: False, it was PP
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 57.76% likelihood
#   Prediction 4: PVC with 42.24% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 75: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 100.00% likelihood
#   Prediction 4: PVC with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 76: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PVC with 99.97% likelihood
#   Prediction 4: PP with 0.03% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 77: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: Unknown with 98.55% likelihood
#   Prediction 4: PP with 0.99% likelihood
#   Prediction 5: PE with 0.46% likelihood
# Sample 78: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 79: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 93.51% likelihood
#   Prediction 4: PE with 6.49% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 80: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 95.46% likelihood
#   Prediction 4: PE with 4.52% likelihood
#   Prediction 5: PET with 0.02% likelihood
# Sample 81: False, it was Unknown
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 92.04% likelihood
#   Prediction 4: PE with 7.95% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 82: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: Unknown with 99.54% likelihood
#   Prediction 4: PVC with 0.42% likelihood
#   Prediction 5: PE with 0.05% likelihood
# Sample 83: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PE with 97.94% likelihood
#   Prediction 4: PP with 1.26% likelihood
#   Prediction 5: PET with 0.80% likelihood
# Sample 84: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 51.55% likelihood
#   Prediction 4: PVC with 48.45% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 85: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PVC with 99.97% likelihood
#   Prediction 4: PP with 0.01% likelihood
#   Prediction 5: PE with 0.01% likelihood
# Sample 86: Correct, it was PET
#   Prediction 1: PET with 0.05% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 96.04% likelihood
#   Prediction 4: PVC with 3.67% likelihood
#   Prediction 5: PE with 0.23% likelihood
# Sample 87: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 99.75% likelihood
#   Prediction 4: PE with 0.25% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 88: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 83.54% likelihood
#   Prediction 4: PVC with 16.46% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 89: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 90: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PE with 99.18% likelihood
#   Prediction 4: PP with 0.75% likelihood
#   Prediction 5: PET with 0.06% likelihood
# Sample 91: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 99.97% likelihood
#   Prediction 4: PVC with 0.03% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 92: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 92.50% likelihood
#   Prediction 4: PVC with 7.50% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 93: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 94: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: Unknown with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 95: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 96: Correct, it was PET
#   Prediction 1: PET with 0.03% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.57% likelihood
#   Prediction 4: PVC with 0.34% likelihood
#   Prediction 5: PE with 0.06% likelihood
# Sample 97: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 98.30% likelihood
#   Prediction 4: PVC with 1.70% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 98: False, it was Unknown
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PE with 53.60% likelihood
#   Prediction 4: PP with 46.40% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 99: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 100: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: Unknown with 99.62% likelihood
#   Prediction 4: PE with 0.38% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 101: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PET with 99.99% likelihood
#   Prediction 4: PE with 0.01% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 102: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PE with 99.99% likelihood
#   Prediction 4: PP with 0.01% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 103: Correct, it was PP
#   Prediction 1: PP with 0.21% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PVC with 95.88% likelihood
#   Prediction 4: PE with 3.51% likelihood
#   Prediction 5: PET with 0.40% likelihood
# Sample 104: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PE with 99.99% likelihood
#   Prediction 4: Unknown with 0.01% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 105: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 80.36% likelihood
#   Prediction 4: PVC with 19.64% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 106: Correct, it was PET
#   Prediction 1: PET with 0.07% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 97.42% likelihood
#   Prediction 4: PVC with 2.32% likelihood
#   Prediction 5: PE with 0.19% likelihood
# Sample 107: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.99% likelihood
#   Prediction 4: PVC with 0.01% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 108: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: Unknown with 99.87% likelihood
#   Prediction 4: PE with 0.11% likelihood
#   Prediction 5: PP with 0.03% likelihood
# Sample 109: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: Unknown with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 110: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 99.35% likelihood
#   Prediction 4: PVC with 0.41% likelihood
#   Prediction 5: PET with 0.24% likelihood
# Sample 111: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PE with 99.80% likelihood
#   Prediction 4: PET with 0.20% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 112: Correct, it was PET
#   Prediction 1: PET with 0.01% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PVC with 99.85% likelihood
#   Prediction 4: PP with 0.11% likelihood
#   Prediction 5: PE with 0.03% likelihood
# Sample 113: False, it was Unknown
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PE with 54.64% likelihood
#   Prediction 4: PP with 45.31% likelihood
#   Prediction 5: PET with 0.05% likelihood
# Sample 114: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 87.94% likelihood
#   Prediction 4: PVC with 12.06% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 115: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 98.10% likelihood
#   Prediction 4: PE with 1.90% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 116: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PP with 99.77% likelihood
#   Prediction 4: PE with 0.23% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 117: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 118: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 97.97% likelihood
#   Prediction 4: PVC with 2.03% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 119: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 99.58% likelihood
#   Prediction 4: PVC with 0.23% likelihood
#   Prediction 5: PET with 0.18% likelihood
# Sample 120: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PE with 95.52% likelihood
#   Prediction 4: PP with 4.46% likelihood
#   Prediction 5: PET with 0.02% likelihood
# Sample 121: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: PVC with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 122: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PE with 99.98% likelihood
#   Prediction 4: PET with 0.02% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 123: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 98.42% likelihood
#   Prediction 4: PVC with 1.58% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 124: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 91.01% likelihood
#   Prediction 4: PVC with 8.99% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 125: Correct, it was PE
#   Prediction 1: PE with 0.97% likelihood
#   Prediction 2: Unknown with 0.08% likelihood
#   Prediction 3: PVC with 62.13% likelihood
#   Prediction 4: PP with 24.34% likelihood
#   Prediction 5: PET with 12.48% likelihood
# Sample 126: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PET with 99.91% likelihood
#   Prediction 4: PE with 0.09% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 127: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 99.48% likelihood
#   Prediction 4: PVC with 0.45% likelihood
#   Prediction 5: PET with 0.07% likelihood
# Sample 128: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: Unknown with 99.78% likelihood
#   Prediction 4: PVC with 0.22% likelihood
#   Prediction 5: PP with 0.01% likelihood
# Sample 129: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.93% likelihood
#   Prediction 4: PVC with 0.07% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 130: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 97.91% likelihood
#   Prediction 4: PVC with 2.09% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 131: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PVC with 99.99% likelihood
#   Prediction 4: PE with 0.01% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 132: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 97.75% likelihood
#   Prediction 4: PVC with 2.24% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 133: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: Unknown with 99.99% likelihood
#   Prediction 4: PE with 0.01% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 134: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PVC with 99.99% likelihood
#   Prediction 4: PE with 0.01% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 135: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 83.32% likelihood
#   Prediction 4: PVC with 16.68% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 136: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 95.82% likelihood
#   Prediction 4: PVC with 4.18% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 137: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 99.83% likelihood
#   Prediction 4: PVC with 0.16% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 138: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 92.91% likelihood
#   Prediction 4: PVC with 7.09% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 139: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 97.43% likelihood
#   Prediction 4: PE with 2.57% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 140: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.97% likelihood
#   Prediction 4: PVC with 0.03% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 141: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.86% likelihood
#   Prediction 4: PVC with 0.14% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 142: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PET with 99.91% likelihood
#   Prediction 4: PE with 0.09% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 143: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PE with 99.96% likelihood
#   Prediction 4: PET with 0.04% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 144: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.72% likelihood
#   Prediction 4: PVC with 0.16% likelihood
#   Prediction 5: PE with 0.12% likelihood
# Sample 145: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PET with 98.87% likelihood
#   Prediction 4: PVC with 0.66% likelihood
#   Prediction 5: PE with 0.47% likelihood
# Sample 146: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 99.96% likelihood
#   Prediction 4: PVC with 0.03% likelihood
#   Prediction 5: PE with 0.01% likelihood
# Sample 147: False, it was PE
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 83.68% likelihood
#   Prediction 4: PVC with 16.32% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 148: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.99% likelihood
#   Prediction 4: PVC with 0.01% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 149: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 83.20% likelihood
#   Prediction 4: PVC with 16.80% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 150: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PE with 99.99% likelihood
#   Prediction 4: PP with 0.01% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 151: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 99.81% likelihood
#   Prediction 4: PE with 0.19% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 152: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 153: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: Unknown with 0.00% likelihood
#   Prediction 5: PVC with 0.00% likelihood
# Sample 154: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 99.95% likelihood
#   Prediction 4: PET with 0.03% likelihood
#   Prediction 5: PP with 0.02% likelihood
# Sample 155: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 100.00% likelihood
#   Prediction 4: PVC with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 156: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 157: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 72.78% likelihood
#   Prediction 4: PVC with 27.22% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 158: Correct, it was PET
#   Prediction 1: PET with 0.02% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PVC with 95.74% likelihood
#   Prediction 4: PP with 2.17% likelihood
#   Prediction 5: PE with 2.08% likelihood
# Sample 159: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 100.00% likelihood
#   Prediction 4: PVC with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 160: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 50.06% likelihood
#   Prediction 4: PVC with 49.94% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 161: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 162: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 75.56% likelihood
#   Prediction 4: PVC with 24.44% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 163: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: Unknown with 99.82% likelihood
#   Prediction 4: PE with 0.18% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 164: Correct, it was PET
#   Prediction 1: PET with 0.01% likelihood
#   Prediction 2: PP with 0.01% likelihood
#   Prediction 3: PE with 99.30% likelihood
#   Prediction 4: Unknown with 0.62% likelihood
#   Prediction 5: PVC with 0.05% likelihood
# Sample 165: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 97.81% likelihood
#   Prediction 4: PVC with 2.05% likelihood
#   Prediction 5: PET with 0.15% likelihood
# Sample 166: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PVC with 100.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 167: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: Unknown with 99.81% likelihood
#   Prediction 4: PE with 0.19% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 168: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PE with 95.84% likelihood
#   Prediction 4: PET with 4.16% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 169: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 170: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.99% likelihood
#   Prediction 4: PVC with 0.01% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 171: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 172: False, it was PE
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 70.14% likelihood
#   Prediction 4: PVC with 29.86% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 173: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 79.18% likelihood
#   Prediction 4: PVC with 20.82% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 174: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 98.92% likelihood
#   Prediction 4: PVC with 1.05% likelihood
#   Prediction 5: PET with 0.03% likelihood
# Sample 175: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PVC with 99.85% likelihood
#   Prediction 4: PP with 0.15% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 176: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 67.42% likelihood
#   Prediction 4: PVC with 32.56% likelihood
#   Prediction 5: PET with 0.02% likelihood
# Sample 177: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 98.28% likelihood
#   Prediction 4: PVC with 1.72% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 178: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PE with 99.95% likelihood
#   Prediction 4: PET with 0.05% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 179: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PE with 99.94% likelihood
#   Prediction 4: PVC with 0.05% likelihood
#   Prediction 5: PET with 0.01% likelihood
# Sample 180: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PE with 98.55% likelihood
#   Prediction 4: PP with 1.45% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 181: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.97% likelihood
#   Prediction 4: PVC with 0.03% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 182: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.40% likelihood
#   Prediction 4: PVC with 0.60% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 183: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: Unknown with 99.98% likelihood
#   Prediction 4: PE with 0.02% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 184: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PET with 99.93% likelihood
#   Prediction 4: PE with 0.07% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 185: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 98.52% likelihood
#   Prediction 4: PE with 1.48% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 186: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 98.90% likelihood
#   Prediction 4: PVC with 1.10% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 187: Correct, it was PVC
#   Prediction 1: PVC with 0.01% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 93.57% likelihood
#   Prediction 4: PE with 6.30% likelihood
#   Prediction 5: PET with 0.11% likelihood
# Sample 188: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 99.99% likelihood
#   Prediction 4: PET with 0.01% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 189: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PET with 99.87% likelihood
#   Prediction 4: PP with 0.13% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 190: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 96.97% likelihood
#   Prediction 4: PE with 3.01% likelihood
#   Prediction 5: PET with 0.02% likelihood
# Sample 191: Correct, it was PET
#   Prediction 1: PET with 0.07% likelihood
#   Prediction 2: PVC with 0.01% likelihood
#   Prediction 3: PE with 97.05% likelihood
#   Prediction 4: Unknown with 2.57% likelihood
#   Prediction 5: PP with 0.30% likelihood
# Sample 192: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 93.26% likelihood
#   Prediction 4: PVC with 6.74% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 193: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PE with 99.64% likelihood
#   Prediction 4: PP with 0.32% likelihood
#   Prediction 5: PET with 0.04% likelihood
# Sample 194: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: Unknown with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 195: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PE with 99.84% likelihood
#   Prediction 4: PP with 0.16% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 196: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
# ...
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PE with 99.80% likelihood
#   Prediction 4: PVC with 0.18% likelihood
#   Prediction 5: PP with 0.01% likelihood
# Sample 8937: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8938: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 99.53% likelihood
#   Prediction 4: PVC with 0.47% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8939: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PET with 99.88% likelihood
#   Prediction 4: PE with 0.12% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 8940: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 98.48% likelihood
#   Prediction 4: PE with 1.52% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8941: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: Unknown with 99.88% likelihood
#   Prediction 4: PE with 0.12% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 8942: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.99% likelihood
#   Prediction 4: PVC with 0.01% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8943: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8944: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: Unknown with 99.97% likelihood
#   Prediction 4: PE with 0.02% likelihood
#   Prediction 5: PVC with 0.00% likelihood
# Sample 8945: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 8946: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: PE with 99.82% likelihood
#   Prediction 4: PVC with 0.18% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8947: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 100.00% likelihood
#   Prediction 4: PVC with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8948: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: Unknown with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 8949: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.93% likelihood
#   Prediction 4: PVC with 0.07% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8950: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 85.91% likelihood
#   Prediction 4: PVC with 14.07% likelihood
#   Prediction 5: PET with 0.03% likelihood
# Sample 8951: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 97.79% likelihood
#   Prediction 4: PVC with 1.78% likelihood
#   Prediction 5: PE with 0.43% likelihood
# Sample 8952: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.85% likelihood
#   Prediction 4: PVC with 0.15% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8953: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 99.70% likelihood
#   Prediction 4: PET with 0.30% likelihood
#   Prediction 5: PP with 0.01% likelihood
# Sample 8954: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PVC with 100.00% likelihood
#   Prediction 4: PP with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 8955: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PET with 99.93% likelihood
#   Prediction 4: PE with 0.07% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 8956: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PE with 99.39% likelihood
#   Prediction 4: PP with 0.56% likelihood
#   Prediction 5: PET with 0.05% likelihood
# Sample 8957: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 8958: Correct, it was Unknown
#   Prediction 1: Unknown with 0.17% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PE with 99.11% likelihood
#   Prediction 4: PP with 0.52% likelihood
#   Prediction 5: PET with 0.19% likelihood
# Sample 8959: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 98.11% likelihood
#   Prediction 4: PVC with 1.48% likelihood
#   Prediction 5: PET with 0.41% likelihood
# Sample 8960: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 88.91% likelihood
#   Prediction 4: PVC with 11.08% likelihood
#   Prediction 5: PET with 0.01% likelihood
# Sample 8961: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 8962: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 94.41% likelihood
#   Prediction 4: PVC with 5.54% likelihood
#   Prediction 5: PET with 0.04% likelihood
# Sample 8963: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PET with 99.99% likelihood
#   Prediction 4: PE with 0.01% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 8964: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PVC with 99.95% likelihood
#   Prediction 4: PP with 0.05% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 8965: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: PP with 99.98% likelihood
#   Prediction 4: PVC with 0.01% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8966: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 98.91% likelihood
#   Prediction 4: PVC with 1.09% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8967: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 95.62% likelihood
#   Prediction 4: PVC with 4.07% likelihood
#   Prediction 5: PET with 0.31% likelihood
# Sample 8968: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: Unknown with 99.99% likelihood
#   Prediction 4: PE with 0.01% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 8969: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.05% likelihood
#   Prediction 4: PVC with 0.95% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8970: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 91.56% likelihood
#   Prediction 4: PP with 8.44% likelihood
#   Prediction 5: PET with 0.01% likelihood
# Sample 8971: False, it was Unknown
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PE with 69.68% likelihood
#   Prediction 4: PP with 30.31% likelihood
#   Prediction 5: PET with 0.01% likelihood
# Sample 8972: Correct, it was PET
#   Prediction 1: PET with 0.01% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 99.24% likelihood
#   Prediction 4: PVC with 0.64% likelihood
#   Prediction 5: PE with 0.10% likelihood
# Sample 8973: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 96.81% likelihood
#   Prediction 4: PVC with 3.19% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8974: Correct, it was PET
#   Prediction 1: PET with 0.07% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 98.80% likelihood
#   Prediction 4: PVC with 0.63% likelihood
#   Prediction 5: PP with 0.50% likelihood
# Sample 8975: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PE with 100.00% likelihood
#   Prediction 4: Unknown with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 8976: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 95.69% likelihood
#   Prediction 4: PVC with 4.31% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8977: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 89.81% likelihood
#   Prediction 4: PVC with 10.19% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8978: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 98.44% likelihood
#   Prediction 4: PVC with 1.55% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 8979: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 95.05% likelihood
#   Prediction 4: PVC with 3.27% likelihood
#   Prediction 5: PET with 1.68% likelihood
# Sample 8980: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: PET with 0.00% likelihood
#   Prediction 3: Unknown with 99.67% likelihood
#   Prediction 4: PE with 0.32% likelihood
#   Prediction 5: PP with 0.01% likelihood
# Sample 8981: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 97.28% likelihood
#   Prediction 4: PVC with 2.72% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8982: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 98.17% likelihood
#   Prediction 4: PVC with 1.83% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8983: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 94.06% likelihood
#   Prediction 4: PE with 5.94% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8984: Correct, it was PET
#   Prediction 1: PET with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PVC with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 8985: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 97.57% likelihood
#   Prediction 4: PVC with 2.43% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8986: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 8987: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 8988: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 94.59% likelihood
#   Prediction 4: PVC with 5.41% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8989: Correct, it was PET
#   Prediction 1: PET with 0.01% likelihood
#   Prediction 2: Unknown with 0.01% likelihood
#   Prediction 3: PP with 99.78% likelihood
#   Prediction 4: PE with 0.17% likelihood
#   Prediction 5: PVC with 0.04% likelihood
# Sample 8990: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 94.65% likelihood
#   Prediction 4: PVC with 5.04% likelihood
#   Prediction 5: PET with 0.31% likelihood
# Sample 8991: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PE with 99.97% likelihood
#   Prediction 4: PET with 0.03% likelihood
#   Prediction 5: PP with 0.00% likelihood
# Sample 8992: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 99.54% likelihood
#   Prediction 4: PVC with 0.33% likelihood
#   Prediction 5: PET with 0.13% likelihood
# Sample 8993: Correct, it was PVC
#   Prediction 1: PVC with 0.00% likelihood
#   Prediction 2: Unknown with 0.00% likelihood
#   Prediction 3: PP with 99.08% likelihood
#   Prediction 4: PE with 0.92% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8994: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PP with 100.00% likelihood
#   Prediction 4: PET with 0.00% likelihood
#   Prediction 5: PE with 0.00% likelihood
# Sample 8995: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 99.19% likelihood
#   Prediction 4: PVC with 0.81% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8996: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 80.88% likelihood
#   Prediction 4: PVC with 18.94% likelihood
#   Prediction 5: PET with 0.18% likelihood
# Sample 8997: Correct, it was PP
#   Prediction 1: PP with 0.00% likelihood
#   Prediction 2: PE with 0.00% likelihood
#   Prediction 3: Unknown with 96.76% likelihood
#   Prediction 4: PVC with 3.24% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8998: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 99.73% likelihood
#   Prediction 4: PVC with 0.27% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 8999: Correct, it was PE
#   Prediction 1: PE with 0.00% likelihood
#   Prediction 2: PP with 0.00% likelihood
#   Prediction 3: Unknown with 100.00% likelihood
#   Prediction 4: PVC with 0.00% likelihood
#   Prediction 5: PET with 0.00% likelihood
# Sample 9000: Correct, it was Unknown
#   Prediction 1: Unknown with 0.00% likelihood
#   Prediction 2: PVC with 0.00% likelihood
#   Prediction 3: PET with 100.00% likelihood
#   Prediction 4: PE with 0.00% likelihood
#   Prediction 5: PP with 0.00% likelihood

# %%
# Get manual input from the user
manual_input = np.array([[1365889,2383139,3943193,6364119,6459881,3520279,1572135,859381,1734251,3039005,5108675,6392189,4980199,2559117,1249619]])  # Replace with your input values

# Normalize the manual input if needed
normalized_manual_input = ((manual_input - 0) / (8388608 - 0))

# Make predictions on manual input
predictions = model.predict(normalized_manual_input)
print(predictions)

# Get the top prediction
top_prediction = np.argmax(predictions)
print(top_prediction)

top_plastic_type = label_encoder.inverse_transform([top_prediction])[0]
print(top_plastic_type)
likelihood = predictions[0][top_prediction] * 100

# Display the prediction for manual input
print(f"Manual Input Prediction:")
print(f"  Prediction: {top_plastic_type} with {likelihood:.2f}% likelihood")
# Out:
# 1/1 [==============================] - 0s 47ms/step
# [[1.1588370e-01 6.4620035e-30 8.8411039e-01 3.9252628e-18 5.8985584e-06]]
# 2
# PP
# Manual Input Prediction:
#   Prediction: PP with 88.41% likelihood

# %%
# Make predictions from manual
manual_input = np.array([[1365889,2383139,3943193,6364119,6459881,3520279,1572135,859381,1734251,3039005,5108675,6392189,4980199,2559117,1249619
]])

# Calculate the column-wise min and max values from your original dataset
min_values = [74296, 1151721, 2379300, 2748695, 3681840, 1997402, 1742243, 942818, 392145, 795677, 1406647, 2482140, 2630495, 1748806, 1249297]
max_values = [1773075, 3755206, 7787954, 8401566, 8405071, 8401566, 7232265, 8185313, 2080604, 4455589, 8402979, 8405071, 8405071, 8403086, 6084492]

# Convert the lists to numpy arrays
min_values = np.array(min_values)
max_values = np.array(max_values)

# Normalize the manual input using the calculated min and max values
normalized_manual_input = (manual_input - min_values) / (max_values - min_values)
# normalized_manual_input = np.array([[0.85611,0.63202,0.53239,0.41068,0.59174,0.39869,0.44654,0.42188,0.8826042,0.67470967,0.34701898,0.42024683,0.34977269,0.16862726,0.1471771]])

print(normalized_manual_input)

predictions = model.predict(normalized_manual_input)
predicted_labels = np.argmax(predictions, axis=1)
predicted_plastic_types = label_encoder.inverse_transform(predicted_labels)

    
## Calculate the percentage likelihoods
percentage_likelihoods = predictions * 100

# Get the indices of the top 4 predicted classes based on percentage likelihoods
top_indices = np.argsort(percentage_likelihoods[0])[::-1][:4]

# Get the labels for the top predicted classes
top_labels = label_encoder.inverse_transform(top_indices)

# Get the predicted label
predicted_label = top_labels[0]

# Get the true label from the original data (replace with your true label)
true_label = 'ALU'  # Replace with the true label

# Calculate the accuracy
if predicted_label == true_label:
    accuracy = "Correct"
else:
    accuracy = "False"

# Print the prediction, label, and accuracy
print(f"Predicted label: {predicted_label}")
print(f"True label: {true_label}")
print(f"Accuracy: {accuracy}")

# Print the percentages for each type
for label, likelihood in zip(top_labels, percentage_likelihoods[0][top_indices]):
    print(f"{label}: {likelihood:.2f}% likelihood")
# Out:
# [[ 7.60306667e-01  4.72988321e-01  2.89146431e-01  6.39573059e-01
#    5.88165389e-01  2.37794816e-01 -3.09849396e-02 -1.15204774e-02
#    7.94870352e-01  6.12945885e-01  5.29138411e-01  6.60154407e-01
#    4.06905026e-01  1.21772904e-01  6.65950391e-05]]
# 1/1 [==============================] - 0s 16ms/step
# Predicted label: Unknown
# True label: ALU
# Accuracy: False
# Unknown: 100.00% likelihood
# PE: 0.00% likelihood
# PP: 0.00% likelihood
# PVC: 0.00% likelihood

# %%
# model.save("15_point_plastic_classifier_model_2_10_HvL.keras")
